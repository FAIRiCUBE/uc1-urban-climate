# %% [markdown]
# # Visualize SentinelHub BYOC collections
# 1. SentinelHub configuration
# 2. List collections and tiles
# 3. Define AOI and visualize it
# 4. Request collection
# 5. Visualize data
# 6. Visualize tile extent

# %% [markdown]
# ## 1. SentinelHub configuration

# %%
# Configure plots for inline use in Jupyter Notebook
# %matplotlib inline

import datetime as dt

# Utilities
import boto3
import dateutil
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import IPython.display
import shapely.geometry

# Sentinel Hub
from sentinelhub import (
    CRS,
    BBox,
    ByocCollection,
    ByocCollectionAdditionalData,
    ByocCollectionBand,
    ByocTile,
    DataCollection,
    DownloadFailedException,
    MimeType,
    SentinelHubBYOC,
    SentinelHubRequest,
    SHConfig,
    bbox_to_dimensions,
)

config = SHConfig()
config.instance_id = os.environ.get("SH_INSTANCE_ID")
config.sh_client_id = os.environ.get("SH_CLIENT_ID")
config.sh_client_secret = os.environ.get("SH_CLIENT_SECRET")
config.aws_access_key_id = os.environ.get("username")
config.aws_secret_access_key = os.environ.get("password")

# %% [markdown]
# ## 2. List collections and tiles

# %%
# Initialize SentinelHubBYOC class
#https://sentinelhub-py.readthedocs.io/en/latest/reference/sentinelhub.html
byoc = SentinelHubBYOC(config=config)
print ("START--------------------------")
# list collections and tiles
# from: https://sentinelhub-py.readthedocs.io/en/latest/examples/byoc_request.html
collections_iterator = byoc.iter_collections()
my_collections = list(collections_iterator)
for collection in my_collections:
    
    print("Collection name:", collection["name"])
    print("Collection id: ", collection["id"])
    tiles = list(byoc.iter_tiles(collection))
    for tile in tiles:
        print("Tile status: ", tile['status'])
        print("Tile created: ", tile['created'])
        print("Tile path: ", tile['path'])
        if(tile['status'] == "FAILED"):
            print("Ingestion failed error: ", tile['additionalData'])
    print("-------------------")
print ("end")
# Out:
# START--------------------------
# Collection name: urban_audit_2021_city
# Collection id:  20774d38-7b2e-43e9-b574-66fa2954da1c
# Tile status:  INGESTED
# Tile created:  2023-03-02T13:33:53.529323Z
# Tile path:  data/d001_administration/urban_audit_city_2021/urban_audit_2021_city_10m_3035_2_6_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-02T13:33:49.103925Z
# Tile path:  data/d001_administration/urban_audit_city_2021/urban_audit_2021_city_10m_3035_3_1_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-02T13:33:53.700509Z
# Tile path:  data/d001_administration/urban_audit_city_2021/urban_audit_2021_city_10m_3035_3_6_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-02T13:33:43.663503Z
# Tile path:  data/d001_administration/urban_audit_city_2021/urban_audit_2021_city_10m_3035_3_4_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-02T13:33:43.825528Z
# Tile path:  data/d001_administration/urban_audit_city_2021/urban_audit_2021_city_10m_3035_3_3_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-02T13:33:48.301249Z
# Tile path:  data/d001_administration/urban_audit_city_2021/urban_audit_2021_city_10m_3035_1_2_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-02T13:33:49.333324Z
# Tile path:  data/d001_administration/urban_audit_city_2021/urban_audit_2021_city_10m_3035_1_1_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-02T13:33:52.783437Z
# Tile path:  data/d001_administration/urban_audit_city_2021/urban_audit_2021_city_10m_3035_4_4_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-02T13:33:52.644015Z
# Tile path:  data/d001_administration/urban_audit_city_2021/urban_audit_2021_city_10m_3035_4_3_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-02T13:33:44.267163Z
# Tile path:  data/d001_administration/urban_audit_city_2021/urban_audit_2021_city_10m_3035_1_4_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-02T13:33:53.148400Z
# Tile path:  data/d001_administration/urban_audit_city_2021/urban_audit_2021_city_10m_3035_4_1_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-02T13:33:48.563978Z
# Tile path:  data/d001_administration/urban_audit_city_2021/urban_audit_2021_city_10m_3035_2_5_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-02T13:33:53.908595Z
# Tile path:  data/d001_administration/urban_audit_city_2021/urban_audit_2021_city_10m_3035_4_6_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-02T13:33:53.342733Z
# Tile path:  data/d001_administration/urban_audit_city_2021/urban_audit_2021_city_10m_3035_1_6_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-02T13:33:43.459976Z
# Tile path:  data/d001_administration/urban_audit_city_2021/urban_audit_2021_city_10m_3035_2_4_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-02T13:33:52.920634Z
# Tile path:  data/d001_administration/urban_audit_city_2021/urban_audit_2021_city_10m_3035_4_5_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-02T13:33:52.297026Z
# Tile path:  data/d001_administration/urban_audit_city_2021/urban_audit_2021_city_10m_3035_2_1_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-02T13:33:52.438111Z
# Tile path:  data/d001_administration/urban_audit_city_2021/urban_audit_2021_city_10m_3035_4_2_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-02T13:33:48.757929Z
# Tile path:  data/d001_administration/urban_audit_city_2021/urban_audit_2021_city_10m_3035_1_5_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-02T13:33:44.039588Z
# Tile path:  data/d001_administration/urban_audit_city_2021/urban_audit_2021_city_10m_3035_2_3_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-02T13:33:48.051470Z
# Tile path:  data/d001_administration/urban_audit_city_2021/urban_audit_2021_city_10m_3035_2_2_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-02T13:33:47.811977Z
# Tile path:  data/d001_administration/urban_audit_city_2021/urban_audit_2021_city_10m_3035_1_3_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-02T13:33:46.899689Z
# Tile path:  data/d001_administration/urban_audit_city_2021/urban_audit_2021_city_10m_3035_3_2_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-02T13:33:46.643267Z
# Tile path:  data/d001_administration/urban_audit_city_2021/urban_audit_2021_city_10m_3035_3_5_(BAND).tif
# -------------------
# Collection name: UrbanAtlas2018_10m_raster_v1
# Collection id:  27c95f8f-fb6b-46f2-8f84-2ce7761eeccd
# Tile status:  INGESTED
# Tile created:  2023-03-01T16:15:07.907902Z
# Tile path:  data/d002_urban_atlas/ua2018_mosaic_raster_10m_cog_2_4_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-01T16:15:08.032911Z
# Tile path:  data/d002_urban_atlas/ua2018_mosaic_raster_10m_cog_2_3_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-01T16:15:06.063378Z
# Tile path:  data/d002_urban_atlas/ua2018_mosaic_raster_10m_cog_4_4_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-01T16:15:06.517056Z
# Tile path:  data/d002_urban_atlas/ua2018_mosaic_raster_10m_cog_4_2_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-01T16:15:07.339291Z
# Tile path:  data/d002_urban_atlas/ua2018_mosaic_raster_10m_cog_3_2_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-01T16:15:06.925264Z
# Tile path:  data/d002_urban_atlas/ua2018_mosaic_raster_10m_cog_3_5_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-01T16:15:07.502707Z
# Tile path:  data/d002_urban_atlas/ua2018_mosaic_raster_10m_cog_3_1_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-01T16:15:08.540383Z
# Tile path:  data/d002_urban_atlas/ua2018_mosaic_raster_10m_cog_1_5_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-01T16:15:08.404789Z
# Tile path:  data/d002_urban_atlas/ua2018_mosaic_raster_10m_cog_1_6_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-01T16:15:04.647122Z
# Tile path:  data/d002_urban_atlas/ua2018_mosaic_raster_10m_cog_5_6_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-01T16:15:08.672430Z
# Tile path:  data/d002_urban_atlas/ua2018_mosaic_raster_10m_cog_1_4_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-01T16:15:04.839411Z
# Tile path:  data/d002_urban_atlas/ua2018_mosaic_raster_10m_cog_5_5_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-01T16:15:09.045712Z
# Tile path:  data/d002_urban_atlas/ua2018_mosaic_raster_10m_cog_1_1_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-01T16:15:08.930817Z
# Tile path:  data/d002_urban_atlas/ua2018_mosaic_raster_10m_cog_1_2_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-01T16:15:05.031858Z
# Tile path:  data/d002_urban_atlas/ua2018_mosaic_raster_10m_cog_5_4_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-01T16:15:08.287696Z
# Tile path:  data/d002_urban_atlas/ua2018_mosaic_raster_10m_cog_2_1_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-01T16:15:05.747036Z
# Tile path:  data/d002_urban_atlas/ua2018_mosaic_raster_10m_cog_4_6_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-01T16:15:05.575903Z
# Tile path:  data/d002_urban_atlas/ua2018_mosaic_raster_10m_cog_5_1_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-01T16:15:08.161713Z
# Tile path:  data/d002_urban_atlas/ua2018_mosaic_raster_10m_cog_2_2_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-01T16:15:06.776811Z
# Tile path:  data/d002_urban_atlas/ua2018_mosaic_raster_10m_cog_3_6_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-01T16:15:06.658685Z
# Tile path:  data/d002_urban_atlas/ua2018_mosaic_raster_10m_cog_4_1_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-01T16:15:05.902704Z
# Tile path:  data/d002_urban_atlas/ua2018_mosaic_raster_10m_cog
4_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-07T14:06:42.892293Z
# Tile path:  data/d001_administration/nuts_2021/NUTS2021_100m_1_1_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-07T14:06:42.450055Z
# Tile path:  data/d001_administration/nuts_2021/NUTS2021_100m_1_5_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-07T14:06:41.396948Z
# Tile path:  data/d001_administration/nuts_2021/NUTS2021_100m_2_5_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-07T14:06:42.994822Z
# Tile path:  data/d001_administration/nuts_2021/NUTS2021_100m_1_2_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-07T14:06:41.990416Z
# Tile path:  data/d001_administration/nuts_2021/NUTS2021_100m_2_3_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-07T14:06:40.894487Z
# Tile path:  data/d001_administration/nuts_2021/NUTS2021_100m_3_5_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-07T14:06:42.215203Z
# Tile path:  data/d001_administration/nuts_2021/NUTS2021_100m_5_1_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-07T14:06:42.099072Z
# Tile path:  data/d001_administration/nuts_2021/NUTS2021_100m_4_2_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-07T14:06:40.037123Z
# Tile path:  data/d001_administration/nuts_2021/NUTS2021_100m_4_4_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-07T14:06:41.286204Z
# Tile path:  data/d001_administration/nuts_2021/NUTS2021_100m_5_6_(BAND).tif
# Tile status:  INGESTED
# Tile created:  2023-03-07T14:06:40.776729Z
# Tile path:  data/d001_administration/nuts_2021/NUTS2021_100m_5_3_(BAND).tif
# -------------------
# end

# %%
# get first tile of first collection
collections_iterator = byoc.iter_collections()
collection = next(collections_iterator)
tile = next(byoc.iter_tiles(collection))
tile
# Out:
# {'id': '9561d1e7-f041-41b6-b790-8cc9c4bd0597',
#  'created': '2023-03-01T10:20:07.219071Z',
#  'ingestionStart': '2023-03-01T10:20:07.219071Z',
#  'coverGeometry': {'type': 'Polygon',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#   'coordinates': [[[4273019.999997908, 4270229.999845818],
#     [5273020.000042262, 4270229.99984135],
#     [5273020.000041623, 5270229.999898263],
#     [4273019.999997887, 5270229.999899021],
#     [4273019.999997908, 4270229.999845818]]]},
#  'tileGeometry': {'type': 'Polygon',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#   'coordinates': [[[4273020.0, 5270230.0],
#     [5273020.0, 5270230.0],
#     [5273020.0, 4270230.0],
#     [4273020.0, 4270230.0],
#     [4273020.0, 5270230.0]]]},
#  'path': 'data/d002_urban_atlas_tiles2/ua2018_mosaic_raster_10m_cog_1_4_(BAND).tif',
#  'status': 'INGESTED',
#  'additionalData': {'hasAddedPoints': True,
#   'filesMetadata': {'B1': {'headerSize': 104786,
#     'etag': '"8561d73ebbbc0a9a1859e0a199051ce9-215"'}},
#   'minMetersPerPixel': 10.0,
#   'maxMetersPerPixel': 1280.0}}

# %% [markdown]
# ## 3. Define AOI and visualize it

# %%
### Lux extent box 6.20,49.60 : 6.34,49.66
## test area 2 17.968,  69.43 
##           : 20.376,  70.16 

x1 = 6.2  # degree
y1 = 49.60  # degree
x2 = 6.34 # degree
y2 = 49.66  # degree


# x1 = 19.50  # degree
# y1 = 69.43  # degree
# x2 = 19.51 # degree
# y2 = 69.44  # degree

aoi = BBox([x1, y1, x2, y2], crs=CRS.WGS84)
IPython.display.GeoJSON(shapely.geometry.box(*aoi).__geo_interface__)
#spatial_res = 0.00018   # = 20.038 meters in degree

# %% [markdown]
# ## 4. Request collection
# Define a DataCollection object from the collectionId.
# Get some information about the collection, such as band names, sample format, etc.

# %%
#https://sentinelhub-py.readthedocs.io/en/latest/examples/byoc_request.html
#https://eurodatacube.com/notebooks/contributions/LPIS_LULC-Slo.ipynb
data_collection = DataCollection.define_byoc("27c95f8f-fb6b-46f2-8f84-2ce7761eeccd")

# list band names of the collection
collection = byoc.get_collection("27c95f8f-fb6b-46f2-8f84-2ce7761eeccd")
collection["additionalData"]
# Out:
# {'bands': {'B1': {'bitDepth': 16,
#    'source': 'B1',
#    'bandIndex': 1,
#    'sampleFormat': 'UINT'}},
#  'maxMetersPerPixel': 6400.0,
#  'extent': {'type': 'Polygon',
#   'coordinates': [[[-49.396508783, 26.176870268],
#     [-49.396508783, 70.57381085],
#     [67.130764957, 70.57381085],
#     [67.130764957, 26.176870268],
#     [-49.396508783, 26.176870268]]]},
#  'hasSensingTimes': 'NO'}

# %% [markdown]
# ### Request to SentinelHub
# Ingredients for a SentinelHub request are:
# - SentinelHub configuration
# - AOI and AOI size
# - requested collection
# - desired output type
# - evalscript
#
# The evalscript tells SH how to compute the output. It is made of two functions
# - setup(), which specifies which bands are requested and how to structure the output
# - evaluatePixel(), which specifies the pixel-wise computation to be done.
# More information about evalscript: [https://docs.sentinel-hub.com/api/latest/evalscript/]

# %%
evalscript_test = """

//VERSION=3
function setup() {
  return {
    input: ["B1"],
    output: { 
        bands: 1 ,
        sampleType: "UINT16" // raster format will be UINT16
        }
    
  };
}

function evaluatePixel(sample) {
  return [sample.B1];
}
"""

request = SentinelHubRequest(
        evalscript=evalscript_test,
        input_data=[
            SentinelHubRequest.input_data(
                data_collection=data_collection,
                #time_interval=tile_time
                # time_interval="2018"
            )
        ],
        responses=[
            SentinelHubRequest.output_response('default', MimeType.PNG)
        ],
        bbox=aoi,
        size=bbox_to_dimensions(aoi, 10),
        config=config
    )

# %% [markdown]
# ## 5. Visualize data

# %%
data = request.get_data()[0]

# is there anything in the data?
if(np.std(data) == 0): 
    print("Error: data is empty :(")
else:
    print("Success!")
    # plot data
    fig, ax = plt.subplots(figsize=(10, 10))

    ax.imshow(data)
    # ax.set_title(tile_time.date().isoformat(), fontsize=10)

    plt.tight_layout()
# Out:
# Success!

# %% [markdown]
# ## 6. Visualize tile extent

# %%
# show tile info in table format -- works for one tile
tile_iterator = byoc.iter_tiles(collection)
tiles_for_visualized = []
tiles_for_visualized.append(ByocTile.from_dict(next(tile_iterator)))

tiles_gdf = gpd.GeoDataFrame(
    tiles_for_visualized,
    geometry=[t.cover_geometry.transform(CRS.WGS84).geometry for t in tiles_for_visualized],
    crs="epsg:4326",
)
tiles_gdf

# show tile info in table format -- works for more than one tiles
# tile_iterator = byoc.iter_tiles(created_collection)
# tiles_for_visualized = []
# for i in range(100):
#     tiles_for_visualized.append(ByocTile.from_dict(next(tile_iterator)))

# tiles_gdf = gpd.GeoDataFrame(
#     tiles_for_visualized,
#     geometry=[t.cover_geometry.transform(CRS.WGS84).geometry for t in tiles_for_visualized],
#     crs="epsg:4326",
# )
# tiles_gdf.head()
# Out:
#                                                 path    status  \
# 0  data/d002_urban_atlas/ua2018_mosaic_raster_10m...  INGESTED
#
#                                 tile_id  \
# 0  0b4fe15f-3396-44ef-abeb-fc32aa36bc6d
#
#                                        tile_geometry  \
# 0  Geometry(POLYGON ((4273020 4270230, 5273020 42...
#
#                                       cover_geometry  \
# 0  Geometry(POLYGON ((4273019.999997257 3270229.9...
#
#                            created sensing_time  \
# 0 2023-03-01 16:15:07.907902+00:00         None
#
#                                      additional_data  \
# 0  {'hasAddedPoints': True, 'filesMetadata': {'B1...
#
#                                           other_data  \
# 0  {'ingestionStart': '2023-03-01T16:15:07.907902Z'}
#
#                                             geometry
# 0  POLYGON ((9.29285 52.53919, 23.87409 51.72383,...

# %%
# show tile extent...
fig, ax = plt.subplots(figsize=(17, 8))
tiles_gdf.plot(ax=ax)
# Out:
# <AxesSubplot: >
