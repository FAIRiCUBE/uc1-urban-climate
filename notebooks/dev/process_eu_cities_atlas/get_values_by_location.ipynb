# %% [markdown]
# # Get data cube values at given locations
#
# Get the value from all data cube dimensions at the species occurrence location.
# -------
# v0.1: First version, Maria Ricci

# %%
import xarray as xr
import rioxarray as rxr
from glob import glob
import re

# %%
# load cube
import re

pattern = r'\\|\.' # to get the name of the layer from the filename

path = "N:/C2205_FAIRiCUBE/f02_data/d060_data_LUXEMBOURG/f01_Lux_neopyhtes/f02_luxembourg_data/f02_raster_10m_collection/*.tif"
layers = glob(path)
da_dict = {}
for layer in layers:
    name = re.split(pattern, layer)[-2]
    # print(layer)
    print(name)
    da = rxr.open_rasterio(filename=layer, default_name=name) # type: ignore
    da_dict[name] = da
da_dict
# Out:
# admin_commune_2024_10m_b1
# admin_quartiers_2024_10m_b1
# cadaster_vdl_public_private_layer_2024_10m_b1
# dem_2019_10m_b1
# dem_aspect_2019_10m_b1
# dem_slope_2019_10m_b1
# dem_surface_model_2019_10m_b1
# flood_map_2021_10m_b1
# hrl_treecover_2018_10m_b1
# land_cover_2018_2021_10m_b2
# land_use_07_15_18_21_10m_b4
# protected_areas_v21_2023_10m_b1
# public_forests_2024_10m_b1
# soil_map_100000_2024_10m_b1
# soil_map_25000_2024_10m_b1
# traffic_intensity_2024_10m_b1
# {'admin_commune_2024_10m_b1': <xarray.DataArray 'admin_commune_2024_10m_b1' (band: 1, y: 1044, x: 972)>
#  [1014768 values with dtype=uint8]
#  Coordinates:
#    * band         (band) int32 1
#    * x            (x) float64 7.286e+04 7.286e+04 ... 8.256e+04 8.256e+04
#    * y            (y) float64 8.002e+04 8.002e+04 8e+04 ... 6.96e+04 6.96e+04
#      spatial_ref  int32 0
#  Attributes:
#      AREA_OR_POINT:  Area
#      _FillValue:     0
#      scale_factor:   1.0
#      add_offset:     0.0,
#  'admin_quartiers_2024_10m_b1': <xarray.DataArray 'admin_quartiers_2024_10m_b1' (band: 1, y: 1044, x: 972)>
#  [1014768 values with dtype=int32]
#  Coordinates:
#    * band         (band) int32 1
#    * x            (x) float64 7.286e+04 7.286e+04 ... 8.256e+04 8.256e+04
#    * y            (y) float64 8.002e+04 8.002e+04 8e+04 ... 6.96e+04 6.96e+04
#      spatial_ref  int32 0
#  Attributes:
#      AREA_OR_POINT:  Area
#      _FillValue:     0
#      scale_factor:   1.0
#      add_offset:     0.0,
#  'cadaster_vdl_public_private_layer_2024_10m_b1': <xarray.DataArray 'cadaster_vdl_public_private_layer_2024_10m_b1' (band: 1,
#                                                                     y: 1044,
#                                                                     x: 972)>
#  [1014768 values with dtype=int32]
#  Coordinates:
#    * band         (band) int32 1
#    * x            (x) float64 7.286e+04 7.286e+04 ... 8.256e+04 8.256e+04
#    * y            (y) float64 8.002e+04 8.002e+04 8e+04 ... 6.96e+04 6.96e+04
#      spatial_ref  int32 0
#  Attributes:
#      AREA_OR_POINT:  Area
#      _FillValue:     -1
#      scale_factor:   1.0
#      add_offset:     0.0,
#  'dem_2019_10m_b1': <xarray.DataArray 'dem_2019_10m_b1' (band: 1, y: 1044, x: 972)>
#  [1014768 values with dtype=float32]
#  Coordinates:
#    * band         (band) int32 1
#    * x            (x) float64 7.286e+04 7.286e+04 ... 8.256e+04 8.256e+04
#    * y            (y) float64 8.002e+04 8.002e+04 8e+04 ... 6.96e+04 6.96e+04
#      spatial_ref  int32 0
#  Attributes:
#      AREA_OR_POINT:  Area
#      _FillValue:     -3.4028235e+38
#      scale_factor:   1.0
#      add_offset:     0.0,
#  'dem_aspect_2019_10m_b1': <xarray.DataArray 'dem_aspect_2019_10m_b1' (band: 1, y: 1044, x: 972)>
#  [1014768 values with dtype=float32]
#  Coordinates:
#    * band         (band) int32 1
#    * x            (x) float64 7.286e+04 7.286e+04 ... 8.256e+04 8.256e+04
#    * y            (y) float64 8.002e+04 8.002e+04 8e+04 ... 6.96e+04 6.96e+04
#      spatial_ref  int32 0
#  Attributes:
#      AREA_OR_POINT:  Area
#      _FillValue:     -9999.0
#      scale_factor:   1.0
#      add_offset:     0.0,
#  'dem_slope_2019_10m_b1': <xarray.DataArray 'dem_slope_2019_10m_b1' (band: 1, y: 1044, x: 972)>
#  [1014768 values with dtype=float32]
#  Coordinates:
#    * band         (band) int32 1
#    * x            (x) float64 7.286e+04 7.286e+04 ... 8.256e+04 8.256e+04
#    * y            (y) float64 8.002e+04 8.002e+04 8e+04 ... 6.96e+04 6.96e+04
#      spatial_ref  int32 0
#  Attributes:
#      AREA_OR_POINT:  Area
#      _FillValue:     -9999.0
#      scale_factor:   1.0
#      add_offset:     0.0,
#  'dem_surface_model_2019_10m_b1': <xarray.DataArray 'dem_surface_model_2019_10m_b1' (band: 1, y: 1044, x: 972)>
#  [1014768 values with dtype=float32]
#  Coordinates:
#    * band         (band) int32 1
#    * x            (x) float64 7.286e+04 7.286e+04 ... 8.256e+04 8.256e+04
#    * y            (y) float64 8.002e+04 8.002e+04 8e+04 ... 6.96e+04 6.96e+04
#      spatial_ref  int32 0
#  Attributes:
#      AREA_OR_POINT:  Point
#      _FillValue:     -1.0
#      scale_factor:   1.0
#      add_offset:     0.0,
#  'flood_map_2021_10m_b1': <xarray.DataArray 'flood_map_2021_10m_b1' (band: 1, y: 1044, x: 972)>
#  [1014768 values with dtype=float32]
#  Coordinates:
#    * band         (band) int32 1
#    * x            (x) float64 7.286e+04 7.286e+04 ... 8.256e+04 8.256e+04
#    * y            (y) float64 8.002e+04 8.002e+04 8e+04 ... 6.96e+04 6.96e+04
#      spatial_ref  int32 0
#  Attributes:
#      AREA_OR_POINT:  Area
#      _FillValue:     0.0
#      scale_factor:   1.0
#      add_offset:     0.0,
#  'hrl_treecover_2018_10m_b1': <xarray.DataArray 'hrl_treecover_2018_10m_b1' (band: 1, y: 1044, x: 972)>
#  [1014768 values with dtype=uint8]
#  Coordinates:
#    * band         (band) int32 1
#    * x            (x) float64 7.286e+04 7.286e+04 ... 8.256e+04 8.256e+04
#    * y            (y) float64 8.002e+04 8.002e+04 8e+04 ... 6.96e+04 6.96e+04
#      spatial_ref  int32 0
#  Attributes:
#      AREA_OR_POINT:       Area
#      DataType:            Thematic
#      RepresentationType:  THEMATIC
#      _FillValue:          0
#      scale_factor:        1.0
#      add_offset:          0.0,
#  'land_cover_2018_2021_10m_b2': <xarray.DataArray 'land_cover_2018_2021_10m_b2' (band: 2, y: 1044, x: 972)>
#  [2029536 values with dtype=int16]
#  Coordinates:
#    * band         (band) int32 1 2
#    * x            (x) float64 7.286e+04 7.286e+04 ... 8.256e+04 8.256e+04
#    * y            (y) float64 8.002e+04 8.002e+04 8e+04 ... 6.96e+04 6.96e+04
#      spatial_ref  int32 0
#  Attributes:
#      AREA_OR_POINT:  Area
#      _FillValue:     -32768
#      scale_factor:   1.0
#      add_offset:     0.0,
#  'land_use_07_15_18_21_10m_b4': <xarray.DataArray 'land_use_07_15_18_21_10m_b4' (band: 4, y: 1044, x: 972)>
#  [4059072 values with dtype=int16]
#  Coordinates:
#    * band         (band) int32 1 2 3 4
#    * x            (x) float64 7.286e+04 7.286e+04 ... 8.256e+04 8.256e+04
#    * y            (y) float64 8.002e+04 8.002e+04 8e+04 ... 6.96e+04 6.96e+04
#      spatial_ref  int32 0
#  Attributes:
#      AREA_OR_POINT:  Area
#      scale_factor:   1.0
#      add_offset:     0.0,
#  'protected_areas_v21_2023_10m_b1': <xarray.DataArray 'protected_areas_v21_2023_10m_b1' (band: 1, y: 1044, x: 972)>
#  [1014768 values with dtype=uint32]
#  Coordinates:
#    * band         (band) int32 1
#    * x            (x) float64 7.286e+04 7.286e+04 ... 8.256e+04 8.256e+04
#    * y            (y) float64 8.002e+04 8.002e+04 8e+04 ... 6.96e+04 6.96e+04
#      spatial_ref  int32 0
#  Attributes:
#      AREA_OR_POINT:  Area
#      _FillValue:     0
#      scale_factor:   1.0
#      add_offset:     0.0,
#  'public_forests_2024_10m_b1': <xarray.DataArray 'public_forests_2024_10m_b1' (band: 1, y: 1044, x: 972)>
#  [1014768 values with dtype=int32]
#  Coordinates:
#    * band         (band) int32 1
#    * x            (x) float64 7.286e+04 7.286e+04 ... 8.256e+04 8.256e+04
#    * y            (y) float64 8.002e+04 8.002e+04 8e+04 ... 6.96e+04 6.96e+04
#      spatial_ref  int32 0
#  Attributes:
#      AREA_OR_POINT:  Area
#      _FillValue:     -1
#      scale_factor:   1.0
#      add_offset:     0.0,
#  'soil_map_100000_2024_10m_b1': <xarray.DataArray 'soil_map_100000_2024_10m_b1' (band: 1, y: 1044, x: 972)>
#  [1014768 values with dtype=int16]
#  Coordinates:
#    * band         (band) int32 1
#    * x            (x) float64 7.286e+04 7.286e+04 ... 8.256e+04 8.256e+04
#    * y            (y) float64 8.002e+04 8.002e+04 8e+04 ... 6.96e+04 6.96e+04
#      spatial_ref  int32 0
#  Attributes:
#      AREA_OR_POINT:  Area
#      _FillValue:     0
#      scale_factor:   1.0
#      add_offset:     0.0,
#  'soil_map_25000_2024_10m_b1': <xarray.DataArray 'soil_map_25000_2024_10m_b1' (band: 1, y: 1044, x: 972)>
#  [1014768 values with dtype=int16]
#  Coordinates:
#    * band         (band) int32 1
#    * x            (x) float64 7.286e+04 7.286e+04 ... 8.256e+04 8.256e+04
#    * y            (y) float64 8.002e+04 8.002e+04 8e+04 ... 6.96e+04 6.96e+04
#      spatial_ref  int32 0
#  Attributes:
#      AREA_OR_POINT:             Area
#      STATISTICS_APPROXIMATE:    YES
#      STATISTICS_MAXIMUM:        217
#      STATISTICS_MEAN:           118.97528945823
#      STATISTICS_MINIMUM:        1
#      STATISTICS_STDDEV:         49.484005893968
#      STATISTICS_VALID_PERCENT:  79.84
#      _FillValue:                -9
#      scale_factor:              1.0
#      add_offset:                0.0,
#  'traffic_intensity_2024_10m_b1': <xarray.DataArray 'traffic_intensity_2024_10m_b1' (band: 1, y: 1044, x: 972)>
#  [1014768 values with dtype=float32]
#  Coordinates:
#    * band         (band) int32 1
#    * x            (x) float64 7.286e+04 7.286e+04 ... 8.256e+04 8.256e+04
#    * y            (y) float64 8.002e+04 8.002e+04 8e+04 ... 6.96e+04 6.96e+04
#      spatial_ref  int32 0
#  Attributes:
#      AREA_OR_POINT:  Area
#      _FillValue:     -9999.0
#      scale_factor:   1.0
#      add_offset:     0.0}

# %%
ds = xr.Dataset(da_dict)

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:                                        (band: 4, x: 972, y: 1044)
# Coordinates:
#   * band                                           (band) int32 1 2 3 4
#   * x                                              (x) float64 7.286e+04 ... ...
#   * y                                              (y) float64 8.002e+04 ... ...
#     spatial_ref                                    int32 0
# Data variables: (12/16)
#     admin_commune_2024_10m_b1                      (band, y, x) float64 0.0 ....
#     admin_quartiers_2024_10m_b1                    (band, y, x) float64 0.0 ....
#     cadaster_vdl_public_private_layer_2024_10m_b1  (band, y, x) float64 1.0 ....
#     dem_2019_10m_b1                                (band, y, x) float32 327.0...
#     dem_aspect_2019_10m_b1                         (band, y, x) float32 180.0...
#     dem_slope_2019_10m_b1                          (band, y, x) float32 5.711...
#     ...                                             ...
#     land_use_07_15_18_21_10m_b4                    (band, y, x) int16 ...
#     protected_areas_v21_2023_10m_b1                (band, y, x) float64 0.0 ....
#     public_forests_2024_10m_b1                     (band, y, x) float64 1.0 ....
#     soil_map_100000_2024_10m_b1                    (band, y, x) float64 0.0 ....
#     soil_map_25000_2024_10m_b1                     (band, y, x) float64 121.0...
#     traffic_intensity_2024_10m_b1                  (band, y, x) float32 -9.99...

# %%
ds.traffic_intensity_2024_10m_b1.sel(band=1).plot()

# %%
# load point data
import pandas as pd

# %%
# %load_ext sql

# %%
# %sql --section fairicube
# Out:
# Connecting to 'fairicube'

# %%
# %sqlcmd tables --schema luxembourg_species
# Out:
# +--------------------------------+
# |              Name              |
# +--------------------------------+
# |         neophytes_list         |
# |     neophytes_geometry_raw     |
# | neophytes_geometry_description |
# | luxembourg_species_description |
# |       neophytes_geometry       |
# |          all_species           |
# |      neophytes_list_gbif       |
# |     all_species_neophytes      |
# +--------------------------------+

# %%
# %sqlcmd columns --table neophytes_geometry --schema luxembourg_species
# Out:
# +--------------------+------------------+----------+---------+---------------+---------+
# |        name        |       type       | nullable | default | autoincrement | comment |
# +--------------------+------------------+----------+---------+---------------+---------+
# |      gbif_key      |      BIGINT      |   True   |   None  |     False     |   None  |
# |      species       |       TEXT       |   True   |   None  |     False     |   None  |
# |       family       |       TEXT       |   True   |   None  |     False     |   None  |
# |    species_name    |       TEXT       |   True   |   None  |     False     |   None  |
# | species_name_lower |       TEXT       |   True   |   None  |     False     |   None  |
# |  observation_key   |       TEXT       |   True   |   None  |     False     |   None  |
# |     date_start     |       DATE       |   True   |   None  |     False     |   None  |
# |      date_end      |       DATE       |   True   |   None  |     False     |   None  |
# |    sample_date     |       DATE       |   True   |   None  |     False     |   None  |
# |   taxon_kingdom    |       TEXT       |   True   |   None  |     False     |   None  |
# |    taxon_phylum    |       TEXT       |   True   |   None  |     False     |   None  |
# |    taxon_class     |       TEXT       |   True   |   None  |     False     |   None  |
# |    taxon_order     |       TEXT       |   True   |   None  |     False     |   None  |
# |    taxon_family    |       TEXT       |   True   |   None  |     False     |   None  |
# |    taxon_genus     |       TEXT       |   True   |   None  |     False     |   None  |
# |    sample_type     |       TEXT       |   True   |   None  |     False     |   None  |
# |      lat_orig      | DOUBLE PRECISION |   True   |   None  |     False     |   None  |
# |      lon_orig      | DOUBLE PRECISION |   True   |   None  |     False     |   None  |
# |     x_epsg2169     |     INTEGER      |   True   |   None  |     False     |   None  |
# |     y_epsg2169     |     INTEGER      |   True   |   None  |     False     |   None  |
# | gridnum2169_100m_x |     INTEGER      |   True   |   None  |     False     |   None  |
# | gridnum2169_100m_y |     INTEGER      |   True   |   None  |     False     |   None  |
# |  gridnum2169_100m  |       TEXT       |   True   |   None  |     False     |   None  |
# | gridnum2169_1km_x  |     INTEGER      |   True   |   None  |     False     |   None  |
# | gridnum2169_1km_y  |     INTEGER      |   True   |   None  |     False     |   None  |
# |  gridnum2169_1km   |       TEXT       |   True   |   None  |     False     |   None  |
# | gridnum2169_10m_x  |     INTEGER      |   True   |   None  |     False     |   None  |
# | gridnum2169_10m_y  |     INTEGER      |   True   |   None  |     False     |   None  |
# |     wkt_string     |       TEXT       |   True   |   None  |     False     |   None  |
# |      geometry      |       NULL       |   True   |   None  |     False     |   None  |
# |     grid10mid      |     VARCHAR      |   True   |   None  |     False     |   None  |
# +--------------------+------------------+----------+---------+---------------+---------+

# %%
df = %sql SELECT gbif_key, species, sample_date, x_epsg2169, y_epsg2169, gridnum2169_100m_x, gridnum2169_10m FROM luxembourg_species.neophytes_geometry
#WHERE sample_date IS NOT NULL
df = df.DataFrame()
# df['sample_year'] = df['sample_date'].apply(lambda x: x.year)
# Out:
# Running query in 'fairicube'
# RuntimeError: (psycopg2.errors.UndefinedColumn) column "gridnum2169_10m" does not exist
# LINE 1: ...date, x_epsg2169, y_epsg2169, gridnum2169_100m_x, gridnum216...
#                                                              ^
# HINT:  Perhaps you meant to reference the column "neophytes_geometry.gridnum2169_100m" or the column "neophytes_geometry.gridnum2169_1km".
#
# [SQL: SELECT gbif_key, species, sample_date, x_epsg2169, y_epsg2169, gridnum2169_100m_x, gridnum2169_10m FROM luxembourg_species.neophytes_geometry]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# If you need help solving this issue, send us a message: https://ploomber.io/community

# %%
# query the cube - one point
ds.sel(x = 77432, y = 74940, method='nearest').to_dataframe()

# %%
# query data cube -- list of points
x_coords = xr.DataArray(df.x_epsg2169)
y_coords = xr.DataArray(df.y_epsg2169)
subset = ds.sel(band = 1, x = x_coords, y = y_coords, method='nearest').to_dataframe()

# %%
df.gridnum2169_100m_x
# Out:
# 0       78300
# 1       78300
# 2       77400
# 3       77400
# 4       78500
#         ...
# 2899    80900
# 2900    77600
# 2901    77600
# 2902    78900
# 2903    78900
# Name: gridnum2169_100m_x, Length: 2904, dtype: int64

# %%
subset.drop_duplicates(subset=['x', 'y'], inplace=True)
subset.drop(columns=['band', 'spatial_ref'], inplace=True)
subset
# Out:
#              x        y  admin_commune_2024_10m_b1  \
# dim_0
# 0      78315.0  73145.0                       61.0
# 2      77465.0  75985.0                       75.0
# 4      78515.0  75525.0                       35.0
# 6      74225.0  74305.0                       61.0
# 7      76775.0  74695.0                       61.0
# ...        ...      ...                        ...
# 2823   75995.0  74705.0                       61.0
# 2841   76995.0  79015.0                       35.0
# 2842   77995.0  78015.0                       35.0
# 2878   72855.0  72015.0                        0.0
# 2894   77995.0  73015.0                       61.0
#
#        admin_quartiers_2024_10m_b1  \
# dim_0
# 0                              4.0
# 2                             20.0
# 4                              7.0
# 6                             17.0
# 7                             14.0
# ...                            ...
# 2823                          14.0
# 2841                           1.0
# 2842                           8.0
# 2878                           0.0
# 2894                           4.0
#
#        cadaster_vdl_public_private_layer_2024_10m_b1  dem_2019_10m_b1  \
# dim_0
# 0                                                1.0            291.0
# 2                                                2.0            270.0
# 4                                                2.0            315.0
# 6                                                2.0            284.0
# 7                                                1.0            270.0
# ...                                              ...              ...
# 2823                                             1.0            286.0
# 2841                                             2.0            239.0
# 2842                                             2.0            268.0
# 2878                                             1.0            279.0
# 2894                                             1.0            286.0
#
#        dem_aspect_2019_10m_b1  dem_slope_2019_10m_b1  \
# dim_0
# 0                  296.565033               3.199601
# 2                  277.431396              30.108191
# 4                  293.962494              26.217613
# 6                  180.000000               5.710593
# 7                  123.690071              15.131807
# ...                       ...                    ...
# 2823               161.565048               2.263636
# 2841               360.000000               2.862405
# 2842               225.000000               9.039936
# 2878             -9999.000000               0.000000
# 2894               296.565033               3.199601
#
#        dem_surface_model_2019_10m_b1  flood_map_2021_10m_b1  \
# dim_0
# 0                         291.081451                    0.0
# 2                         266.053009                    0.0
# 4                         332.403015                    0.0
# 6                         287.870605                    0.0
# 7                         272.687592                    0.0
# ...                              ...                    ...
# 2823                      289.476410                    0.0
# 2841                      247.454849                    0.0
# 2842                      269.682648                    0.0
# 2878                      294.953613                    0.0
# 2894                      287.383301                    0.0
#
#        hrl_treecover_2018_10m_b1  land_cover_2018_2021_10m_b2  \
# dim_0
# 0                            0.0                        196.0
# 2                            0.0                         97.0
# 4                           66.0                          0.0
# 6                            0.0                         23.0
# 7                            0.0                          0.0
# ...                          ...                          ...
# 2823                         0.0                          0.0
# 2841                         0.0                        196.0
# 2842                         0.0                         82.0
# 2878                         0.0                          0.0
# 2894                         0.0                        189.0
#
#        land_use_07_15_18_21_10m_b4  protected_areas_v21_2023_10m_b1  \
# dim_0
# 0                              612                              0.0
# 2                              313                              0.0
# 4                              313                              0.0
# 6                              111                              0.0
# 7                              111                              0.0
# ...                            ...                              ...
# 2823                           133                              0.0
# 2841                           113                              0.0
# 2842                           160                              0.0
# 2878                             0                              0.0
# 2894                           612                              0.0
#
#        public_forests_2024_10m_b1  soil_map_100000_2024_10m_b1  \
# dim_0
# 0                            -1.0                         30.0
# 2                            -1.0                         30.0
# 4                            -1.0                         30.0
# 6                            -1.0                         30.0
# 7                            -1.0                         30.0
# ...                           ...                          ...
# 2823                         -1.0                         30.0
# 2841                         -1.0                         26.0
# 2842                         -1.0                         13.0
# 2878                         -1.0                          0.0
# 2894                         -1.0                         30.0
#
#        soil_map_25000_2024_10m_b1  traffic_intensity_2024_10m_b1
# dim_0
# 0                           143.0                       7.964112
# 2                           143.0                       0.000000
# 4                           208.0                       0.000000
# 6                           143.0                     227.683273
# 7                           143.0                       0.000000
# ...                           ...                            ...
# 2823                        143.0                       0.000000
# 2841                          8.0                       0.000000
# 2842                        143.0                       4.223669
# 2878                          2.0                   -9999.000000
# 2894                        143.0                     116.664062
#
# [1150 rows x 18 columns]

# %%
# compute gridnum 10m columns gridnum2169_10m_y and gridnum2169_10m_x
subset['gridnum2169_10m_x'] = subset.x//10*10
subset['gridnum2169_10m_y'] = subset.y//10*10
# rename table
datacube_extract = subset

# %%
# save to database
# %sql --persist datacube_extract --no-index
# Out:
# Running query in 'fairicube'
# Success! Persisted datacube_extract to the database.
