# %% [markdown]
# ## QC of Ingestion

# %%
# Configure plots for inline use in Jupyter Notebook
# %matplotlib inline

import datetime as dt

# Utilities
import boto3
import dateutil
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
import os
import rasterio
import rasterio.mask
from rasterio.plot import show_hist
from rasterio.plot import show
from rasterio.windows import Window
import random
import fiona
import numpy as np
from shapely.geometry import mapping, Polygon
from shapely import geometry
import logging    

# Sentinel Hub
from sentinelhub import (
    CRS,
    BBox,
    ByocCollection,
    ByocCollectionAdditionalData,
    ByocCollectionBand,
    ByocTile,
    DataCollection,
    DownloadFailedException,
    MimeType,
    SentinelHubBYOC,
    SentinelHubRequest,
    SHConfig,
    bbox_to_dimensions,
    os_utils,
)

config = SHConfig()
config.instance_id = os.environ.get("SH_INSTANCE_ID")
config.sh_client_id = os.environ.get("SH_CLIENT_ID")
config.sh_client_secret = os.environ.get("SH_CLIENT_SECRET")
config.aws_access_key_id = os.environ.get("username")
config.aws_secret_access_key = os.environ.get("password")
    
print ("done")
# Out:
# done

# %%
# Read raster files on S3 drive
#### CHECKING ENV ZONES:
#### https://github.com/FAIRiCUBE/uc1-urban-climate/blob/master/notebooks/dev/f01_ingestion/edc_ingestion/ingestion_08_env_zones.ipynb

#https://sentinelhub-py.readthedocs.io/en/latest/examples/byoc_request.html#Create-new-collection


##########################SET name and data folder: 
name_of_ingestion = "environmental_zones_1km"  ## should be the collection name!!!"
collection_id ='5b45916e-6704-4581-824f-4d713198731b'  # collection ID 
input_folder ="./../../../../s3/data/d005_env_zones/eea_r_3035_1_km_envzones_p_2018_v01_r00"   ## conect to tile folder on S3
###################################################




# assign directory
directory = input_folder
print (directory)
print ("following raster is selected for QC:")

##################################### QC log file set up:
#now we will Create and configure logger 
#https://www.geeksforgeeks.org/reading-writing-text-files-python/
qc_log = open("QC_"+name_of_ingestion+".txt","w")
qc_log.write("QC_"+name_of_ingestion+" \n")
qc_log.write("---------------------------------------------------------- \n")
#########################################################



###############################################################open collection:
# check ingestion status

# Initialize SentinelHubBYOC class
byoc = SentinelHubBYOC(config=config)

#good=' 5b45916e-6704-4581-824f-4d713198731b'
#############################################################
name_of_your_collection = name_of_ingestion

#############################################################
#collection = ByocCollection(name=name_of_your_collection, s3_bucket="hub-fairicube0")
#byoc.delete_collection(new_collection) # for the delte of the collection
#my_collection = byoc.get_collection(created_collection["id"])


collections_iterator = byoc.iter_collections(name_of_your_collection)

my_collection = list(collections_iterator)[0]



#print("Collection name:", my_collection["name"])
#print("Collection id: ", my_collection["id"])
tiles = list(byoc.iter_tiles(my_collection))

for tile in tiles:
    #print(tile)
    #print("Tile created: ", tile['path'])
    tile_name = tile['path'].split("/")
    tile_name_2=(tile_name[3])
    #print ( tile['path'])
    #print (tile_name_2)
    tile_name_3 = tile_name_2.split("(")
    tile_name_4= tile_name_3[0]+"B01.tif"
    #print (tile_name_4)

    
    ###########################################################################################################################START QC of every single tile:

    
    ## reading the raster files on s3:
    raster_list=[]
    # iterate over files in
    # that directory
    for filename in os.scandir(directory):                                 ####LOOP first over cube tiles - then over raster tiles  (1)
        if filename.is_file():
            #print(filename.path)
            raster_with_full_filename = filename
            raster_name_from_s3_1=filename.path.split("/")
            raster_name_from_s3_2=raster_name_from_s3_1[-1]
            
            #print (raster_name_from_s3_2)
            
            if tile_name_4 == raster_name_from_s3_2:                        ####LOOP first over cube tiles - then over raster tiles  (2)
                print("xxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
                
                ## PART 1 select randomly one raster: ----------------------------------    
                raster_for_qc = raster_with_full_filename  
                print('ooooooooooooooooooooooooooooooooooooo')
                print ( "RASTER for QC:")
                print(raster_for_qc)
                print ( "CUBE tile for QC:")
                print(tile['id'])
                      
                print('ooooooooooooooooooooooooooooooooooooo')
                

                ### PART 1 b read raster: ----------------------------------  

                ##raster_for_qc=test_raster############################################################################################# 
                raster = rasterio.open(raster_for_qc)
                qc_log.write("(1) CHECK 1 - spatial check for raster files:   \n")
                qc_log.write("----------------------------------------------   \n")

                ##https://rasterio.readthedocs.io/en/stable/quickstart.html
                #qc_log.write("Reading spatial information from s3 tiles   \n")
                
                
                raster_name = raster.name
                raster_bands = raster.count
                raster_width= raster.width
                raster_height= raster.height
                raster_bounds= raster.bounds
                
                qc_log.write( raster_name + "   \n ")
                #
                left = raster_bounds[0]
                bottom = raster_bounds[1]
                right = raster_bounds[2]
                top = raster_bounds[3]

                raster_transform =raster.transform
                pixelSizeX = raster_transform[0]
                pixelSizeY =-raster_transform[4]
                raster_crs =raster.crs

                #qc_log.write ("raster information:  \n")
                #qc_log.write (raster_name           + " \n")
                #qc_log.write ('================  \n')
                #qc_log.write (str(raster_bands)     + " \n")
#
                #qc_log.write (str(raster_bounds)    + " \n")
                #qc_log.write (str(raster_transform) + " \n")
#
                #qc_log.write (str(raster_crs)        +" \n")
                #qc_log.write ('-----------------  \n')
                #qc_log.write (str(left)+'  left  \n')
                #qc_log.write (str(bottom)+'  bottom  \n')
                #qc_log.write (str(right)+'  right  \n')
                #qc_log.write (str(top)+'  top  \n')
                #qc_log.write ('-----------------  \n')
                #
                raster_dtype = raster.dtypes[0]
                raster_nodata = raster.nodata
                #qc_log.write ("raster data type: " + str(raster_dtype)     + " \n")
                #qc_log.write ("raster nodata value: " + str(raster_nodata) + " \n")  
                #
                
               #with rasterio.open(raster_for_qc) as ds:   ### checking band statistics: transfer data to array:
               #    band_data=ds.read()
               #    r_min = band_data.min() 
               #    r_max = band_data.max() 
               #    r_mean = band_data.mean() 
                    
                with rasterio.open(raster_for_qc) as ds:
                    band_data = ds.read(1, window=Window(0, 0, 20, 20))  # pixel 2000/100 = 20
                    r_min_raster = band_data.min() 
                    r_max_raster = band_data.max() 
                    r_mean_raster = band_data.mean() 
                     

                    #test= array.np.median()
                # print ("band statistics:")
                # print (r_min)
                # print (r_max)
                # print (r_mean)
                #print (raster_with_full_filename)
            
                ##cube tiles_for_qc=test_raster#############################################################################################  START
                
                #print(tile)
                #qc_log.write ("-------------------------------------------------------  \n")
                #qc_log.write ("cube tile  information:  \n")
                #qc_log.write ("======================== \n")
                #cube_tile_properties = tile['coverGeometry']
                #print(cube_tile_properties)
                
                ### getting data statistics from small AOI inside the cube-tile:  
                #x1 =bottom_left_x
                #y1 =bottom_left_y
                x1 =left
                y1 =top
                
                
                #x1 =4014674
                #y1= 2933830
                x2 =x1 + 2000
                y2 =y1 - 2000
                resolution = 100
                bbox_coords = x1, y1, x2, y2
                print (bbox_coords)
                lux_bbox=  BBox(bbox=bbox_coords, crs=CRS('3035').pyproj_crs())
                
                
                
                lux_size = bbox_to_dimensions(lux_bbox, resolution=resolution)
                print(f"Image shape at {resolution} m resolution: {lux_size} pixels")
                data_collection_aoi = DataCollection.define_byoc(collection_id, name=name_of_ingestion)

                # simple evalscript to check if single request works
                evalscript_test = """

                //VERSION=3
                function setup() {
                  return {
                    input: ["B01"],
                    output: { 
                        bands: 1,
                        sampleType: "UINT16" // raster format will be UINT16
                        }

                  };
                }

                function evaluatePixel(sample) {
                  return [sample.B01];
                }
                """
                request = SentinelHubRequest(
                        evalscript=evalscript_test,
                        input_data=[
                            SentinelHubRequest.input_data(
                                data_collection=DataCollection.environmental_zones_1km,
                                # time_interval=("2018-01-01", "2019-01-01")
                                # time_interval="2018"
                            )
                        ],
                        responses=[
                            SentinelHubRequest.output_response('default', MimeType.PNG)
                        ],
                        bbox=lux_bbox,
                        size=bbox_to_dimensions(lux_bbox, 100),
                        config=config)

                data = request.get_data()[0]

                data_min_cube = np.min(data)
                data_max_cube = np.max(data)
                data_mean_cube= np.mean(data)
                #print (data_min_cube)
                #print (data_max_cube)
                #print (data_mean_cube)
                ##cube tiles_for_qc=test_raster#############################################################################################  END
                
                qc_log.write ("xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx\n")  
                print ("check 1.1:.....") ########################################################################################check 1.1 CRS
                EPSG_code = tile['coverGeometry'][ 'crs']['properties'][ 'name'].split(':')[-1]
                #qc_log.write ("ESPG: "+str(EPSG_code)           + " \n")
                #print ("---------")
                cube_epsg_str =  ("EPSG:"+str(EPSG_code))
                
                qc_log.write ("check 1.1 (CRS) -START \n")   
                qc_log.write ("-RASTER:  \n")
                qc_log.write ("  EPSG code: " +str(raster_crs) +' \n')    
                qc_log.write ("-CUBE_TILE:  \n")
                qc_log.write ("  EPSG code: " +str(cube_epsg_str) +' \n')            
                raster_epsg_str =  (str(raster_crs))
                #print ("---------")
                
                if cube_epsg_str == raster_epsg_str:
                    qc_log.write ("check 1.1 - EPSG (crs): OK   \n")
                else:
                    qc_log.write ("check 1.1 - EPSG (crs): NOT-OK  \n")
                    
                qc_log.write ("xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx\n")   
                print ("check 1.2:.....") ########################################################################################check 1.2 cell size
                qc_log.write ("check 1.2 (cellsize)-START  \n")  
                qc_log.write ("-RASTER:  \n")
                qc_log.write ("  Pixel size x: " +str(pixelSizeX) +' \n')
                qc_log.write ("  Pixel siez y: " +str(pixelSizeY) +' \n')
                              
                qc_log.write ("-CUBE_TILE:  \n")
                
                qc_log.write ("xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx\n")  
                print ("check 1.3:.....") ########################################################################################check 1.3 tile size extend:
                qc_log.write ("check 1.3 (extend-START \n")  
                qc_log.write ("-RASTER:  \n")
                qc_log.write ("  wiht: "+str(raster_width)     + " \n")
                qc_log.write ("  height: "+str(raster_height)    + " \n")
                qc_log.write ("-CUBE_TILE:  \n")
                
                
                #pixelSizeX = raster_transform[0]   ## raster
                #pixelSizeY =-raster_transform[4]    ###raster
                qc_log.write ("xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx\n")  
                print ("check 1.4:.....")             
                qc_log.write ("check 1.4 (data type & statistics)-START  \n")  
                #https://sentinelhub-py.readthedocs.io/en/latest/examples/byoc_request.html
                ##print ("NEXT file:.....")
                
                qc_log.write ("-RASTER:  \n")
                qc_log.write ("  raster data type: "    + str(raster_dtype)     + " \n")
                qc_log.write ("  raster nodata value: " + str(raster_nodata)    + " \n")  
                qc_log.write ("  max raster value: "  +str(r_max_raster) +' \n')
                qc_log.write ("  min raster value: " +str(r_min_raster) +' \n')
                qc_log.write ("  avg raster value: " +str(r_mean_raster) +' \n')
                qc_log.write ("-CUBE_TILE:  \n")
                qc_log.write ("  max cube value: "  +str(data_max_cube) +' \n')
                qc_log.write ("  min cube value: " +str(data_min_cube) +' \n')
                qc_log.write ("  avg cube  value: " +str(data_mean_cube) +' \n')
                
                
                if str(r_max_raster) == str(data_max_cube)  and str(r_min_raster) == str(data_min_cube) :                     
                    qc_log.write ("check 1.4 - data : OK   \n")
                else:
                    qc_log.write ("check 1.4 - data :  NOT-OK  \n")
                                  
                                  
                qc_log.write ("xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx\n")  
                print ("check 1.5:.....")  
                qc_log.write ("check 1.5 (extend -START \n")  
                qc_log.write ("-RASTER:  \n")
                qc_log.write ("  left: "+str(left)+'        \n')
                qc_log.write ("  bottom: " +str(bottom)+'    \n')
                qc_log.write ("  right: "+str(right)+'       \n')
                qc_log.write ("  top: " +str(top)+'            \n')
                qc_log.write ("-CUBE_TILE:  \n")
                
                #print (t['tileGeometry'] ['coordinates']  )
                bbox = tile['tileGeometry'] ['coordinates']

                ## top left
                #print ("top left:")
                top_left_x = bbox[0][0][0] 
                #print (top_left_x)
                top_left_y = bbox[0][0][1] 
                #print (top_left_y)

                ## rop  right
                #print ("top right:")
                top_right_x = bbox[0][1][0] 
                #print (top_right_x)
                top_right_y = bbox[0][1][1] 
                #print (top_right_y)


                ## bottom  right
                #print ("bottom right:")
                bottom_right_x = bbox[0][2][0] 
                #print (bottom_right_x)
                bottom_right_y = bbox[0][2][1] 
                #print (bottom_right_y)

                ## bottom left 
                #print ("bottom left:")
                bottom_left_x = bbox[0][3][0] 
                #print (bottom_left_x)
                bottom_left_y = bbox[0][3][1] 
                #print (bottom_left_y)
                
                qc_log.write ("  left: "   +str(bottom_left_x)+'         \n')
                qc_log.write ("  bottom: " +str(bottom_left_y)+'         \n')
                qc_log.write ("  right: "  +str(top_right_x)  +'         \n')
                qc_log.write ("  top: "    +str(top_right_y)  +'         \n')
                
                if str(bottom_left_x) == str(left)  and str(bottom_left_y) == str(bottom) and str(top_right_x) == str(right)    and str(top_right_y) == str(top):                     
                    qc_log.write ("check 1.5 - extend : OK   \n")
                else:
                    qc_log.write ("check 1.5 - extend :  NOT-OK  \n")
                
#print("2-------------------")

###############################################################open collection:

qc_log.close()
print ("end")
# Out:
# ./../../../../s3/data/d005_env_zones/eea_r_3035_1_km_envzones_p_2018_v01_r00
# following raster is selected for QC:
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ooooooooooooooooooooooooooooooooooooo
# RASTER for QC:
# <DirEntry 'env_zones_1km_3035_2_6_B01.tif'>
# CUBE tile for QC:
# 00cec537-6717-4e3b-89ad-7bd3240af390
# ooooooooooooooooooooooooooooooooooooo
# (5900000.0, 4500000.0, 5902000.0, 4498000.0)
# Image shape at 100 m resolution: (27, 10) pixels
# check 1.1:.....
# check 1.2:.....
# check 1.3:.....
# check 1.4:.....
# check 1.5:.....
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ooooooooooooooooooooooooooooooooooooo
# RASTER for QC:
# <DirEntry 'env_zones_1km_3035_3_3_B01.tif'>
# CUBE tile for QC:
# 022c35df-0e5e-45ba-a013-06008c324cd5
# ooooooooooooooooooooooooooooooooooooo
# (2900000.0, 3500000.0, 2902000.0, 3498000.0)
# Image shape at 100 m resolution: (14, 24) pixels
# check 1.1:.....
# check 1.2:.....
# check 1.3:.....
# check 1.4:.....
# check 1.5:.....
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ooooooooooooooooooooooooooooooooooooo
# RASTER for QC:
# <DirEntry 'env_zones_1km_3035_5_7_B01.tif'>
# CUBE tile for QC:
# 041464c0-566e-4860-96a6-cdee15d53e6c
# ooooooooooooooooooooooooooooooooooooo
# (6900000.0, 1500000.0, 6902000.0, 1498000.0)
# Image shape at 100 m resolution: (25, 11) pixels
# check 1.1:.....
# check 1.2:.....
# check 1.3:.....
# check 1.4:.....
# check 1.5:.....
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ooooooooooooooooooooooooooooooooooooo
# RASTER for QC:
# <DirEntry 'env_zones_1km_3035_1_3_B01.tif'>
# CUBE tile for QC:
# 051d2ad0-26f4-46a1-8549-79e3e86f56d0
# ooooooooooooooooooooooooooooooooooooo
# (2900000.0, 5500000.0, 2902000.0, 5498000.0)
# Image shape at 100 m resolution: (6, 27) pixels
# check 1.1:.....
# check 1.2:.....
# check 1.3:.....
# check 1.4:.....
# check 1.5:.....
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ooooooooooooooooooooooooooooooooooooo
# RASTER for QC:
# <DirEntry 'env_zones_1km_3035_2_4_B01.tif'>
# CUBE tile for QC:
# 0f43f608-0952-4982-8c47-a22bb8e71f55
# ooooooooooooooooooooooooooooooooooooo
# (3900000.0, 4500000.0, 3902000.0, 4498000.0)
# Image shape at 100 m resolution: (18, 22) pixels
# check 1.1:.....
# check 1.2:.....
# check 1.3:.....
# check 1.4:.....
# check 1.5:.....
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ooooooooooooooooooooooooooooooooooooo
# RASTER for QC:
# <DirEntry 'env_zones_1km_3035_2_3_B01.tif'>
# CUBE tile for QC:
# 102e23da-404b-4539-817c-75de2a039b86
# ooooooooooooooooooooooooooooooooooooo
# (2900000.0, 4500000.0, 2902000.0, 4498000.0)
# Image shape at 100 m resolution: (11, 26) pixels
# check 1.1:.....
# check 1.2:.....
# check 1.3:.....
# check 1.4:.....
# check 1.5:.....
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ooooooooooooooooooooooooooooooooooooo
# RASTER for QC:
# <DirEntry 'env_zones_1km_3035_5_3_B01.tif'>
# CUBE tile for QC:
# 28ba65f4-689a-4554-9295-53fbeac94042
# ooooooooooooooooooooooooooooooooooooo
# (2900000.0, 1500000.0, 2902000.0, 1498000.0)
# Image shape at 100 m resolution: (17, 23) pixels
# check 1.1:.....
# check 1.2:.....
# check 1.3:.....
# check 1.4:.....
# check 1.5:.....
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ooooooooooooooooooooooooooooooooooooo
# RASTER for QC:
# <DirEntry 'env_zones_1km_3035_4_7_B01.tif'>
# CUBE tile for QC:
# 28d462fa-5ffb-4d35-8285-ea5c9f668c77
# ooooooooooooooooooooooooooooooooooooo
# (6900000.0, 2500000.0, 6902000.0, 2498000.0)
# Image shape at 100 m resolution: (26, 11) pixels
# check 1.1:.....
# check 1.2:.....
# check 1.3:.....
# check 1.4:.....
# check 1.5:.....
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ooooooooooooooooooooooooooooooooooooo
# RASTER for QC:
# <DirEntry 'env_zones_1km_3035_3_2_B01.tif'>
# CUBE tile for QC:
# 29286bb4-a1ac-476c-8355-84c75605bd4f
# ooooooooooooooooooooooooooooooooooooo
# (1900000.0, 3500000.0, 1902000.0, 3498000.0)
# Image shape at 100 m resolution: (8, 27) pixels
# check 1.1:.....
# check 1.2:.....
# check 1.3:.....
# check 1.4:.....
# check 1.5:.....
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ooooooooooooooooooooooooooooooooooooo
# RASTER for QC:
# <DirEntry 'env_zones_1km_3035_3_4_B01.tif'>
# CUBE tile for QC:
# 321c8496-7da5-4128-abfb-e810188ca4f4
# ooooooooooooooooooooooooooooooooooooo
# (3900000.0, 3500000.0, 3902000.0, 3498000.0)
# Image shape at 100 m resolution: (18, 22) pixels
# check 1.1:.....
# check 1.2:.....
# check 1.3:.....
# check 1.4:.....
# check 1.5:.....
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ooooooooooooooooooooooooooooooooooooo
# RASTER for QC:
# <DirEntry 'env_zones_1km_3035_5_1_B01.tif'>
# CUBE tile for QC:
# 3c44f8e2-3e28-4b54-8abd-88df27aae9e6
# ooooooooooooooooooooooooooooooooooooo
# (900000.0, 1500000.0, 902000.0, 1498000.0)
# Image shape at 100 m resolution: (11, 27) pixels
# check 1.1:.....
# check 1.2:.....
# check 1.3:.....
# check 1.4:.....
# check 1.5:.....
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ooooooooooooooooooooooooooooooooooooo
# RASTER for QC:
# <DirEntry 'env_zones_1km_3035_5_6_B01.tif'>
# CUBE tile for QC:
# 4d67b303-a3d6-48b5-b5c1-1516847fc3a6
# ooooooooooooooooooooooooooooooooooooo
# (5900000.0, 1500000.0, 5902000.0, 1498000.0)
# Image shape at 100 m resolution: (23, 15) pixels
# check 1.1:.....
# check 1.2:.....
# check 1.3:.....
# check 1.4:.....
# check 1.5:.....
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ooooooooooooooooooooooooooooooooooooo
# RASTER for QC:
# <DirEntry 'env_zones_1km_3035_1_5_B01.tif'>
# CUBE tile for QC:
# 4dcdd25b-ed1c-4bab-8e69-1c01e54605f2
# ooooooooooooooooooooooooooooooooooooo
# (4900000.0, 5500000.0, 4902000.0, 5498000.0)
# Image shape at 100 m resolution: (25, 15) pixels
# check 1.1:.....
# check 1.2:.....
# check 1.3:.....
# check 1.4:.....
# check 1.5:.....
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ooooooooooooooooooooooooooooooooooooo
# RASTER for QC:
# <DirEntry 'env_zones_1km_3035_3_6_B01.tif'>
# CUBE tile for QC:
# 53c916e6-bf8a-468f-8afb-0ff454c78fe3
# ooooooooooooooooooooooooooooooooooooo
# (5900000.0, 3500000.0, 5902000.0, 3498000.0)
# Image shape at 100 m resolution: (25, 13) pixels
# check 1.1:.....
# check 1.2:.....
# check 1.3:.....
# check 1.4:.....
# check 1.5:.....
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ooooooooooooooooooooooooooooooooooooo
# RASTER for QC:
# <DirEntry 'env_zones_1km_3035_2_1_B01.tif'>
# CUBE tile for QC:
# 5419a528-83f3-45f7-a131-46d28026d744
# ooooooooooooooooooooooooooooooooooooo
# (900000.0, 4500000.0, 902000.0, 4498000.0)
# Image shape at 100 m resolution: (1, 27) pixels
# check 1.1:.....
# check 1.2:.....
# check 1.3:.....
# check 1.4:.....
# check 1.5:.....
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ooooooooooooooooooooooooooooooooooooo
# RASTER for QC:
# <DirEntry 'env_zones_1km_3035_4_3_B01.tif'>
# CUBE tile for QC:
# 5546830a-f3f6-4f64-b019-b293376ea24f
# ooooooooooooooooooooooooooooooooooooo
# (2900000.0, 2500000.0, 2902000.0, 2498000.0)
# Image shape at 100 m resolution: (15, 24) pixels
# check 1.1:.....
# check 1.2:.....
# check 1.3:.....
# check 1.4:.....
# check 1.5:.....
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ooooooooooooooooooooooooooooooooooooo
# RASTER for QC:
# <DirEntry 'env_zones_1km_3035_3_1_B01.tif'>
# CUBE tile for QC:
# 66f8669f-ad7f-4276-813a-83a348129c65
# ooooooooooooooooooooooooooooooooooooo
# (900000.0, 3500000.0, 902000.0, 3498000.0)
# Image shape at 100 m resolution: (5, 28) pixels
# check 1.1:.....
# check 1.2:.....
# check 1.3:.....
# check 1.4:.....
# check 1.5:.....
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ooooooooooooooooooooooooooooooooooooo
# RASTER for QC:
# <DirEntry 'env_zones_1km_3035_3_5_B01.tif'>
# CUBE tile for QC:
# 68eee2bf-1467-456c-b6c7-8158c460b406
# ooooooooooooooooooooooooooooooooooooo
# (4900000.0, 3500000.0, 4902000.0, 3498000.0)
# Image shape at 100 m resolution: (23, 17) pixels
# check 1.1:.....
# check 1.2:.....
# check 1.3:.....
# check 1.4:.....
# check 1.5:.....
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ooooooooooooooooooooooooooooooooooooo
# RASTER for QC:
# <DirEntry 'env_zones_1km_3035_5_4_B01.tif'>
# CUBE tile for QC:
# 6f114691-a381-4bb9-85b3-e4fa2655ebea
# ooooooooooooooooooooooooooooooooooooo
# (3900000.0, 1500000.0, 3902000.0, 1498000.0)
# Image shape at 100 m resolution: (18, 22) pixels
# check 1.1:.....
# check 1.2:.....
# check 1.3:.....
# check 1.4:.....
# check 1.5:.....
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ooooooooooooooooooooooooooooooooooooo
# RASTER for QC:
# <DirEntry 'env_zones_1km_3035_1_7_B01.tif'>
# CUBE tile for QC:
# 8c8ead2e-35a2-4a4b-b431-eb7df46730a2
# ooooooooooooooooooooooooooooooooooooo
# (6900000.0, 5500000.0, 6902000.0, 5498000.0)
# Image shape at 100 m resolution: (29, 3) pixels
# check 1.1:.....
# check 1.2:.....
# check 1.3:.....
# check 1.4:.....
# check 1.5:.....
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ooooooooooooooooooooooooooooooooooooo
# RASTER for QC:
# <DirEntry 'env_zones_1km_3035_4_1_B01.tif'>
# CUBE tile for QC:
# 91254e03-9cfe-4af5-b766-4ce0ae67f1e6
# ooooooooooooooooooooooooooooooooooooo
# (900000.0, 2500000.0, 902000.0, 2498000.0)
# Image shape at 100 m resolution: (8, 28) pixels
# check 1.1:.....
# check 1.2:.....
# check 1.3:.....
# check 1.4:.....
# check 1.5:.....
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ooooooooooooooooooooooooooooooooooooo
# RASTER for QC:
# <DirEntry 'env_zones_1km_3035_1_6_B01.tif'>
# CUBE tile for QC:
# 91d1a813-696d-4578-9ed9-6dc61c0b5a94
# ooooooooooooooooooooooooooooooooooooo
# (5900000.0, 5500000.0, 5902000.0, 5498000.0)
# Image shape at 100 m resolution: (29, 5) pixels
# check 1.1:.....
# check 1.2:.....
# check 1.3:.....
# check 1.4:.....
# check 1.5:.....
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ooooooooooooooooooooooooooooooooooooo
# RASTER for QC:
# <DirEntry 'env_zones_1km_3035_4_5_B01.tif'>
# CUBE tile for QC:
# ab312cb8-451e-4819-8b8e-b9eda4a798b7
# ooooooooooooooooooooooooooooooooooooo
# (4900000.0, 2500000.0, 4902000.0, 2498000.0)
# Image shape at 100 m resolution: (21, 19) pixels
# check 1.1:.....
# check 1.2:.....
# check 1.3:.....
# check 1.4:.....
# check 1.5:.....
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ooooooooooooooooooooooooooooooooooooo
# RASTER for QC:
# <DirEntry 'env_zones_1km_3035_2_2_B01.tif'>
# CUBE tile for QC:
# b1a1bb65-f45b-45f7-87a4-408ab3c82cc0
# ooooooooooooooooooooooooooooooooooooo
# (1900000.0, 4500000.0, 1902000.0, 4498000.0)
# Image shape at 100 m resolution: (5, 27) pixels
# check 1.1:.....
# check 1.2:.....
# check 1.3:.....
# check 1.4:.....
# check 1.5:.....
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ooooooooooooooooooooooooooooooooooooo
# RASTER for QC:
# <DirEntry 'env_zones_1km_3035_4_4_B01.tif'>
# CUBE tile for QC:
# b56cebf4-80a3-4cfe-b39b-9fa7b8807fab
# ooooooooooooooooooooooooooooooooooooo
# (3900000.0, 2500000.0, 3902000.0, 2498000.0)
# Image shape at 100 m resolution: (18, 22) pixels
# check 1.1:.....
# check 1.2:.....
# check 1.3:.....
# check 1.4:.....
# check 1.5:.....
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ooooooooooooooooooooooooooooooooooooo
# RASTER for QC:
# <DirEntry 'env_zones_1km_3035_4_2_B01.tif'>
# CUBE tile for QC:
# b652967d-de78-437f-8154-9beb8fbba372
# ooooooooooooooooooooooooooooooooooooo
# (1900000.0, 2500000.0, 1902000.0, 2498000.0)
# Image shape at 100 m resolution: (11, 26) pixels
# check 1.1:.....
# check 1.2:.....
# check 1.3:.....
# check 1.4:.....
# check 1.5:.....
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ooooooooooooooooooooooooooooooooooooo
# RASTER for QC:
# <DirEntry 'env_zones_1km_3035_2_5_B01.tif'>
# CUBE tile for QC:
# b96a98c6-e6e1-4f7f-a8f2-097cbead69df
# ooooooooooooooooooooooooooooooooooooo
# (4900000.0, 4500000.0, 4902000.0, 4498000.0)
# Image shape at 100 m resolution: (23, 17) pixels
# check 1.1:.....
# check 1.2:.....
# check 1.3:.....
# check 1.4:.....
# check 1.5:.....
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ooooooooooooooooooooooooooooooooooooo
# RASTER for QC:
# <DirEntry 'env_zones_1km_3035_2_7_B01.tif'>
# CUBE tile for QC:
# bfc0f26e-d2a9-4ab0-8c5e-e67cde697f2d
# ooooooooooooooooooooooooooooooooooooo
# (6900000.0, 4500000.0, 6902000.0, 4498000.0)
# Image shape at 100 m resolution: (29, 3) pixels
# check 1.1:.....
# check 1.2:.....
# check 1.3:.....
# check 1.4:.....
# check 1.5:.....
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ooooooooooooooooooooooooooooooooooooo
# RASTER for QC:
# <DirEntry 'env_zones_1km_3035_4_6_B01.tif'>
# CUBE tile for QC:
# c9487ecc-5137-4854-9e83-e8e4904ff5cb
# ooooooooooooooooooooooooooooooooooooo
# (5900000.0, 2500000.0, 5902000.0, 2498000.0)
# Image shape at 100 m resolution: (24, 15) pixels
# check 1.1:.....
# check 1.2:.....
# check 1.3:.....
# check 1.4:.....
# check 1.5:.....
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ooooooooooooooooooooooooooooooooooooo
# RASTER for QC:
# <DirEntry 'env_zones_1km_3035_1_4_B01.tif'>
# CUBE tile for QC:
# cb5e3611-6566-40a9-a7f1-7f8710e40dd5
# ooooooooooooooooooooooooooooooooooooo
# (3900000.0, 5500000.0, 3902000.0, 5498000.0)
# Image shape at 100 m resolution: (15, 24) pixels
# check 1.1:.....
# check 1.2:.....
# check 1.3:.....
# check 1.4:.....
# check 1.5:.....
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ooooooooooooooooooooooooooooooooooooo
# RASTER for QC:
# <DirEntry 'env_zones_1km_3035_5_2_B01.tif'>
# CUBE tile for QC:
# cebcef00-89b8-45d3-93ff-117afab96c03
# ooooooooooooooooooooooooooooooooooooo
# (1900000.0, 1500000.0, 1902000.0, 1498000.0)
# Image shape at 100 m resolution: (14, 26) pixels
# check 1.1:.....
# check 1.2:.....
# check 1.3:.....
# check 1.4:.....
# check 1.5:.....
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ooooooooooooooooooooooooooooooooooooo
# RASTER for QC:
# <DirEntry 'env_zones_1km_3035_5_5_B01.tif'>
# CUBE tile for QC:
# e0fad0e0-a9f6-470e-b6bd-0f05f32bd1b1
# ooooooooooooooooooooooooooooooooooooo
# (4900000.0, 1500000.0, 4902000.0, 1498000.0)
# Image shape at 100 m resolution: (21, 19) pixels
# check 1.1:.....
# check 1.2:.....
# check 1.3:.....
# check 1.4:.....
# check 1.5:.....
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ooooooooooooooooooooooooooooooooooooo
# RASTER for QC:
# <DirEntry 'env_zones_1km_3035_3_7_B01.tif'>
# CUBE tile for QC:
# e589aa4d-2871-4147-b3f3-9624f5914063
# ooooooooooooooooooooooooooooooooooooo
# (6900000.0, 3500000.0, 6902000.0, 3498000.0)
# Image shape at 100 m resolution: (27, 8) pixels
# check 1.1:.....
# check 1.2:.....
# check 1.3:.....
# check 1.4:.....
# check 1.5:.....
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ooooooooooooooooooooooooooooooooooooo
# RASTER for QC:
# <DirEntry 'env_zones_1km_3035_1_2_B01.tif'>
# CUBE tile for QC:
# f1e73eff-3433-4817-907e-8a32a5f2be0d
# ooooooooooooooooooooooooooooooooooooo
# (1900000.0, 5500000.0, 1902000.0, 5498000.0)
# Image shape at 100 m resolution: (1, 27) pixels
# check 1.1:.....
# check 1.2:.....
# check 1.3:.....
# check 1.4:.....
# check 1.5:.....
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ooooooooooooooooooooooooooooooooooooo
# RASTER for QC:
# <DirEntry 'env_zones_1km_3035_1_1_B01.tif'>
# CUBE tile for QC:
# f40821f5-bacb-4bc6-8d98-358035a04e11
# ooooooooooooooooooooooooooooooooooooo
# (900000.0, 5500000.0, 902000.0, 5498000.0)
# Image shape at 100 m resolution: (5, 26) pixels
# check 1.1:.....
# check 1.2:.....
# check 1.3:.....
# check 1.4:.....
# check 1.5:.....
# end

# %%
print ("raster info:")

from rasterio.windows import Window
input_folder ="./../../../../s3/data/d005_env_zones/eea_r_3035_1_km_envzones_p_2018_v01_r00"  


raster_with_full_filename = input_folder+"/env_zones_1km_3035_2_5_B01.tif"


raster_dtype = raster.dtypes[0]
raster_nodata = raster.nodata
print (raster_dtype)
print (raster_nodata)


with rasterio.open(raster_with_full_filename) as ds:
    wband_data = ds.read(1, window=Window(0, 0, 20, 20))  # pixel 2000/100 = 20
    
    band_data=ds.read()
    r_min = band_data.min() 
    r_max = band_data.max() 
    r_mean = band_data.mean() 
    r_mean2 = wband_data.mean() 
    
    #test= array.np.median()
print ("badnd statistics:")
print (r_min)
print (r_max)
print (r_mean)
print (r_mean2)
#print (raster_with_full_filename)
# Out:
# raster info:
# uint8
# 0.0
# badnd statistics:
# 0
# 6
# 1.00431891
# 2.0

# %%
from src import utils
utils.list_byoc_collections(list_tiles=False)
# Out:
# Collection name: TreeCoverDensity2018_10m_raster
# Collection id:  3947b646-383c-4e91-aade-2f039bd6ba4b
# -------------------
# Collection name: UrbanAtlas2012_10m_raster
# Collection id:  47ea75a0-875f-4ee9-ae78-b02be89d43d7
# -------------------
# Collection name: environmental_zones_1km
# Collection id:  5b45916e-6704-4581-824f-4d713198731b
# -------------------
# Collection name: UrbanAtlas2018_10m_raster
# Collection id:  78545a11-1e57-4ed0-a3ce-68c2e305216b
# -------------------
# Collection name: urban_audit_2021_city
# Collection id:  7b4d761f-893b-43be-a4d6-4f37375318d3
# -------------------
# Collection name: urban_audit_2021_fua
# Collection id:  c12e7be5-9f5e-441c-930f-2f274218e6d3
# -------------------
# Collection name: ImperviousnessDensity2018_10m_raster
# Collection id:  c57f7668-2717-4529-93cc-5372bc96ebbe
# -------------------
# Collection name: nuts3_2021
# Collection id:  d0a3f8c5-bf65-4bf2-9a3d-37a1d7101874
# -------------------
# Collection name: Halle_UA_height
# Collection id:  dfad0a7e-9d3a-46e2-9fb6-7940f85b8929
# -------------------
# Collection name: urban_audit_2021_city
# Collection id:  f14a4561-3d47-4a7b-914b-420c5c78bd1e
# -------------------

# %%
### testing cube
import json
print (tile)

for t in tiles:
        if t['id'] == '00cec537-6717-4e3b-89ad-7bd3240af390':
            print (t['id'])
            #print (t['properties'])
            for item in t:
                print (item)
            
            print (t['tileGeometry'] ['coordinates']  )
            bbox = t['tileGeometry'] ['coordinates']
            
            ## top left
            print ("top left:")
            top_left_x = bbox[0][0][0] 
            print (top_left_x)
            top_left_y = bbox[0][0][1] 
            print (top_left_y)
            
            ## rop  right
            print ("top right:")
            top_right_x = bbox[0][1][0] 
            print (top_right_x)
            top_right_y = bbox[0][1][1] 
            print (top_right_y)
 

            ## bottom  right
            print ("bottom right:")
            bottom_right_x = bbox[0][2][0] 
            print (bottom_right_x)
            bottom_right_y = bbox[0][2][1] 
            print (bottom_right_y)
            
            ## bottom left 
            print ("bottom left:")
            bottom_left_x = bbox[0][3][0] 
            print (bottom_left_x)
            bottom_left_y = bbox[0][3][1] 
            print (bottom_left_y)
            

            
    
#extend = tile['coverGeometry'][ 'crs']['properties'][ 'name'].split(':')[-1]


#bbox = tile['coordinates']

#print = (bbox)
# Out:
# {'id': 'f40821f5-bacb-4bc6-8d98-358035a04e11', 'created': '2023-12-12T14:21:31.760197Z', 'ingestionStart': '2023-12-12T14:21:31.760197Z', 'sensingTime': '2018-01-01T00:00:00Z', 'coverGeometry': {'type': 'Polygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}}, 'coordinates': [[[899999.9997812272, 4499999.999760259], [1899999.9998805118, 4499999.999828045], [1899999.9998928742, 5499999.999900502], [899999.9998236685, 5499999.99987142], [899999.9997812272, 4499999.999760259]]]}, 'tileGeometry': {'type': 'Polygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}}, 'coordinates': [[[900000.0, 5500000.0], [1900000.0, 5500000.0], [1900000.0, 4500000.0], [900000.0, 4500000.0], [900000.0, 5500000.0]]]}, 'path': 'data/d005_env_zones/eea_r_3035_1_km_envzones_p_2018_v01_r00/env_zones_1km_3035_1_1_(BAND).tif', 'status': 'INGESTED', 'additionalData': {'hasAddedPoints': True, 'filesMetadata': {'B01': {'headerSize': 2436, 'etag': '"90acd49a663f61bad94d2b0f750abd93"'}}, 'minMetersPerPixel': 100.0, 'maxMetersPerPixel': 1600.0}}
# 00cec537-6717-4e3b-89ad-7bd3240af390
# id
# created
# ingestionStart
# sensingTime
# coverGeometry
# tileGeometry
# path
# status
# additionalData
# [[[5900000.0, 4500000.0], [6900000.0, 4500000.0], [6900000.0, 3500000.0], [5900000.0, 3500000.0], [5900000.0, 4500000.0]]]
# top left:
# 5900000.0
# 4500000.0
# top right:
# 6900000.0
# 4500000.0
# bottom right:
# 6900000.0
# 3500000.0
# bottom left:
# 5900000.0
# 3500000.0

# %%
##checking tile: max min from CUBE-til3e
import IPython.display
#print(tile)
import shapely.geometry

# x1 = 6  # degree
# y1 = 49  # degree
# x2 = 6.9 # degree
# y2 = 49.9  # degree

# bbox_lux = x1, y1, x2, y2



x1 =bottom_left_x
y1 =bottom_left_y


x1 =4014674
y1= 2933830
x2 =x1 + 2000
y2 =y1 + 2000


resolution = 100
# lux_bbox = BBox(bbox=bbox_lux, crs=CRS.WGS84)#
bbox_coords = x1, y1, x2, y2
print (bbox_coords)
lux_bbox=  BBox(bbox=bbox_coords, crs=CRS('3035').pyproj_crs())
lux_size = bbox_to_dimensions(lux_bbox, resolution=resolution)
print(f"Image shape at {resolution} m resolution: {lux_size} pixels")

IPython.display.GeoJSON(shapely.geometry.box(*bbox_lux).__geo_interface__)

#print (tile)

#collection_id= tile['id']

name_of_ingestion = "environmental_zones_1km"
collection_id ='5b45916e-6704-4581-824f-4d713198731b'
#collections_iterator = byoc.iter_collections(name_of_your_collection)
data_collection_aoi = DataCollection.define_byoc(collection_id, name=name_of_ingestion)

# simple evalscript to check if single request works
evalscript_test = """

//VERSION=3
function setup() {
  return {
    input: ["B01"],
    output: { 
        bands: 1,
        sampleType: "UINT16" // raster format will be UINT16
        }
    
  };
}

function evaluatePixel(sample) {
  return [sample.B01];
}
"""
request = SentinelHubRequest(
        evalscript=evalscript_test,
        input_data=[
            SentinelHubRequest.input_data(
                data_collection=DataCollection.environmental_zones_1km,
                # time_interval=("2018-01-01", "2019-01-01")
                # time_interval="2018"
            )
        ],
        responses=[
            SentinelHubRequest.output_response('default', MimeType.PNG)
        ],
        bbox=lux_bbox,
        size=bbox_to_dimensions(lux_bbox, 100),
        config=config)
    
data = request.get_data()[0]

data_min = np.min(data)
data_max = np.max(data)
data_mean = np.mean(data)
print (data_min)
print (data_max)
print (data_mean)
# Out:
# (4014674, 2933830, 4016674, 2935830)
# Image shape at 100 m resolution: (18, 22) pixels
# 6
# 7
# 6.492424242424242

# %%
data_mean
# Out:
# 6.492424242424242

# %%
from rasterio.windows import Window

with rasterio.open('tests/data/RGB.byte.tif') as src:
    w = src.read(1, window=Window(0, 0, 512, 256))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 3
#       1 from rasterio.windows import Window
# ----> 3 Window(col_off, row_off, width, height)
#
# NameError: name 'col_off' is not defined

# %%
# Read raster files on S3 drive
#### CHECKING ENV ZONES:
#### https://github.com/FAIRiCUBE/uc1-urban-climate/blob/master/notebooks/dev/f01_ingestion/edc_ingestion/ingestion_08_env_zones.ipynb

#https://sentinelhub-py.readthedocs.io/en/latest/examples/byoc_request.html#Create-new-collection


##########################SET name and data folder: 
name_of_ingestion = "environmental_zones_1km"  ## should be the collection name!!!"

input_folder ="./../../../../s3/data/d005_env_zones/eea_r_3035_1_km_envzones_p_2018_v01_r00"   ## conect to tile folder on S3
###################################################




# assign directory
directory = input_folder
print (directory)
print ("following raster is selected for QC:")

##################################### QC log file set up:
#now we will Create and configure logger 
#https://www.geeksforgeeks.org/reading-writing-text-files-python/
qc_log = open("QC_"+name_of_ingestion+".txt","w")
qc_log.write("QC_"+name_of_ingestion+" \n")
qc_log.write("---------------------------------------------------------- \n")
#########################################################

raster_list=[]
# iterate over files in
# that directory
for filename in os.scandir(directory):
    if filename.is_file():
        #print(filename.path)
        #print 
        raster_list.append(filename.path)
             
        
## PART 1 select randomly one raster: ----------------------------------    
raster_for_qc = raster_list[0]  # Select first raster of the raster-list
#raster_for_qc = random.choice(raster_list)   # select one file radmonly 
print(raster_for_qc)

## PART 1 b read raster: ----------------------------------  

#raster_for_qc=test_raster############################################################################################# for testing
raster = rasterio.open(raster_for_qc)


qc_log.write("(1) CHECK 1 - (spatial check for raster files:   \n")
qc_log.write("----------------------------------------------   \n")

#https://rasterio.readthedocs.io/en/stable/quickstart.html
qc_log.write("Reading spatial information from s3 tiles   \n")
qc_log.write(raster_for_qc+"   \n")
raster_name = raster.name
raster_bands = raster.count
raster_width= raster.width
raster_height= raster.height
raster_bounds= raster.bounds
#
left = raster_bounds[0]
bottom = raster_bounds[1]
right = raster_bounds[2]
top = raster_bounds[3]

raster_transform =raster.transform
pixelSizeX = raster_transform[0]
pixelSizeY =-raster_transform[4]
raster_crs =raster.crs

qc_log.write ("raster information:  \n")
qc_log.write (raster_name           + " \n")
qc_log.write ('================  \n')
qc_log.write (str(raster_bands)     + " \n")
qc_log.write (str(raster_width)     + " \n")
qc_log.write (str(raster_height)    + " \n")
qc_log.write (str(raster_bounds)    + " \n")
qc_log.write (str(raster_transform) + " \n")
qc_log.write ('-----------------  \n')
qc_log.write (str(pixelSizeX) +' pixel size x  \n')
qc_log.write (str(pixelSizeY) +' pixel size y  \n')
qc_log.write (str(raster_crs)        +" \n")
qc_log.write ('-----------------  \n')
qc_log.write (str(left)+'  left  \n')
qc_log.write (str(bottom)+'  bottom  \n')
qc_log.write (str(right)+'  right  \n')
qc_log.write (str(top)+'  top  \n')



###############################################################open collection:
# check ingestion status

# Initialize SentinelHubBYOC class
byoc = SentinelHubBYOC(config=config)

#good=' 5b45916e-6704-4581-824f-4d713198731b'
#############################################################
name_of_your_collection = name_of_ingestion

#############################################################
#collection = ByocCollection(name=name_of_your_collection, s3_bucket="hub-fairicube0")
#byoc.delete_collection(new_collection) # for the delte of the collection
#my_collection = byoc.get_collection(created_collection["id"])


collections_iterator = byoc.iter_collections(name_of_your_collection)

my_collection = list(collections_iterator)[0]



#print("Collection name:", my_collection["name"])
#print("Collection id: ", my_collection["id"])
tiles = list(byoc.iter_tiles(my_collection))

for tile in tiles:
    #print(tile)
    #print("Tile created: ", tile['path'])
    tile_name = tile['path'].split("/")
    tile_name_2=(tile_name[3])
    #print ( tile['path'])
    #print (tile_name_2)
    tile_name_3 = tile_name_2.split("(")
    tile_name_4= tile_name_3[0]+"B01.tif"
    print (tile_name_4)
    ### checking s3 raster files:
    raster_name_from_s3_1=raster_name.split("/")
    raster_name_from_s3_2=raster_name_from_s3_1[-1]
    print (raster_name_from_s3_2)
    
    #print("Tile status: ", tile['status'])
    #print("Tile created: ", tile['created'])
    #if(tile['status'] == "FAILED"):
    #    print("Ingestion failed error: ", tile['additionalData'])
#print("2-------------------")

###############################################################open collection:

qc_log.close()
print ("end")
# Out:
# ./../../../../s3/data/d005_env_zones/eea_r_3035_1_km_envzones_p_2018_v01_r00
# following raster is selected for QC:
# ./../../../../s3/data/d005_env_zones/eea_r_3035_1_km_envzones_p_2018_v01_r00/env_zones_1km_3035_1_1_B01.tif
# env_zones_1km_3035_2_6_B01.tif
# env_zones_1km_3035_1_1_B01.tif
# env_zones_1km_3035_3_3_B01.tif
# env_zones_1km_3035_1_1_B01.tif
# env_zones_1km_3035_5_7_B01.tif
# env_zones_1km_3035_1_1_B01.tif
# env_zones_1km_3035_1_3_B01.tif
# env_zones_1km_3035_1_1_B01.tif
# env_zones_1km_3035_2_4_B01.tif
# env_zones_1km_3035_1_1_B01.tif
# env_zones_1km_3035_2_3_B01.tif
# env_zones_1km_3035_1_1_B01.tif
# env_zones_1km_3035_5_3_B01.tif
# env_zones_1km_3035_1_1_B01.tif
# env_zones_1km_3035_4_7_B01.tif
# env_zones_1km_3035_1_1_B01.tif
# env_zones_1km_3035_3_2_B01.tif
# env_zones_1km_3035_1_1_B01.tif
# env_zones_1km_3035_3_4_B01.tif
# env_zones_1km_3035_1_1_B01.tif
# env_zones_1km_3035_5_1_B01.tif
# env_zones_1km_3035_1_1_B01.tif
# env_zones_1km_3035_5_6_B01.tif
# env_zones_1km_3035_1_1_B01.tif
# env_zones_1km_3035_1_5_B01.tif
# env_zones_1km_3035_1_1_B01.tif
# env_zones_1km_3035_3_6_B01.tif
# env_zones_1km_3035_1_1_B01.tif
# env_zones_1km_3035_2_1_B01.tif
# env_zones_1km_3035_1_1_B01.tif
# env_zones_1km_3035_4_3_B01.tif
# env_zones_1km_3035_1_1_B01.tif
# env_zones_1km_3035_3_1_B01.tif
# env_zones_1km_3035_1_1_B01.tif
# env_zones_1km_3035_3_5_B01.tif
# env_zones_1km_3035_1_1_B01.tif
# env_zones_1km_3035_5_4_B01.tif
# env_zones_1km_3035_1_1_B01.tif
# env_zones_1km_3035_1_7_B01.tif
# env_zones_1km_3035_1_1_B01.tif
# env_zones_1km_3035_4_1_B01.tif
# env_zones_1km_3035_1_1_B01.tif
# env_zones_1km_3035_1_6_B01.tif
# env_zones_1km_3035_1_1_B01.tif
# env_zones_1km_3035_4_5_B01.tif
# env_zones_1km_3035_1_1_B01.tif
# env_zones_1km_3035_2_2_B01.tif
# env_zones_1km_3035_1_1_B01.tif
# env_zones_1km_3035_4_4_B01.tif
# env_zones_1km_3035_1_1_B01.tif
# env_zones_1km_3035_4_2_B01.tif
# env_zones_1km_3035_1_1_B01.tif
# env_zones_1km_3035_2_5_B01.tif
# env_zones_1km_3035_1_1_B01.tif
# env_zones_1km_3035_2_7_B01.tif
# env_zones_1km_3035_1_1_B01.tif
# env_zones_1km_3035_4_6_B01.tif
# env_zones_1km_3035_1_1_B01.tif
# env_zones_1km_3035_1_4_B01.tif
# env_zones_1km_3035_1_1_B01.tif
# env_zones_1km_3035_5_2_B01.tif
# env_zones_1km_3035_1_1_B01.tif
# env_zones_1km_3035_5_5_B01.tif
# env_zones_1km_3035_1_1_B01.tif
# env_zones_1km_3035_3_7_B01.tif
# env_zones_1km_3035_1_1_B01.tif
# env_zones_1km_3035_1_2_B01.tif
# env_zones_1km_3035_1_1_B01.tif
# env_zones_1km_3035_1_1_B01.tif
# env_zones_1km_3035_1_1_B01.tif
# end

# %%
my_collections
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 my_collections
#
# NameError: name 'my_collections' is not defined

# %%
list(collections_iterator)

# %%
# Read raster files on S3 drive


#https://sentinelhub-py.readthedocs.io/en/latest/examples/byoc_request.html#Create-new-collection


input_folder ="./../../../s3/data/d002_urban_atlas"
aoi_folder ="./../../../s3/data/d002_urban_atlas/aoi"

##./../../../s3/data/d001_administration/nuts_2021

test_raster = "./../../../s3/data/d002_urban_atlas/ua2018_mosaic_raster_10m_cog_2_2_B1.tif"


# assign directory
directory = input_folder
print (directory)
print ("following raster is selected for QC:")

raster_list=[]
# iterate over files in
# that directory
for filename in os.scandir(directory):
    if filename.is_file():
        #print(filename.path)
        raster_list.append(filename.path)
             
        
## PART 1 select randomly one raster: ----------------------------------    
#print (raster_list)
raster_for_qc = random.choice(raster_list)
#print(raster_for_qc)

## PART 1 b read raster: ----------------------------------   
raster_for_qc=test_raster############################################################################################# for testing
raster = rasterio.open(raster_for_qc)



#raster = rasterio.open(test_raster)

#https://rasterio.readthedocs.io/en/stable/quickstart.html
raster_name = raster.name
raster_bands = raster.count
raster_width= raster.width
raster_height= raster.height
raster_bounds= raster.bounds

left = raster_bounds[0]
bottom = raster_bounds[1]
right = raster_bounds[2]
top = raster_bounds[3]

raster_transform =raster.transform
pixelSizeX = raster_transform[0]
pixelSizeY =-raster_transform[4]
raster_crs =raster.crs
# print raster information:
# print (raster_name)
# print ('================')
# print (raster_bands)
# print (raster_width)
# print (raster_height)
# print (raster_bounds)
# print (raster_transform)
# print ('-----------------')
# print (str(pixelSizeX) +' pixel size x')
# print (str(pixelSizeY) +' pixel size y')
# print (raster_crs)
# print ('-----------------')
# print (str(left)+'  left')
# print (str(bottom)+'  bottom')
# print (str(right)+'  right')
# print (str(top)+'  top')


# build random aoi:--------------------------------------
random__y = random.randrange(bottom,top)
random__x = random.randrange(left,right)
print (random__x)
print (random__y)
aoi_left= random__y
aoi_buttom=random__x
aoi_right=random__y +1000
aoi_top=random__x+1000

fixed_center_coordinate_x = 3024866  #  North of Frankfurt
fixed_center_coordinate_y =4201149

##3458860,3203796 : 3491673,3249116 ## test extent for ua2018_mosaic_raster_10m_cog_2_2_B1
fixed_center_coordinate_x = 3458860  # ua2018_mosaic_raster_10m_cog_2_2_B1
fixed_center_coordinate_y =3203796

aoi_left= fixed_center_coordinate_y
aoi_buttom=fixed_center_coordinate_x
aoi_right=fixed_center_coordinate_y +1000
aoi_top=fixed_center_coordinate_x+1000
#https://stackoverflow.com/questions/30457089/how-to-create-a-shapely-polygon-from-a-list-of-shapely-points
p1 = geometry.Point(aoi_left,aoi_buttom) # 0-0
p2 = geometry.Point(aoi_left,aoi_top)  # 1 0

p3 = geometry.Point(aoi_right,aoi_top)
p4 = geometry.Point(aoi_right,aoi_buttom)
pointList = [p1, p2, p3, p4, p1]                    
poly = geometry.Polygon([[p.x, p.y] for p in pointList])
print(poly.wkt) 

# Define a polygon feature geometry with one attribute
schema = {
    'geometry': 'Polygon',
    'properties': {'id': 'int'},
    }
# Write a new Shapefile
with fiona.open(aoi_folder+'/'+ 'aoi.shp', 'w', 'ESRI Shapefile', schema) as c:
    ## If there are multiple geometries, put the "for" loop here
    c.write({
        'geometry': mapping(poly),
        'properties': {'id': 123},
    })


###testing aoi

with fiona.open(aoi_folder+'/'+ 'aoi.shp', "r") as shapefile:
     shapes = [feature["geometry"] for feature in shapefile]


with rasterio.open(raster_for_qc) as src:
     out_image, out_transform = rasterio.mask.mask(src, shapes, crop=True)
     out_meta = src.meta


print (out_image)


out_meta.update({"driver": "GTiff",
                  "height": out_image.shape[1],
                  "width": out_image.shape[2],
                  "transform": out_transform})
output_raster = aoi_folder+"/aoi.tif"

with rasterio.open(output_raster, "w", **out_meta) as dest:
    dest.write(out_image)


# Plot / show band 1--------------------------------------------------------------START QC of AOI RASTER:
raster_show = rasterio.open(output_raster)
show((raster_show, 1))    
print ("Raster info:....................")
print(raster_show.profile)
print ("Raster Histogramm:....................")
band1 = raster_show.read(1)
#print(band1)
#uniq_vals = np.unique(band1)
#print(sorted(uniq_vals))
print ("Count of pixel values:..........")
unique, counts = np.unique(band1, return_counts=True)
print(np.asarray((unique, counts)).T)

pixel_max = np.max(band1)
print ("Pixel max: '" + str(pixel_max))
pixel_min = np.min(band1)
print ("Pixel min'" + str(pixel_min))





#############
print ("add. RASTER info.............................................:..........")
raster = raster_show
raster_name = raster.name
raster_bands = raster.count
raster_width= raster.width
raster_height= raster.height
raster_bounds= raster.bounds

left = raster_bounds[0]
bottom = raster_bounds[1]
right = raster_bounds[2]
top = raster_bounds[3]

raster_transform =raster.transform
pixelSizeX = raster_transform[0]
pixelSizeY =-raster_transform[4]
raster_crs =raster.crs
# print raster information:
print (raster_name)
print ('================')
print (raster_bands)
print (raster_width)
print (raster_height)
print (raster_bounds)
print (raster_transform)
print ('-----------------')
print (str(pixelSizeX) +' pixel size x')
print (str(pixelSizeY) +' pixel size y')
print (raster_crs)
print ('-----------------')
print (str(left)+'  left')
print (str(bottom)+'  bottom')
print (str(right)+'  right')
print (str(top)+'  top')


print ("end")

# %%
#xx error hello world
##for collection in my_collections:   
 # byoc.delete_collection(collection)
#print ("end")

# %%
tiles
# Out:
# [{'id': '00cec537-6717-4e3b-89ad-7bd3240af390',
#   'created': '2023-12-12T14:21:33.035665Z',
#   'ingestionStart': '2023-12-12T14:21:33.035665Z',
#   'sensingTime': '2018-01-01T00:00:00Z',
#   'coverGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[5900000.000092124, 3499999.999726154],
#      [6900000.000182957, 3499999.9996529873],
#      [6900000.000131197, 4499999.99982101],
#      [5900000.00007046, 4499999.999850882],
#      [5900000.000092124, 3499999.999726154]]]},
#   'tileGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[5900000.0, 4500000.0],
#      [6900000.0, 4500000.0],
#      [6900000.0, 3500000.0],
#      [5900000.0, 3500000.0],
#      [5900000.0, 4500000.0]]]},
#   'path': 'data/d005_env_zones/eea_r_3035_1_km_envzones_p_2018_v01_r00/env_zones_1km_3035_2_6_(BAND).tif',
#   'status': 'INGESTED',
#   'additionalData': {'hasAddedPoints': True,
#    'filesMetadata': {'B01': {'headerSize': 2436,
#      'etag': '"2ec215fe13289a3a8188b32dabfd16f9"'}},
#    'minMetersPerPixel': 100.0,
#    'maxMetersPerPixel': 1600.0}},
#  {'id': '022c35df-0e5e-45ba-a013-06008c324cd5',
#   'created': '2023-12-12T14:21:33.447472Z',
#   'ingestionStart': '2023-12-12T14:21:33.447472Z',
#   'sensingTime': '2018-01-01T00:00:00Z',
#   'coverGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[2899999.9998744843, 2499999.999453159],
#      [3899999.9999655355, 2499999.999501127],
#      [3899999.9999778327, 3499999.9997583767],
#      [2899999.9999188688, 3499999.999733258],
#      [2899999.9998744843, 2499999.999453159]]]},
#   'tileGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[2900000.0, 3500000.0],
#      [3900000.0, 3500000.0],
#      [3900000.0, 2500000.0],
#      [2900000.0, 2500000.0],
#      [2900000.0, 3500000.0]]]},
#   'path': 'data/d005_env_zones/eea_r_3035_1_km_envzones_p_2018_v01_r00/env_zones_1km_3035_3_3_(BAND).tif',
#   'status': 'INGESTED',
#   'additionalData': {'hasAddedPoints': True,
#    'filesMetadata': {'B01': {'headerSize': 2436,
#      'etag': '"10e60bf35844c894888b2be079c40e4f"'}},
#    'minMetersPerPixel': 100.0,
#    'maxMetersPerPixel': 1600.0}},
#  {'id': '041464c0-566e-4860-96a6-cdee15d53e6c',
#   'created': '2023-12-12T14:21:35.260844Z',
#   'ingestionStart': '2023-12-12T14:21:35.260844Z',
#   'sensingTime': '2018-01-01T00:00:00Z',
#   'coverGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[6900000.000368189, 899999.9986336487],
#      [7400000.000440067, 899999.9985969854],
#      [7400000.000434471, 1499999.9988026752],
#      [6900000.000351546, 1499999.99887175],
#      [6900000.000368189, 899999.9986336487]]]},
#   'tileGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[6900000.0, 1500000.0],
#      [7400000.0, 1500000.0],
#      [7400000.0, 900000.0],
#      [6900000.0, 900000.0],
#      [6900000.0, 1500000.0]]]},
#   'path': 'data/d005_env_zones/eea_r_3035_1_km_envzones_p_2018_v01_r00/env_zones_1km_3035_5_7_(BAND).tif',
#   'status': 'INGESTED',
#   'additionalData': {'hasAddedPoints': True,
#    'filesMetadata': {'B01': {'headerSize': 1490,
#      'etag': '"1f2120189e44fc8b140556096a4ac7f7"'}},
#    'minMetersPerPixel': 100.0,
#    'maxMetersPerPixel': 800.0}},
#  {'id': '051d2ad0-26f4-46a1-8549-79e3e86f56d0',
#   'created': '2023-12-12T14:21:31.990988Z',
#   'ingestionStart': '2023-12-12T14:21:31.990988Z',
#   'sensingTime': '2018-01-01T00:00:00Z',
#   'coverGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[2899999.999937216, 4499999.999853213],
#      [3899999.9999819086, 4499999.999860434],
#      [3899999.999981156, 5499999.999909193],
#      [2899999.999937468, 5499999.999907678],
#      [2899999.999937216, 4499999.999853213]]]},
#   'tileGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[2900000.0, 5500000.0],
#      [3900000.0, 5500000.0],
#      [3900000.0, 4500000.0],
#      [2900000.0, 4500000.0],
#      [2900000.0, 5500000.0]]]},
#   'path': 'data/d005_env_zones/eea_r_3035_1_km_envzones_p_2018_v01_r00/env_zones_1km_3035_1_3_(BAND).tif',
#   'status': 'INGESTED',
#   'additionalData': {'hasAddedPoints': True,
#    'filesMetadata': {'B01': {'headerSize': 2436,
#      'etag': '"7c81ea4502c45318413c41ae2b5d1c4d"'}},
#    'minMetersPerPixel': 100.0,
#    'maxMetersPerPixel': 1600.0}},
#  {'id': '0f43f608-0952-4982-8c47-a22bb8e71f55',
#   'created': '2023-12-12T14:21:32.834071Z',
#   'ingestionStart': '2023-12-12T14:21:32.834071Z',
#   'sensingTime': '2018-01-01T00:00:00Z',
#   'coverGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[3899999.9999778327, 3499999.9997583767],
#      [4900000.000030691, 3499999.9997563823],
#      [4900000.000024923, 4499999.999859922],
#      [3899999.9999819086, 4499999.999860434],
#      [3899999.9999778327, 3499999.9997583767]]]},
#   'tileGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[3900000.0, 4500000.0],
#      [4900000.0, 4500000.0],
#      [4900000.0, 3500000.0],
#      [3900000.0, 3500000.0],
#      [3900000.0, 4500000.0]]]},
#   'path': 'data/d005_env_zones/eea_r_3035_1_km_envzones_p_2018_v01_r00/env_zones_1km_3035_2_4_(BAND).tif',
#   'status': 'INGESTED',
#   'additionalData': {'hasAddedPoints': True,
#    'filesMetadata': {'B01': {'headerSize': 2436,
#      'etag': '"ae00c6a276e7ee70b9eeca7d37da6318"'}},
#    'minMetersPerPixel': 100.0,
#    'maxMetersPerPixel': 1600.0}},
#  {'id': '102e23da-404b-4539-817c-75de2a039b86',
#   'created': '2023-12-12T14:21:32.736808Z',
#   'ingestionStart': '2023-12-12T14:21:32.736808Z',
#   'sensingTime': '2018-01-01T00:00:00Z',
#   'coverGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[2899999.9999188688, 3499999.999733258],
#      [3899999.9999778327, 3499999.9997583767],
#      [3899999.9999819086, 4499999.999860434],
#      [2899999.999937216, 4499999.999853213],
#      [2899999.9999188688, 3499999.999733258]]]},
#   'tileGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[2900000.0, 4500000.0],
#      [3900000.0, 4500000.0],
#      [3900000.0, 3500000.0],
#      [2900000.0, 3500000.0],
#      [2900000.0, 4500000.0]]]},
#   'path': 'data/d005_env_zones/eea_r_3035_1_km_envzones_p_2018_v01_r00/env_zones_1km_3035_2_3_(BAND).tif',
#   'status': 'INGESTED',
#   'additionalData': {'hasAddedPoints': True,
#    'filesMetadata': {'B01': {'headerSize': 2436,
#      'etag': '"bc398936f0cdc07cc1bdd8f4e5349cb8"'}},
#    'minMetersPerPixel': 100.0,
#    'maxMetersPerPixel': 1600.0}},
#  {'id': '28ba65f4-689a-4554-9295-53fbeac94042',
#   'created': '2023-12-12T14:21:34.859533Z',
#   'ingestionStart': '2023-12-12T14:21:34.859533Z',
#   'sensingTime': '2018-01-01T00:00:00Z',
#   'coverGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[2899999.9998020055, 899999.9987186198],
#      [3899999.9999423567, 899999.9987599789],
#      [3899999.999949166, 1499999.9990534706],
#      [2899999.9998213183, 1499999.9989992643],
#      [2899999.9998020055, 899999.9987186198]]]},
#   'tileGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[2900000.0, 1500000.0],
#      [3900000.0, 1500000.0],
#      [3900000.0, 900000.0],
#      [2900000.0, 900000.0],
#      [2900000.0, 1500000.0]]]},
#   'path': 'data/d005_env_zones/eea_r_3035_1_km_envzones_p_2018_v01_r00/env_zones_1km_3035_5_3_(BAND).tif',
#   'status': 'INGESTED',
#   'additionalData': {'hasAddedPoints': True,
#    'filesMetadata': {'B01': {'headerSize': 1996,
#      'etag': '"35e102ce9566ee84e4b14a1456a2fb50"'}},
#    'minMetersPerPixel': 100.0,
#    'maxMetersPerPixel': 1600.0}},
#  {'id': '28d462fa-5ffb-4d35-8285-ea5c9f668c77',
#   'created': '2023-12-12T14:21:34.560213Z',
#   'ingestionStart': '2023-12-12T14:21:34.560213Z',
#   'sensingTime': '2018-01-01T00:00:00Z',
#   'coverGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[6900000.000351546, 1499999.99887175],
#      [7400000.000434471, 1499999.9988026752],
#      [7400000.000353016, 2499999.999241539],
#      [6900000.000270415, 2499999.9993238994],
#      [6900000.000351546, 1499999.99887175]]]},
#   'tileGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[6900000.0, 2500000.0],
#      [7400000.0, 2500000.0],
#      [7400000.0, 1500000.0],
#      [6900000.0, 1500000.0],
#      [6900000.0, 2500000.0]]]},
#   'path': 'data/d005_env_zones/eea_r_3035_1_km_envzones_p_2018_v01_r00/env_zones_1km_3035_4_7_(BAND).tif',
#   'status': 'INGESTED',
#   'additionalData': {'hasAddedPoints': True,
#    'filesMetadata': {'B01': {'headerSize': 1916,
#      'etag': '"5dd8086ec0e5e66b39e86bfb90542c13"'}},
#    'minMetersPerPixel': 100.0,
#    'maxMetersPerPixel': 1600.0}},
#  {'id': '29286bb4-a1ac-476c-8355-84c75605bd4f',
#   'created': '2023-12-12T14:21:33.344758Z',
#   'ingestionStart': '2023-12-12T14:21:33.344758Z',
#   'sensingTime': '2018-01-01T00:00:00Z',
#   'coverGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[1899999.9997529364, 2499999.9993465855],
#      [2899999.9998744843, 2499999.999453159],
#      [2899999.9999188688, 3499999.999733258],
#      [1899999.9998345384, 3499999.99966833],
#      [1899999.9997529364, 2499999.9993465855]]]},
#   'tileGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[1900000.0, 3500000.0],
#      [2900000.0, 3500000.0],
#      [2900000.0, 2500000.0],
#      [1900000.0, 2500000.0],
#      [1900000.0, 3500000.0]]]},
#   'path': 'data/d005_env_zones/eea_r_3035_1_km_envzones_p_2018_v01_r00/env_zones_1km_3035_3_2_(BAND).tif',
#   'status': 'INGESTED',
#   'additionalData': {'hasAddedPoints': True,
#    'filesMetadata': {'B01': {'headerSize': 2436,
#      'etag': '"cc0985ef37f1f0d95a55756275497913"'}},
#    'minMetersPerPixel': 100.0,
#    'maxMetersPerPixel': 1600.0}},
#  {'id': '321c8496-7da5-4128-abfb-e810188ca4f4',
#   'created': '2023-12-12T14:21:33.546981Z',
#   'ingestionStart': '2023-12-12T14:21:33.546981Z',
#   'sensingTime': '2018-01-01T00:00:00Z',
#   'coverGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[3899999.9999655355, 2499999.999501127],
#      [4900000.000047716, 2499999.999497109],
#      [4900000.000030691, 3499999.9997563823],
#      [3899999.9999778327, 3499999.9997583767],
#      [3899999.9999655355, 2499999.999501127]]]},
#   'tileGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[3900000.0, 3500000.0],
#      [4900000.0, 3500000.0],
#      [4900000.0, 2500000.0],
#      [3900000.0, 2500000.0],
#      [3900000.0, 3500000.0]]]},
#   'path': 'data/d005_env_zones/eea_r_3035_1_km_envzones_p_2018_v01_r00/env_zones_1km_3035_3_4_(BAND).tif',
#   'status': 'INGESTED',
#   'additionalData': {'hasAddedPoints': True,
#    'filesMetadata': {'B01': {'headerSize': 2436,
#      'etag': '"85783b4e934494acb023d209e0fa5950"'}},
#    'minMetersPerPixel': 100.0,
#    'maxMetersPerPixel': 1600.0}},
#  {'id': '3c44f8e2-3e28-4b54-8abd-88df27aae9e6',
#   'created': '2023-12-12T14:21:34.664076Z',
#   'ingestionStart': '2023-12-12T14:21:34.664076Z',
#   'sensingTime': '2018-01-01T00:00:00Z',
#   'coverGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[899999.9995141891, 899999.9985771412],
#      [1899999.9996551168, 899999.9986460446],
#      [1899999.9996738061, 1499999.9988923713],
#      [899999.9995077639, 1499999.9987544336],
#      [899999.9995141891, 899999.9985771412]]]},
#   'tileGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[900000.0, 1500000.0],
#      [1900000.0, 1500000.0],
#      [1900000.0, 900000.0],
#      [900000.0, 900000.0],
#      [900000.0, 1500000.0]]]},
#   'path': 'data/d005_env_zones/eea_r_3035_1_km_envzones_p_2018_v01_r00/env_zones_1km_3035_5_1_(BAND).tif',
#   'status': 'INGESTED',
#   'additionalData': {'hasAddedPoints': True,
#    'filesMetadata': {'B01': {'headerSize': 1996,
#      'etag': '"07448410f2cfe20ad4cb96ca88fd042d"'}},
#    'minMetersPerPixel': 100.0,
#    'maxMetersPerPixel': 1600.0}},
#  {'id': '4d67b303-a3d6-48b5-b5c1-1516847fc3a6',
#   'created': '2023-12-12T14:21:35.161716Z',
#   'ingestionStart': '2023-12-12T14:21:35.161716Z',
#   'sensingTime': '2018-01-01T00:00:00Z',
#   'coverGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[5900000.000220842, 899999.9987086263],
#      [6900000.000368189, 899999.9986336487],
#      [6900000.000351546, 1499999.99887175],
#      [5900000.000200475, 1499999.998985574],
#      [5900000.000220842, 899999.9987086263]]]},
#   'tileGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[5900000.0, 1500000.0],
#      [6900000.0, 1500000.0],
#      [6900000.0, 900000.0],
#      [5900000.0, 900000.0],
#      [5900000.0, 1500000.0]]]},
#   'path': 'data/d005_env_zones/eea_r_3035_1_km_envzones_p_2018_v01_r00/env_zones_1km_3035_5_6_(BAND).tif',
#   'status': 'INGESTED',
#   'additionalData': {'hasAddedPoints': True,
#    'filesMetadata': {'B01': {'headerSize': 1996,
#      'etag': '"fafae56c348f3e25ac4fdb09715d9e8d"'}},
#    'minMetersPerPixel': 100.0,
#    'maxMetersPerPixel': 1600.0}},
#  {'id': '4dcdd25b-ed1c-4bab-8e69-1c01e54605f2',
#   'created': '2023-12-12T14:21:32.209194Z',
#   'ingestionStart': '2023-12-12T14:21:32.209194Z',
#   'sensingTime': '2018-01-01T00:00:00Z',
#   'coverGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[4900000.000024923, 4499999.999859922],
#      [5900000.00007046, 4499999.999850882],
#      [5900000.000069293, 5499999.999907136],
#      [4900000.000025874, 5499999.999909077],
#      [4900000.000024923, 4499999.999859922]]]},
#   'tileGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[4900000.0, 5500000.0],
#      [5900000.0, 5500000.0],
#      [5900000.0, 4500000.0],
#      [4900000.0, 4500000.0],
#      [4900000.0, 5500000.0]]]},
#   'path': 'data/d005_env_zones/eea_r_3035_1_km_envzones_p_2018_v01_r00/env_zones_1km_3035_1_5_(BAND).tif',
#   'status': 'INGESTED',
#   'additionalData': {'hasAddedPoints': True,
#    'filesMetadata': {'B01': {'headerSize': 2436,
#      'etag': '"534645aa736006be0a59b92fa0a8d2c0"'}},
#    'minMetersPerPixel': 100.0,
#    'maxMetersPerPixel': 1600.0}},
#  {'id': '53c916e6-bf8a-468f-8afb-0ff454c78fe3',
#   'created': '2023-12-12T14:21:33.747682Z',
#   'ingestionStart': '2023-12-12T14:21:33.747682Z',
#   'sensingTime': '2018-01-01T00:00:00Z',
#   'coverGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[5900000.000142133, 2499999.999440437],
#      [6900000.000270415, 2499999.9993238994],
#      [6900000.000182957, 3499999.9996529873],
#      [5900000.000092124, 3499999.999726154],
#      [5900000.000142133, 2499999.999440437]]]},
#   'tileGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[5900000.0, 3500000.0],
#      [6900000.0, 3500000.0],
#      [6900000.0, 2500000.0],
#      [5900000.0, 2500000.0],
#      [5900000.0, 3500000.0]]]},
#   'path': 'data/d005_env_zones/eea_r_3035_1_km_envzones_p_2018_v01_r00/env_zones_1km_3035_3_6_(BAND).tif',
#   'status': 'INGESTED',
#   'additionalData': {'hasAddedPoints': True,
#    'filesMetadata': {'B01': {'headerSize': 2436,
#      'etag': '"43d3ae2cfe27852ca24876793b2ef94e"'}},
#    'minMetersPerPixel': 100.0,
#    'maxMetersPerPixel': 1600.0}},
#  {'id': '5419a528-83f3-45f7-a131-46d28026d744',
#   'created': '2023-12-12T14:21:32.524534Z',
#   'ingestionStart': '2023-12-12T14:21:32.524534Z',
#   'sensingTime': '2018-01-01T00:00:00Z',
#   'coverGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[899999.9996950845, 3499999.999540969],
#      [1899999.9998345384, 3499999.99966833],
#      [1899999.9998805118, 4499999.999828045],
#      [899999.9997812272, 4499999.999760259],
#      [899999.9996950845, 3499999.999540969]]]},
#   'tileGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[900000.0, 4500000.0],
#      [1900000.0, 4500000.0],
#      [1900000.0, 3500000.0],
#      [900000.0, 3500000.0],
#      [900000.0, 4500000.0]]]},
#   'path': 'data/d005_env_zones/eea_r_3035_1_km_envzones_p_2018_v01_r00/env_zones_1km_3035_2_1_(BAND).tif',
#   'status': 'INGESTED',
#   'additionalData': {'hasAddedPoints': True,
#    'filesMetadata': {'B01': {'headerSize': 2436,
#      'etag': '"6c42d09772ff28648a080b13af8b4a5a"'}},
#    'minMetersPerPixel': 100.0,
#    'maxMetersPerPixel': 1600.0}},
#  {'id': '5546830a-f3f6-4f64-b019-b293376ea24f',
#   'created': '2023-12-12T14:21:34.159677Z',
#   'ingestionStart': '2023-12-12T14:21:34.159677Z',
#   'sensingTime': '2018-01-01T00:00:00Z',
#   'coverGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[2899999.9998213183, 1499999.9989992643],
#      [3899999.999949166, 1499999.9990534706],
#      [3899999.9999655355, 2499999.999501127],
#      [2899999.9998744843, 2499999.999453159],
#      [2899999.9998213183, 1499999.9989992643]]]},
#   'tileGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[2900000.0, 2500000.0],
#      [3900000.0, 2500000.0],
#      [3900000.0, 1500000.0],
#      [2900000.0, 1500000.0],
#      [2900000.0, 2500000.0]]]},
#   'path': 'data/d005_env_zones/eea_r_3035_1_km_envzones_p_2018_v01_r00/env_zones_1km_3035_4_3_(BAND).tif',
#   'status': 'INGESTED',
#   'additionalData': {'hasAddedPoints': True,
#    'filesMetadata': {'B01': {'headerSize': 2436,
#      'etag': '"ebcfeb29a1bf7e2fb83f342f8b0f0b6f"'}},
#    'minMetersPerPixel': 100.0,
#    'maxMetersPerPixel': 1600.0}},
#  {'id': '66f8669f-ad7f-4276-813a-83a348129c65',
#   'created': '2023-12-12T14:21:33.249131Z',
#   'ingestionStart': '2023-12-12T14:21:33.249131Z',
#   'sensingTime': '2018-01-01T00:00:00Z',
#   'coverGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[899999.9995828187, 2499999.9991765604],
#      [1899999.9997529364, 2499999.9993465855],
#      [1899999.9998345384, 3499999.99966833],
#      [899999.9996950845, 3499999.999540969],
#      [899999.9995828187, 2499999.9991765604]]]},
#   'tileGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[900000.0, 3500000.0],
#      [1900000.0, 3500000.0],
#      [1900000.0, 2500000.0],
#      [900000.0, 2500000.0],
#      [900000.0, 3500000.0]]]},
#   'path': 'data/d005_env_zones/eea_r_3035_1_km_envzones_p_2018_v01_r00/env_zones_1km_3035_3_1_(BAND).tif',
#   'status': 'INGESTED',
#   'additionalData': {'hasAddedPoints': True,
#    'filesMetadata': {'B01': {'headerSize': 2436,
#      'etag': '"0b31003d61d717d48572cf6ecf605432"'}},
#    'minMetersPerPixel': 100.0,
#    'maxMetersPerPixel': 1600.0}},
#  {'id': '68eee2bf-1467-456c-b6c7-8158c460b406',
#   'created': '2023-12-12T14:21:33.648848Z',
#   'ingestionStart': '2023-12-12T14:21:33.648848Z',
#   'sensingTime': '2018-01-01T00:00:00Z',
#   'coverGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[4900000.000047716, 2499999.999497109],
#      [5900000.000142133, 2499999.999440437],
#      [5900000.000092124, 3499999.999726154],
#      [4900000.000030691, 3499999.9997563823],
#      [4900000.000047716, 2499999.999497109]]]},
#   'tileGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[4900000.0, 3500000.0],
#      [5900000.0, 3500000.0],
#      [5900000.0, 2500000.0],
#      [4900000.0, 2500000.0],
#      [4900000.0, 3500000.0]]]},
#   'path': 'data/d005_env_zones/eea_r_3035_1_km_envzones_p_2018_v01_r00/env_zones_1km_3035_3_5_(BAND).tif',
#   'status': 'INGESTED',
#   'additionalData': {'hasAddedPoints': True,
#    'filesMetadata': {'B01': {'headerSize': 2436,
#      'etag': '"074f4daa9b277a2eed3f5f85b49c6e74"'}},
#    'minMetersPerPixel': 100.0,
#    'maxMetersPerPixel': 1600.0}},
#  {'id': '6f114691-a381-4bb9-85b3-e4fa2655ebea',
#   'created': '2023-12-12T14:21:34.960116Z',
#   'ingestionStart': '2023-12-12T14:21:34.960116Z',
#   'sensingTime': '2018-01-01T00:00:00Z',
#   'coverGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[3899999.9999423567, 899999.9987599789],
#      [4900000.000079409, 899999.9987562797],
#      [4900000.000070169, 1499999.9990487644],
#      [3899999.999949166, 1499999.9990534706],
#      [3899999.9999423567, 899999.9987599789]]]},
#   'tileGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[3900000.0, 1500000.0],
#      [4900000.0, 1500000.0],
#      [4900000.0, 900000.0],
#      [3900000.0, 900000.0],
#      [3900000.0, 1500000.0]]]},
#   'path': 'data/d005_env_zones/eea_r_3035_1_km_envzones_p_2018_v01_r00/env_zones_1km_3035_5_4_(BAND).tif',
#   'status': 'INGESTED',
#   'additionalData': {'hasAddedPoints': True,
#    'filesMetadata': {'B01': {'headerSize': 1996,
#      'etag': '"a55f9de163d86dfa8b3b59322d8bc7f7"'}},
#    'minMetersPerPixel': 100.0,
#    'maxMetersPerPixel': 1600.0}},
#  {'id': '8c8ead2e-35a2-4a4b-b431-eb7df46730a2',
#   'created': '2023-12-12T14:21:32.422411Z',
#   'ingestionStart': '2023-12-12T14:21:32.422411Z',
#   'sensingTime': '2018-01-01T00:00:00Z',
#   'coverGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[6900000.000131197, 4499999.99982101],
#      [7400000.000177065, 4499999.999790369],
#      [7400000.000146814, 5499999.99988564],
#      [6900000.000115294, 5499999.999898047],
#      [6900000.000131197, 4499999.99982101]]]},
#   'tileGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[6900000.0, 5500000.0],
#      [7400000.0, 5500000.0],
#      [7400000.0, 4500000.0],
#      [6900000.0, 4500000.0],
#      [6900000.0, 5500000.0]]]},
#   'path': 'data/d005_env_zones/eea_r_3035_1_km_envzones_p_2018_v01_r00/env_zones_1km_3035_1_7_(BAND).tif',
#   'status': 'INGESTED',
#   'additionalData': {'hasAddedPoints': True,
#    'filesMetadata': {'B01': {'headerSize': 1916,
#      'etag': '"3d53034b14696b0debcb8dd37f56b2c1"'}},
#    'minMetersPerPixel': 100.0,
#    'maxMetersPerPixel': 1600.0}},
#  {'id': '91254e03-9cfe-4af5-b766-4ce0ae67f1e6',
#   'created': '2023-12-12T14:21:33.957644Z',
#   'ingestionStart': '2023-12-12T14:21:33.957644Z',
#   'sensingTime': '2018-01-01T00:00:00Z',
#   'coverGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[899999.9995077639, 1499999.9987544336],
#      [1899999.9996738061, 1499999.9988923713],
#      [1899999.9997529364, 2499999.9993465855],
#      [899999.9995828187, 2499999.9991765604],
#      [899999.9995077639, 1499999.9987544336]]]},
#   'tileGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[900000.0, 2500000.0],
#      [1900000.0, 2500000.0],
#      [1900000.0, 1500000.0],
#      [900000.0, 1500000.0],
#      [900000.0, 2500000.0]]]},
#   'path': 'data/d005_env_zones/eea_r_3035_1_km_envzones_p_2018_v01_r00/env_zones_1km_3035_4_1_(BAND).tif',
#   'status': 'INGESTED',
#   'additionalData': {'hasAddedPoints': True,
#    'filesMetadata': {'B01': {'headerSize': 2436,
#      'etag': '"2831920b362a023f447a4523fd5cd89d"'}},
#    'minMetersPerPixel': 100.0,
#    'maxMetersPerPixel': 1600.0}},
#  {'id': '91d1a813-696d-4578-9ed9-6dc61c0b5a94',
#   'created': '2023-12-12T14:21:32.322185Z',
#   'ingestionStart': '2023-12-12T14:21:32.322185Z',
#   'sensingTime': '2018-01-01T00:00:00Z',
#   'coverGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[5900000.00007046, 4499999.999850882],
#      [6900000.000131197, 4499999.99982101],
#      [6900000.000115294, 5499999.999898047],
#      [5900000.000069293, 5499999.999907136],
#      [5900000.00007046, 4499999.999850882]]]},
#   'tileGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[5900000.0, 5500000.0],
#      [6900000.0, 5500000.0],
#      [6900000.0, 4500000.0],
#      [5900000.0, 4500000.0],
#      [5900000.0, 5500000.0]]]},
#   'path': 'data/d005_env_zones/eea_r_3035_1_km_envzones_p_2018_v01_r00/env_zones_1km_3035_1_6_(BAND).tif',
#   'status': 'INGESTED',
#   'additionalData': {'hasAddedPoints': True,
#    'filesMetadata': {'B01': {'headerSize': 2436,
#      'etag': '"a443dd6b98b73f1d4da532b0bf539cb2"'}},
#    'minMetersPerPixel': 100.0,
#    'maxMetersPerPixel': 1600.0}},
#  {'id': 'ab312cb8-451e-4819-8b8e-b9eda4a798b7',
#   'created': '2023-12-12T14:21:34.359855Z',
#   'ingestionStart': '2023-12-12T14:21:34.359855Z',
#   'sensingTime': '2018-01-01T00:00:00Z',
#   'coverGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[4900000.000070169, 1499999.9990487644],
#      [5900000.000200475, 1499999.998985574],
#      [5900000.000142133, 2499999.999440437],
#      [4900000.000047716, 2499999.999497109],
#      [4900000.000070169, 1499999.9990487644]]]},
#   'tileGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[4900000.0, 2500000.0],
#      [5900000.0, 2500000.0],
#      [5900000.0, 1500000.0],
#      [4900000.0, 1500000.0],
#      [4900000.0, 2500000.0]]]},
#   'path': 'data/d005_env_zones/eea_r_3035_1_km_envzones_p_2018_v01_r00/env_zones_1km_3035_4_5_(BAND).tif',
#   'status': 'INGESTED',
#   'additionalData': {'hasAddedPoints': True,
#    'filesMetadata': {'B01': {'headerSize': 2436,
#      'etag': '"cf61420133d6cf1e749ac725f4e2af8c"'}},
#    'minMetersPerPixel': 100.0,
#    'maxMetersPerPixel': 1600.0}},
#  {'id': 'b1a1bb65-f45b-45f7-87a4-408ab3c82cc0',
#   'created': '2023-12-12T14:21:32.635824Z',
#   'ingestionStart': '2023-12-12T14:21:32.635824Z',
#   'sensingTime': '2018-01-01T00:00:00Z',
#   'coverGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[1899999.9998345384, 3499999.99966833],
#      [2899999.9999188688, 3499999.999733258],
#      [2899999.999937216, 4499999.999853213],
#      [1899999.9998805118, 4499999.999828045],
#      [1899999.9998345384, 3499999.99966833]]]},
#   'tileGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[1900000.0, 4500000.0],
#      [2900000.0, 4500000.0],
#      [2900000.0, 3500000.0],
#      [1900000.0, 3500000.0],
#      [1900000.0, 4500000.0]]]},
#   'path': 'data/d005_env_zones/eea_r_3035_1_km_envzones_p_2018_v01_r00/env_zones_1km_3035_2_2_(BAND).tif',
#   'status': 'INGESTED',
#   'additionalData': {'hasAddedPoints': True,
#    'filesMetadata': {'B01': {'headerSize': 2436,
#      'etag': '"1eb49f8f563f0bd1a9d50cadbd4614b5"'}},
#    'minMetersPerPixel': 100.0,
#    'maxMetersPerPixel': 1600.0}},
#  {'id': 'b56cebf4-80a3-4cfe-b39b-9fa7b8807fab',
#   'created': '2023-12-12T14:21:34.256642Z',
#   'ingestionStart': '2023-12-12T14:21:34.256642Z',
#   'sensingTime': '2018-01-01T00:00:00Z',
#   'coverGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[3899999.999949166, 1499999.9990534706],
#      [4900000.000070169, 1499999.9990487644],
#      [4900000.000047716, 2499999.999497109],
#      [3899999.9999655355, 2499999.999501127],
#      [3899999.999949166, 1499999.9990534706]]]},
#   'tileGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[3900000.0, 2500000.0],
#      [4900000.0, 2500000.0],
#      [4900000.0, 1500000.0],
#      [3900000.0, 1500000.0],
#      [3900000.0, 2500000.0]]]},
#   'path': 'data/d005_env_zones/eea_r_3035_1_km_envzones_p_2018_v01_r00/env_zones_1km_3035_4_4_(BAND).tif',
#   'status': 'INGESTED',
#   'additionalData': {'hasAddedPoints': True,
#    'filesMetadata': {'B01': {'headerSize': 2436,
#      'etag': '"9f7381c3c8ceed9c0d37499a729851b1"'}},
#    'minMetersPerPixel': 100.0,
#    'maxMetersPerPixel': 1600.0}},
#  {'id': 'b652967d-de78-437f-8154-9beb8fbba372',
#   'created': '2023-12-12T14:21:34.058622Z',
#   'ingestionStart': '2023-12-12T14:21:34.058622Z',
#   'sensingTime': '2018-01-01T00:00:00Z',
#   'coverGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[1899999.9996738061, 1499999.9988923713],
#      [2899999.9998213183, 1499999.9989992643],
#      [2899999.9998744843, 2499999.999453159],
#      [1899999.9997529364, 2499999.9993465855],
#      [1899999.9996738061, 1499999.9988923713]]]},
#   'tileGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[1900000.0, 2500000.0],
#      [2900000.0, 2500000.0],
#      [2900000.0, 1500000.0],
#      [1900000.0, 1500000.0],
#      [1900000.0, 2500000.0]]]},
#   'path': 'data/d005_env_zones/eea_r_3035_1_km_envzones_p_2018_v01_r00/env_zones_1km_3035_4_2_(BAND).tif',
#   'status': 'INGESTED',
#   'additionalData': {'hasAddedPoints': True,
#    'filesMetadata': {'B01': {'headerSize': 2436,
#      'etag': '"f2ac160586faf1928469536037187083"'}},
#    'minMetersPerPixel': 100.0,
#    'maxMetersPerPixel': 1600.0}},
#  {'id': 'b96a98c6-e6e1-4f7f-a8f2-097cbead69df',
#   'created': '2023-12-12T14:21:32.934723Z',
#   'ingestionStart': '2023-12-12T14:21:32.934723Z',
#   'sensingTime': '2018-01-01T00:00:00Z',
#   'coverGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[4900000.000030691, 3499999.9997563823],
#      [5900000.000092124, 3499999.999726154],
#      [5900000.00007046, 4499999.999850882],
#      [4900000.000024923, 4499999.999859922],
#      [4900000.000030691, 3499999.9997563823]]]},
#   'tileGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[4900000.0, 4500000.0],
#      [5900000.0, 4500000.0],
#      [5900000.0, 3500000.0],
#      [4900000.0, 3500000.0],
#      [4900000.0, 4500000.0]]]},
#   'path': 'data/d005_env_zones/eea_r_3035_1_km_envzones_p_2018_v01_r00/env_zones_1km_3035_2_5_(BAND).tif',
#   'status': 'INGESTED',
#   'additionalData': {'hasAddedPoints': True,
#    'filesMetadata': {'B01': {'headerSize': 2436,
#      'etag': '"9c451346eb6a7804893456e5f672f5cb"'}},
#    'minMetersPerPixel': 100.0,
#    'maxMetersPerPixel': 1600.0}},
#  {'id': 'bfc0f26e-d2a9-4ab0-8c5e-e67cde697f2d',
#   'created': '2023-12-12T14:21:33.148247Z',
#   'ingestionStart': '2023-12-12T14:21:33.148247Z',
#   'sensingTime': '2018-01-01T00:00:00Z',
#   'coverGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[6900000.000182957, 3499999.9996529873],
#      [7400000.00024894, 3499999.9995930186],
#      [7400000.000177065, 4499999.999790369],
#      [6900000.000131197, 4499999.99982101],
#      [6900000.000182957, 3499999.9996529873]]]},
#   'tileGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[6900000.0, 4500000.0],
#      [7400000.0, 4500000.0],
#      [7400000.0, 3500000.0],
#      [6900000.0, 3500000.0],
#      [6900000.0, 4500000.0]]]},
#   'path': 'data/d005_env_zones/eea_r_3035_1_km_envzones_p_2018_v01_r00/env_zones_1km_3035_2_7_(BAND).tif',
#   'status': 'INGESTED',
#   'additionalData': {'hasAddedPoints': True,
#    'filesMetadata': {'B01': {'headerSize': 1916,
#      'etag': '"676812796febc450342c3b379170e6fc"'}},
#    'minMetersPerPixel': 100.0,
#    'maxMetersPerPixel': 1600.0}},
#  {'id': 'c9487ecc-5137-4854-9e83-e8e4904ff5cb',
#   'created': '2023-12-12T14:21:34.458526Z',
#   'ingestionStart': '2023-12-12T14:21:34.458526Z',
#   'sensingTime': '2018-01-01T00:00:00Z',
#   'coverGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[5900000.000200475, 1499999.998985574],
#      [6900000.000351546, 1499999.99887175],
#      [6900000.000270415, 2499999.9993238994],
#      [5900000.000142133, 2499999.999440437],
#      [5900000.000200475, 1499999.998985574]]]},
#   'tileGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[5900000.0, 2500000.0],
#      [6900000.0, 2500000.0],
#      [6900000.0, 1500000.0],
#      [5900000.0, 1500000.0],
#      [5900000.0, 2500000.0]]]},
#   'path': 'data/d005_env_zones/eea_r_3035_1_km_envzones_p_2018_v01_r00/env_zones_1km_3035_4_6_(BAND).tif',
#   'status': 'INGESTED',
#   'additionalData': {'hasAddedPoints': True,
#    'filesMetadata': {'B01': {'headerSize': 2436,
#      'etag': '"f327da0a0d70e0c50dd5bf750848f136"'}},
#    'minMetersPerPixel': 100.0,
#    'maxMetersPerPixel': 1600.0}},
#  {'id': 'cb5e3611-6566-40a9-a7f1-7f8710e40dd5',
#   'created': '2023-12-12T14:21:32.090358Z',
#   'ingestionStart': '2023-12-12T14:21:32.090358Z',
#   'sensingTime': '2018-01-01T00:00:00Z',
#   'coverGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[3899999.9999819086, 4499999.999860434],
#      [4900000.000024923, 4499999.999859922],
#      [4900000.000025874, 5499999.999909077],
#      [3899999.999981156, 5499999.999909193],
#      [3899999.9999819086, 4499999.999860434]]]},
#   'tileGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[3900000.0, 5500000.0],
#      [4900000.0, 5500000.0],
#      [4900000.0, 4500000.0],
#      [3900000.0, 4500000.0],
#      [3900000.0, 5500000.0]]]},
#   'path': 'data/d005_env_zones/eea_r_3035_1_km_envzones_p_2018_v01_r00/env_zones_1km_3035_1_4_(BAND).tif',
#   'status': 'INGESTED',
#   'additionalData': {'hasAddedPoints': True,
#    'filesMetadata': {'B01': {'headerSize': 2436,
#      'etag': '"e14866ef497fbab22453535dcec4284c"'}},
#    'minMetersPerPixel': 100.0,
#    'maxMetersPerPixel': 1600.0}},
#  {'id': 'cebcef00-89b8-45d3-93ff-117afab96c03',
#   'created': '2023-12-12T14:21:34.760658Z',
#   'ingestionStart': '2023-12-12T14:21:34.760658Z',
#   'sensingTime': '2018-01-01T00:00:00Z',
#   'coverGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[1899999.9996551168, 899999.9986460446],
#      [2899999.9998020055, 899999.9987186198],
#      [2899999.9998213183, 1499999.9989992643],
#      [1899999.9996738061, 1499999.9988923713],
#      [1899999.9996551168, 899999.9986460446]]]},
#   'tileGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[1900000.0, 1500000.0],
#      [2900000.0, 1500000.0],
#      [2900000.0, 900000.0],
#      [1900000.0, 900000.0],
#      [1900000.0, 1500000.0]]]},
#   'path': 'data/d005_env_zones/eea_r_3035_1_km_envzones_p_2018_v01_r00/env_zones_1km_3035_5_2_(BAND).tif',
#   'status': 'INGESTED',
#   'additionalData': {'hasAddedPoints': True,
#    'filesMetadata': {'B01': {'headerSize': 1996,
#      'etag': '"4320bb022c033ee5cd879679d5ad7e79"'}},
#    'minMetersPerPixel': 100.0,
#    'maxMetersPerPixel': 1600.0}},
#  {'id': 'e0fad0e0-a9f6-470e-b6bd-0f05f32bd1b1',
#   'created': '2023-12-12T14:21:35.058784Z',
#   'ingestionStart': '2023-12-12T14:21:35.058784Z',
#   'sensingTime': '2018-01-01T00:00:00Z',
#   'coverGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[4900000.000079409, 899999.9987562797],
#      [5900000.000220842, 899999.9987086263],
#      [5900000.000200475, 1499999.998985574],
#      [4900000.000070169, 1499999.9990487644],
#      [4900000.000079409, 899999.9987562797]]]},
#   'tileGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[4900000.0, 1500000.0],
#      [5900000.0, 1500000.0],
#      [5900000.0, 900000.0],
#      [4900000.0, 900000.0],
#      [4900000.0, 1500000.0]]]},
#   'path': 'data/d005_env_zones/eea_r_3035_1_km_envzones_p_2018_v01_r00/env_zones_1km_3035_5_5_(BAND).tif',
#   'status': 'INGESTED',
#   'additionalData': {'hasAddedPoints': True,
#    'filesMetadata': {'B01': {'headerSize': 1996,
#      'etag': '"5eec4c5d356f778dff7d03b534b32795"'}},
#    'minMetersPerPixel': 100.0,
#    'maxMetersPerPixel': 1600.0}},
#  {'id': 'e589aa4d-2871-4147-b3f3-9624f5914063',
#   'created': '2023-12-12T14:21:33.859001Z',
#   'ingestionStart': '2023-12-12T14:21:33.859001Z',
#   'sensingTime': '2018-01-01T00:00:00Z',
#   'coverGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[6900000.000270415, 2499999.9993238994],
#      [7400000.000353016, 2499999.999241539],
#      [7400000.00024894, 3499999.9995930186],
#      [6900000.000182957, 3499999.9996529873],
#      [6900000.000270415, 2499999.9993238994]]]},
#   'tileGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[6900000.0, 3500000.0],
#      [7400000.0, 3500000.0],
#      [7400000.0, 2500000.0],
#      [6900000.0, 2500000.0],
#      [6900000.0, 3500000.0]]]},
#   'path': 'data/d005_env_zones/eea_r_3035_1_km_envzones_p_2018_v01_r00/env_zones_1km_3035_3_7_(BAND).tif',
#   'status': 'INGESTED',
#   'additionalData': {'hasAddedPoints': True,
#    'filesMetadata': {'B01': {'headerSize': 1916,
#      'etag': '"17aa9d99876c2b134076e6998eafb978"'}},
#    'minMetersPerPixel': 100.0,
#    'maxMetersPerPixel': 1600.0}},
#  {'id': 'f1e73eff-3433-4817-907e-8a32a5f2be0d',
#   'created': '2023-12-12T14:21:31.879442Z',
#   'ingestionStart': '2023-12-12T14:21:31.879442Z',
#   'sensingTime': '2018-01-01T00:00:00Z',
#   'coverGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[1899999.9998805118, 4499999.999828045],
#      [2899999.999937216, 4499999.999853213],
#      [2899999.999937468, 5499999.999907678],
#      [1899999.9998928742, 5499999.999900502],
#      [1899999.9998805118, 4499999.999828045]]]},
#   'tileGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[1900000.0, 5500000.0],
#      [2900000.0, 5500000.0],
#      [2900000.0, 4500000.0],
#      [1900000.0, 4500000.0],
#      [1900000.0, 5500000.0]]]},
#   'path': 'data/d005_env_zones/eea_r_3035_1_km_envzones_p_2018_v01_r00/env_zones_1km_3035_1_2_(BAND).tif',
#   'status': 'INGESTED',
#   'additionalData': {'hasAddedPoints': True,
#    'filesMetadata': {'B01': {'headerSize': 2436,
#      'etag': '"dccfd65d6135ec11f1b30919c633106c"'}},
#    'minMetersPerPixel': 100.0,
#    'maxMetersPerPixel': 1600.0}},
#  {'id': 'f40821f5-bacb-4bc6-8d98-358035a04e11',
#   'created': '2023-12-12T14:21:31.760197Z',
#   'ingestionStart': '2023-12-12T14:21:31.760197Z',
#   'sensingTime': '2018-01-01T00:00:00Z',
#   'coverGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[899999.9997812272, 4499999.999760259],
#      [1899999.9998805118, 4499999.999828045],
#      [1899999.9998928742, 5499999.999900502],
#      [899999.9998236685, 5499999.99987142],
#      [899999.9997812272, 4499999.999760259]]]},
#   'tileGeometry': {'type': 'Polygon',
#    'crs': {'type': 'name',
#     'properties': {'name': 'urn:ogc:def:crs:EPSG::3035'}},
#    'coordinates': [[[900000.0, 5500000.0],
#      [1900000.0, 5500000.0],
#      [1900000.0, 4500000.0],
#      [900000.0, 4500000.0],
#      [900000.0, 5500000.0]]]},
#   'path': 'data/d005_env_zones/eea_r_3035_1_km_envzones_p_2018_v01_r00/env_zones_1km_3035_1_1_(BAND).tif',
#   'status': 'INGESTED',
#   'additionalData': {'hasAddedPoints': True,
#    'filesMetadata': {'B01': {'headerSize': 2436,
#      'etag': '"90acd49a663f61bad94d2b0f750abd93"'}},
#    'minMetersPerPixel': 100.0,
#    'maxMetersPerPixel': 1600.0}}]
