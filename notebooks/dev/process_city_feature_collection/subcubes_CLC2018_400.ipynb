# %% [markdown]
# # City cube processing loop - get CLC Water classes in buffered city
# Get land cover data from CLC 2018 in and around city, by creating a buffer around city geometry.
# This notebook focuses on Water classes (CLC4**).

# %%
# %matplotlib inline

import numpy as np
import fiona
import shapely
from shapely.geometry import MultiLineString, MultiPolygon, Polygon, box, shape
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
import os
from pathlib import Path
import rasterio
import IPython.display
import time  
import datetime
from contextlib import redirect_stdout
import rasterio
import rasterio.features

# load utils functions
from src import utils

# Sentinel Hub
from sentinelhub import (
    CRS,
    BBox,
    BBoxSplitter,
    ByocCollection,
    ByocCollectionAdditionalData,
    ByocCollectionBand,
    ByocTile,
    DataCollection,
    DownloadFailedException,
    SentinelHubDownloadClient,
    MimeType,
    SentinelHubBYOC,
    SentinelHubRequest,
    SHConfig,
    bbox_to_dimensions,
    os_utils,
    Geometry
)

config = SHConfig()
config.instance_id = os.environ.get("SH_INSTANCE_ID")
config.sh_client_id = os.environ.get("SH_CLIENT_ID")
config.sh_client_secret = os.environ.get("SH_CLIENT_SECRET")
config.aws_access_key_id = os.environ.get("username")
config.aws_secret_access_key = os.environ.get("password")

# %%
# read in the city polygons
from src import db_connect, utils
from sqlalchemy import text
import geopandas as gpd

home_dir = os.environ.get('HOME')
home_dir = 'C:/Users/MariaRicci/Projects_Cdrive/FAIRiCube'
engine_postgresql = db_connect.create_engine(db_config = f"{home_dir}/uc1-urban-climate/database.ini")

with engine_postgresql.begin() as conn:
    query = text("""
              SELECT urau_code, urau_name, geometry
              FROM lut.l_city_urau2021
              """)
    gdf = gpd.read_postgis(query, conn, geom_col='geometry')

resolution = 100

row = gdf[gdf.urau_name == 'Verona']
geometry = row.geometry
print(row.bounds.values[0])

def buffer_bounds(row, buffer_multiplier, crs, resolution):
    bbox_coords = tuple(row.bounds.values[0])
    bbox = BBox(bbox=bbox_coords, crs=crs)
    bbox_size = bbox_to_dimensions(bbox, resolution=resolution)
    bbox_size
    # Compute the parameters of the georeference
    dirx = (bbox_coords[2] - bbox_coords[0]) / bbox_size[1] # pixel size in the x-direction in map units/pixel
    diry = -(bbox_coords[3] - bbox_coords[1]) / bbox_size[0] # pixel size in the y-direction in map units, almost always negative
    bbox_coords_b = [bbox_coords[0]-dirx,
                    bbox_coords[1]+buffer_multiplier*diry,
                    bbox_coords[2]+dirx,
                    bbox_coords[3]-buffer_multiplier*diry]
    bbox_b = BBox(bbox=bbox_coords_b, crs=crs)
    bbox_size_b = bbox_to_dimensions(bbox_b, resolution=resolution)
    bbox_size_b
    return bbox_b, bbox_size_b

def polygon_to_mask(coords, geometry, crs):
    bbox = BBox(bbox=coords, crs=crs)
    bbox_size = bbox_to_dimensions(bbox, resolution=resolution)
    # Compute the parameters of the georeference
    dirx = (coords[2] - coords[0]) / bbox_size[1] # pixel size in the x-direction in map units/pixel
    diry = -(coords[3] - coords[1]) / bbox_size[0] # pixel size in the y-direction in map units, almost always negative
    x0 = coords[0] # x-coordinate of the center of the upper left pixel
    y0 = coords[3] # y-coordinate of the center of the upper left pixel
    transform = rasterio.Affine(dirx, 0, x0, 
                                0, diry, y0)
    rasterized = rasterio.features.rasterize(
            [geometry],
            out_shape=bbox_size,
            fill=0,
            default_value=1,
            transform=transform,
            all_touched=True,
            dtype='float64'
        )
    return rasterized
bbox,bbox_size = buffer_bounds(row, 2, CRS.WGS84, 100)
coords = bbox.min_x, bbox.min_y, bbox.max_x, bbox.max_y
rasterized = polygon_to_mask(coords, row.geometry.item(), CRS.WGS84)
# utils.plot_image(rasterized)
# Out:
# [10.8768365 45.349396  11.1243715 45.5417995]

# %%
# plot bounding box
print(f"Image shape at {100} m resolution: {bbox_size} pixels") 
IPython.display.GeoJSON(shapely.geometry.box(*bbox).__geo_interface__)
# Out:
# Image shape at 100 m resolution: (190, 223) pixels

# %% [markdown]
# ## Collections

# %%
# copy CollectionId from FAIRiCube catalog https://catalog.fairicube.eu/
collection_id_clc = "cbdba844-f86d-41dc-95ad-b3f7f12535e9"
collection_name_clc="CLC"
end_point = "https://creodias.sentinel-hub.com"
# define collection
data_collection_clc = DataCollection.define_byoc(collection_id_clc, name=collection_name_clc, service_url = end_point)
data_collection_clc
# Out:
# <DataCollection.CLC: DataCollectionDefinition(
#   api_id: byoc-cbdba844-f86d-41dc-95ad-b3f7f12535e9
#   catalog_id: byoc-cbdba844-f86d-41dc-95ad-b3f7f12535e9
#   wfs_id: byoc-cbdba844-f86d-41dc-95ad-b3f7f12535e9
#   service_url: https://creodias.sentinel-hub.com
#   collection_type: BYOC
#   collection_id: cbdba844-f86d-41dc-95ad-b3f7f12535e9
#   is_timeless: False
#   has_cloud_coverage: False
# )>

# %% [markdown]
# ## Prepare request
# Define evalscript and an helper function to get the SentinelHub requests

# %%
evalscript = """
//VERSION=3
function setup() {
  return {
    input: ["CLC", "dataMask"],
    output: {
      bands: 1,
      sampleType: "UINT16"
    }
  }
}

function evaluatePixel(sample) {
    if(sample.CLC < 45 && sample.CLC > 39) {
        return [sample.CLC*0];
    } else {
        return [sample.CLC/sample.CLC]
    }
}

"""
input_data = [
        SentinelHubRequest.input_data(
            data_collection=DataCollection.CLC,
            time_interval=("2017-01-01", "2019-01-01") # select only CLC 2018
        ),
    ]
def sentinelhub_request(evalscript, input_data, geometry, bbox, bbox_size, config):
    request = SentinelHubRequest(
        evalscript=evalscript,
        input_data=input_data,
        responses=[SentinelHubRequest.output_response("default", MimeType.PNG)],
        bbox=bbox,
        size=bbox_size,
        geometry = geometry,
        config=config,
        )
    return request

# %%
from scipy import ndimage
# data processing function
def avg_distance_to_water(data_array,mask_array):
    res = ndimage.distance_transform_edt(data_array)
    return res, np.mean(res, where=mask_array)

# %%
bbox,bbox_size = buffer_bounds(row, 2, CRS.WGS84, 100)
coords = bbox.min_x, bbox.min_y, bbox.max_x, bbox.max_y
mask_array = polygon_to_mask(coords, row.geometry.item(), CRS.WGS84)
request = sentinelhub_request(evalscript,input_data, bbox, bbox_size, config)
try:
    data = request.get_data()[0]
    res, avg = avg_distance_to_water(data, mask_array)
    utils.plot_image(res)
except:
    print("an error occurred")

# %%
# create temporary df
df_all = pd.DataFrame(columns=['URAU_CODE', 'CLC', 'count'])
# skipped Oulu/Uleåborg
for row in gdf_city.itertuples():
    print("Downloading " + row.URAU_NAME + " data")
    
    #------------------------------------------
    geometry_gdf = row.geometry
    # get only buffer zone
    geometry_b, bbox_b, bbox_size_b = utils.buffer_geometry(geometry_gdf, CRS.WGS84, buffer_size=1, resolution=resolution)
    
    bbox_subsize_b = utils.bbox_optimal_subsize(bbox_size_b)
    if(bbox_subsize_b == 1 ):
        request = sentinelhub_request(evalscript,input_data, bbox_b, bbox_size_b, config)
        try:
            data = request.get_data()[0]
        except:
            print("an error occurred")
            break
        # do something with the data
        mask_array = polygon_to_mask(bbox_b, geometry)
        res, avg = avg_distance_to_water(data, mask_array)
    else:
        print("Splitting bounding box in", (bbox_subsize_b,bbox_subsize_b), " subgrid")
        bbox_split = BBoxSplitter([bbox_b], CRS.WGS84, bbox_subsize_b)
        # create a list of requests
        bbox_list = bbox_split.get_bbox_list()
        sh_requests = [sentinelhub_request(evalscript,input_data, subbbox, bbox_to_dimensions(subbbox, resolution=resolution), config) for 
                       subbbox in bbox_list]
        tiles = []
        error=False
        for req,subbbox in zip(sh_requests,bbox_list):
            try:
                tile = req.get_data()[0]
            except:
                print("an error occurred")
                error=True
                break
            # do something with the data
            tiles.append(tile)
        if(error):
            break
        # TODO 
        data = combine_tiles(bbox_list, tiles)
        mask_array = polygon_to_mask(bbox_b, geometry)
        res, avg = avg_distance_to_water(data, mask_array)
    print("---------------------------")
# Out:
# Downloading Mons data
#   URAU_CODE CLC  count
# 1    BE009C  41  25656
# ---------------------------
# Downloading Genève data
#   URAU_CODE CLC count
# 1    CH003C  41  6682
# ---------------------------
# Downloading Basel data
#   URAU_CODE CLC  count
# 0    CH004C  40  25084
# ---------------------------
# Downloading Lausanne data
#   URAU_CODE CLC  count
# 0    CH005C  41  15687
# ---------------------------
# Downloading La Rochelle data
#   URAU_CODE CLC  count
# 1    FR054C  44  10560
# ---------------------------
# Downloading Lorient data
#   URAU_CODE CLC  count
# 0    FR055C  43  22642
# ---------------------------
# Downloading Cherbourg-en-Cotentin data
#   URAU_CODE CLC  count
# 0    FR056C  44  11911
# ---------------------------
# Downloading Béziers data
# No water features
#   URAU_CODE CLC  count
# 0    FR056C  44  11911
# ---------------------------
# Downloading Kortrijk data
# No water features
#   URAU_CODE CLC  count
# 0    FR056C  44  11911
# ---------------------------
# Downloading Oostende data
#   URAU_CODE CLC count
# 1    BE011C  44    23
# ---------------------------
# Downloading Mechelen data
#   URAU_CODE CLC count
# 1    BE012C  43   608
# ---------------------------
# Downloading Mouscron data
# No water features
#   URAU_CODE CLC count
# 1    BE012C  43   608
# ---------------------------
# Downloading Linz data
#   URAU_CODE CLC  count
# 1    AT003C  41  11289
# ---------------------------
# Downloading Salzburg data
#   URAU_CODE CLC  count
# 0    AT004C  40  16114
# ---------------------------
# Downloading Innsbruck data
#   URAU_CODE CLC  count
# 0    AT005C  40  10913
# ---------------------------
# Downloading Fréjus data
#   URAU_CODE CLC  count
# 1    FR049C  44  47071
# ---------------------------
# Downloading Chambéry data
# No water features
#   URAU_CODE CLC  count
# 1    FR049C  44  47071
# ---------------------------
# Downloading Mantes-la-Jolie data
#   URAU_CODE CLC count
# 1    FR051C  41  9809
# ---------------------------
# Downloading Douai data
#   URAU_CODE CLC count
# 0    FR052C  41  2585
# ---------------------------
# Downloading La Louvière data
#   URAU_CODE CLC count
# 0    BE014C  40  2403
# ---------------------------
# Downloading Verviers data
# No water features
#   URAU_CODE CLC count
# 0    BE014C  40  2403
# ---------------------------
# Downloading Luzern data
#   URAU_CODE CLC  count
# 0    CH006C  41  30167
# ---------------------------
# Downloading Winterthur data
# No water features
#   URAU_CODE CLC  count
# 0    CH006C  41  30167
# ---------------------------
# Downloading Lugano data
#   URAU_CODE CLC  count
# 0    CH008C  41  26835
# ---------------------------
# Downloading Zadar data
# Splitting bounding box in (3, 3)  subgrid
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 0    CH008C  41  26835
# ---------------------------
# Downloading Budapest data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 0    CH008C  41  26835
# ---------------------------
# Downloading Sofia data
# Splitting bounding box in (3, 3)  subgrid
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 0    CH008C  41  26835
# ---------------------------
# Downloading Osijek data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 0    CH008C  41  26835
# ---------------------------
# Downloading Split data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 0    CH008C  41  26835
# ---------------------------
# Downloading Veszprém data
# No water features
#   URAU_CODE CLC  count
# 0    CH008C  41  26835
# ---------------------------
# Downloading Békéscsaba data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 0    CH008C  41  26835
# ---------------------------
# Downloading Kaposvár data
#   URAU_CODE CLC  count
# 0    HU015C  41  24746
# ---------------------------
# Downloading Eger data
#   URAU_CODE CLC count
# 0    HU016C  41   294
# ---------------------------
# Downloading Plovdiv data
#   URAU_CODE CLC  count
# 1    BG002C  41  14696
# ---------------------------
# Downloading Varna data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 1    BG002C  41  14696
# ---------------------------
# Downloading Burgas data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 1    BG002C  41  14696
# ---------------------------
# Downloading Waterford data
#   URAU_CODE CLC  count
# 3    IE005C  44  45521
# ---------------------------
# Downloading Reims data
# No water features
#   URAU_CODE CLC  count
# 3    IE005C  44  45521
# ---------------------------
# Downloading Napoli data
# Splitting bounding box in (3, 3)  subgrid
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 3    IE005C  44  45521
# ---------------------------
# Downloading Torino data
#   URAU_CODE CLC  count
# 0    IT004C  40  26687
# ---------------------------
# Downloading Székesfehérvár data
#   URAU_CODE CLC  count
# 0    HU009C  41  29345
# ---------------------------
# Downloading Szombathely data
#   URAU_CODE CLC count
# 0    HU010C  41  7013
# ---------------------------
# Downloading Szolnok data
#   URAU_CODE CLC  count
# 1    HU011C  41  32834
# ---------------------------
# Downloading Tatabánya data
#   URAU_CODE CLC count
# 0    HU012C  41  6533
# ---------------------------
# Downloading Pleven data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC count
# 0    HU012C  41  6533
# ---------------------------
# Downloading Ruse data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC count
# 0    HU012C  41  6533
# ---------------------------
# Downloading Orléans data
#   URAU_CODE CLC count
# 1    FR018C  41  6347
# ---------------------------
# Downloading Nancy data
#   URAU_CODE CLC count
# 0    FR019C  41  5398
# ---------------------------
# Downloading Dijon data
#   URAU_CODE CLC count
# 0    FR020C  41  3199
# ---------------------------
# Downloading Clermont-Ferrand data
# No water features
#   URAU_CODE CLC count
# 0    FR020C  41  3199
# ---------------------------
# Downloading Espoo/Esbo data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC count
# 0    FR020C  41  3199
# ---------------------------
# Downloading Paris data
# Splitting bounding box in (3, 3)  subgrid
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC count
# 0    FR020C  41  3199
# ---------------------------
# Downloading Lyon data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC count
# 0    FR020C  41  3199
# ---------------------------
# Downloading Melun data
#   URAU_CODE CLC  count
# 0    FR053C  40  16037
# ---------------------------
# Downloading Vidin data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 0    FR053C  40  16037
# ---------------------------
# Downloading Pula/Pola data
#   URAU_CODE CLC  count
# 0    HR006C  44  81344
# ---------------------------
# Downloading Brest data
#   URAU_CODE CLC  count
# 0    FR034C  44  13117
# ---------------------------
# Downloading Amiens data
#   URAU_CODE CLC  count
# 0    FR035C  41  13797
# ---------------------------
# Downloading Dunkerque data
#   URAU_CODE CLC  count
# 2    FR036C  44  13128
# ---------------------------
# Downloading Perpignan data
# No water features
#   URAU_CODE CLC  count
# 2    FR036C  44  13128
# ---------------------------
# Downloading Stara Zagora data
# Splitting bounding box in (3, 3)  subgrid
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 2    FR036C  44  13128
# ---------------------------
# Downloading Miskolc data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 2    FR036C  44  13128
# ---------------------------
# Downloading Nyíregyháza data
#   URAU_CODE CLC  count
# 0    HU003C  41  26330
# ---------------------------
# Downloading Vantaa/Vanda data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 0    HU003C  41  26330
# ---------------------------
# Downloading Sliven data
# Splitting bounding box in (3, 3)  subgrid
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 0    HU003C  41  26330
# ---------------------------
# Downloading Dobrich data
# No water features
#   URAU_CODE CLC  count
# 0    HU003C  41  26330
# ---------------------------
# Downloading Turku/Åbo data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 0    HU003C  41  26330
# ---------------------------
# Downloading Le Havre data
#   URAU_CODE CLC  count
# 2    FR022C  44  28973
# ---------------------------
# Downloading Saint-Étienne data
#   URAU_CODE CLC  count
# 0    FR023C  41  18037
# ---------------------------
# Downloading Angers data
#   URAU_CODE CLC  count
# 1    FR024C  41  16879
# ---------------------------
# Downloading Lahti/Lahtis data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 1    FR024C  41  16879
# ---------------------------
# Downloading Kuopio data
# Splitting bounding box in (5, 5)  subgrid
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 1    FR024C  41  16879
# ---------------------------
# Downloading Schweinfurt data
#   URAU_CODE CLC count
# 1    DE074C  41  5729
# ---------------------------
# Downloading Greifswald data
#   URAU_CODE CLC  count
# 1    DE075C  44  19774
# ---------------------------
# Downloading Shumen data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 1    DE075C  44  19774
# ---------------------------
# Downloading Mulhouse data
#   URAU_CODE CLC count
# 0    FR025C  41   234
# ---------------------------
# Downloading Annecy data
#   URAU_CODE CLC  count
# 0    FR038C  41  33359
# ---------------------------
# Downloading Besançon data
#   URAU_CODE CLC  count
# 0    FR039C  40  12267
# ---------------------------
# Downloading Bayonne data
#   URAU_CODE CLC count
# 2    FR040C  44  2018
# ---------------------------
# Downloading La Seyne-sur-Mer data
#   URAU_CODE CLC  count
# 0    FR041C  44  47143
# ---------------------------
# Downloading Pau data
#   URAU_CODE CLC count
# 0    FR042C  41  1020
# ---------------------------
# Downloading Larnaka data
#   URAU_CODE CLC  count
# 0    CY002C  44  17408
# ---------------------------
# Downloading Klagenfurt data
#   URAU_CODE CLC  count
# 0    AT006C  41  14378
# ---------------------------
# Downloading Pécs data
#   URAU_CODE CLC count
# 0    HU004C  41  5441
# ---------------------------
# Downloading Debrecen data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC count
# 0    HU004C  41  5441
# ---------------------------
# Downloading Jyväskylä data
# Splitting bounding box in (3, 3)  subgrid
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC count
# 0    HU004C  41  5441
# ---------------------------
# Downloading Avignon data
#   URAU_CODE CLC   count
# 0    FR043C  40  101467
# ---------------------------
# Downloading Bruxelles/Brussel data
#   URAU_CODE CLC count
# 0    BE001C  40  3150
# ---------------------------
# Downloading Antwerpen data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC count
# 0    BE001C  40  3150
# ---------------------------
# Downloading St. Gallen data
# No water features
#   URAU_CODE CLC count
# 0    BE001C  40  3150
# ---------------------------
# Downloading Biel/Bienne data
#   URAU_CODE CLC count
# 1    CH010C  41  5200
# ---------------------------
# Downloading Veliko Tarnovo data
# Splitting bounding box in (3, 3)  subgrid
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC count
# 1    CH010C  41  5200
# ---------------------------
# Downloading Pernik data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC count
# 1    CH010C  41  5200
# ---------------------------
# Downloading Yambol data
#   URAU_CODE CLC  count
# 0    BG013C  41  23000
# ---------------------------
# Downloading Reykjavík data
# Splitting bounding box in (3, 3)  subgrid
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 0    BG013C  41  23000
# ---------------------------
# Downloading Lens data
# No water features
#   URAU_CODE CLC  count
# 0    BG013C  41  23000
# ---------------------------
# Downloading Gießen data
#   URAU_CODE CLC count
# 0    DE054C  41  1686
# ---------------------------
# Downloading Lüneburg data
# No water features
#   URAU_CODE CLC count
# 0    DE054C  41  1686
# ---------------------------
# Downloading Bayreuth data
# No water features
#   URAU_CODE CLC count
# 0    DE054C  41  1686
# ---------------------------
# Downloading Solingen data
#   URAU_CODE CLC count
# 0    DE094C  41  2630
# ---------------------------
# Downloading Osnabrück data
#   URAU_CODE CLC count
# 0    DE095C  41  2469
# ---------------------------
# Downloading Speyer data
#   URAU_CODE CLC  count
# 1    DE077C  41  19277
# ---------------------------
# Downloading Passau data
#   URAU_CODE CLC count
# 1    DE078C  41   544
# ---------------------------
# Downloading Leverkusen data
#   URAU_CODE CLC count
# 1    DE097C  41  8870
# ---------------------------
# Downloading Oldenburg (Oldenburg) data
#   URAU_CODE CLC  count
# 0    DE098C  41  12575
# ---------------------------
# Downloading Neuss data
#   URAU_CODE CLC count
# 1    DE099C  41  8178
# ---------------------------
# Downloading Heilbronn data
#   URAU_CODE CLC  count
# 0    DE107C  40  13176
# ---------------------------
# Downloading Remscheid data
#   URAU_CODE CLC count
# 0    DE108C  41  9666
# ---------------------------
# Downloading Offenbach am Main data
#   URAU_CODE CLC  count
# 0    DE109C  40  13148
# ---------------------------
# Downloading Lemesos data
#   URAU_CODE CLC  count
# 1    CY003C  44  14592
# ---------------------------
# Downloading Ústí nad Labem data
#   URAU_CODE CLC  count
# 1    CZ005C  41  19861
# ---------------------------
# Downloading Olomouc data
#   URAU_CODE CLC count
# 0    CZ006C  41  7939
# ---------------------------
# Downloading Havířov data
#   URAU_CODE CLC count
# 0    CZ015C  41  3030
# ---------------------------
# Downloading Most data
#   URAU_CODE CLC  count
# 0    CZ016C  41  33816
# ---------------------------
# Downloading Karviná data
#   URAU_CODE CLC  count
# 0    CZ017C  41  24281
# ---------------------------
# Downloading Hamburg data
# Splitting bounding box in (5, 5)  subgrid
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 0    CZ017C  41  24281
# ---------------------------
# Downloading München data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 0    CZ017C  41  24281
# ---------------------------
# Downloading Leipzig data
#   URAU_CODE CLC  count
# 1    DE008C  41  72985
# ---------------------------
# Downloading Hannover data
#   URAU_CODE CLC  count
# 0    DE013C  41  20699
# ---------------------------
# Downloading Flensburg data
#   URAU_CODE CLC count
# 1    DE049C  44  8205
# ---------------------------
# Downloading Wiesbaden data
#   URAU_CODE CLC count
# 1    DE019C  41  4039
# ---------------------------
# Downloading Göttingen data
# No water features
#   URAU_CODE CLC count
# 1    DE019C  41  4039
# ---------------------------
# Downloading Mülheim a.d.Ruhr data
#   URAU_CODE CLC count
# 0    DE021C  40  6522
# ---------------------------
# Downloading Moers data
#   URAU_CODE CLC count
# 0    DE022C  41  7894
# ---------------------------
# Downloading Augsburg data
#   URAU_CODE CLC count
# 0    DE031C  41  1464
# ---------------------------
# Downloading Bonn data
#   URAU_CODE CLC  count
# 0    DE032C  40  60263
# ---------------------------
# Downloading Rostock data
#   URAU_CODE CLC  count
# 2    DE040C  44  23676
# ---------------------------
# Downloading Marburg data
# No water features
#   URAU_CODE CLC  count
# 2    DE040C  44  23676
# ---------------------------
# Downloading Wolfsburg data
#   URAU_CODE CLC  count
# 1    DE104C  41  10398
# ---------------------------
# Downloading Bremerhaven data
#   URAU_CODE CLC  count
# 2    DE105C  43  44071
# ---------------------------
# Downloading Celle data
#   URAU_CODE CLC count
# 0    DE057C  41  3070
# ---------------------------
# Downloading Aschaffenburg data
#   URAU_CODE CLC  count
# 0    DE058C  40  18118
# ---------------------------
# Downloading Bamberg data
#   URAU_CODE CLC count
# 0    DE059C  40   376
# ---------------------------
# Downloading Köln data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC count
# 0    DE059C  40   376
# ---------------------------
# Downloading Frankfurt am Main data
#   URAU_CODE CLC  count
# 0    DE005C  40  40265
# ---------------------------
# Downloading Dessau-Roßlau data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 0    DE005C  40  40265
# ---------------------------
# Downloading Duisburg data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 0    DE005C  40  40265
# ---------------------------
# Downloading Bottrop data
#   URAU_CODE CLC count
# 0    DE106C  41  7464
# ---------------------------
# Downloading Liberec data
# No water features
#   URAU_CODE CLC count
# 0    DE106C  41  7464
# ---------------------------
# Downloading České Budějovice data
#   URAU_CODE CLC  count
# 0    CZ008C  41  22820
# ---------------------------
# Downloading Hamm data
# No water features
#   URAU_CODE CLC  count
# 0    CZ008C  41  22820
# ---------------------------
# Downloading Herne data
#   URAU_CODE CLC count
# 0    DE093C  40  2946
# ---------------------------
# Downloading Essen data
#   URAU_CODE CLC  count
# 1    DE006C  41  28449
# ---------------------------
# Downloading Stuttgart data
#   URAU_CODE CLC  count
# 0    DE007C  40  10966
# ---------------------------
# Downloading Praha data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 0    DE007C  40  10966
# ---------------------------
# Downloading Hradec Králové data
#   URAU_CODE CLC count
# 0    CZ009C  41  4247
# ---------------------------
# Downloading Chomutov-Jirkov data
#   URAU_CODE CLC  count
# 0    CZ018C  41  11313
# ---------------------------
# Downloading Darmstadt data
# No water features
#   URAU_CODE CLC  count
# 0    CZ018C  41  11313
# ---------------------------
# Downloading Stralsund data
#   URAU_CODE CLC  count
# 1    DE068C  42  28392
# ---------------------------
# Downloading Friedrichshafen data
#   URAU_CODE CLC  count
# 0    DE069C  41  11851
# ---------------------------
# Downloading Offenburg data
#   URAU_CODE CLC count
# 0    DE070C  41  3830
# ---------------------------
# Downloading Dresden data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC count
# 0    DE070C  41  3830
# ---------------------------
# Downloading Dortmund data
#   URAU_CODE CLC  count
# 0    DE010C  41  10904
# ---------------------------
# Downloading Nürnberg data
#   URAU_CODE CLC count
# 0    DE014C  41  3088
# ---------------------------
# Downloading Trier data
#   URAU_CODE CLC  count
# 0    DE024C  40  38345
# ---------------------------
# Downloading Plauen data
# No water features
#   URAU_CODE CLC  count
# 0    DE024C  40  38345
# ---------------------------
# Downloading Karlsruhe data
#   URAU_CODE CLC  count
# 1    DE033C  41  27184
# ---------------------------
# Downloading Mönchengladbach data
#   URAU_CODE CLC count
# 0    DE034C  41   262
# ---------------------------
# Downloading Mainz data
#   URAU_CODE CLC  count
# 0    DE035C  40  45371
# ---------------------------
# Downloading Kaiserslautern data
# No water features
#   URAU_CODE CLC  count
# 0    DE035C  40  45371
# ---------------------------
# Downloading Iserlohn data
# No water features
#   URAU_CODE CLC  count
# 0    DE035C  40  45371
# ---------------------------
# Downloading Esslingen am Neckar data
#   URAU_CODE CLC count
# 0    DE043C  40  2936
# ---------------------------
# Downloading Konstanz data
#   URAU_CODE CLC  count
# 1    DE051C  41  27833
# ---------------------------
# Downloading Neumünster data
#   URAU_CODE CLC  count
# 0    DE052C  41  12594
# ---------------------------
# Downloading Neubrandenburg data
#   URAU_CODE CLC   count
# 0    DE061C  41  228452
# ---------------------------
# Downloading Ingolstadt data
#   URAU_CODE CLC  count
# 1    DE112C  41  15288
# ---------------------------
# Downloading Kiel data
#   URAU_CODE CLC  count
# 2    DE036C  44  28203
# ---------------------------
# Downloading Saarbrücken data
#   URAU_CODE CLC count
# 0    DE037C  41   155
# ---------------------------
# Downloading Mannheim data
#   URAU_CODE CLC count
# 1    DE081C  41    59
# ---------------------------
# Downloading Gelsenkirchen data
# No water features
#   URAU_CODE CLC count
# 1    DE081C  41    59
# ---------------------------
# Downloading Münster data
#   URAU_CODE CLC  count
# 0    DE083C  41  17098
# ---------------------------
# Downloading Gera data
# No water features
#   URAU_CODE CLC  count
# 0    DE083C  41  17098
# ---------------------------
# Downloading Heidelberg data
#   URAU_CODE CLC  count
# 0    DE100C  40  25130
# ---------------------------
# Downloading Paderborn data
#   URAU_CODE CLC  count
# 0    DE101C  41  34170
# ---------------------------
# Downloading Würzburg data
#   URAU_CODE CLC count
# 0    DE102C  40  7825
# ---------------------------
# Downloading Recklinghausen data
# No water features
#   URAU_CODE CLC count
# 0    DE102C  40  7825
# ---------------------------
# Downloading Brno data
#   URAU_CODE CLC  count
# 0    CZ002C  41  21473
# ---------------------------
# Downloading Lübeck data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 0    CZ002C  41  21473
# ---------------------------
# Downloading Hagen data
#   URAU_CODE CLC  count
# 1    DE090C  41  17444
# ---------------------------
# Downloading Kassel data
#   URAU_CODE CLC count
# 1    DE091C  41  2920
# ---------------------------
# Downloading Berlin data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC count
# 1    DE091C  41  2920
# ---------------------------
# Downloading Görlitz data
#   URAU_CODE CLC  count
# 0    DE071C  41  86558
# ---------------------------
# Downloading Sankt Augustin data
# No water features
#   URAU_CODE CLC  count
# 0    DE071C  41  86558
# ---------------------------
# Downloading Neu-Ulm data
#   URAU_CODE CLC count
# 0    DE073C  41  4534
# ---------------------------
# Downloading Düsseldorf data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC count
# 0    DE073C  41  4534
# ---------------------------
# Downloading Hanau data
#   URAU_CODE CLC  count
# 0    DE044C  40  11092
# ---------------------------
# Downloading Pardubice data
#   URAU_CODE CLC count
# 0    CZ010C  41   314
# ---------------------------
# Downloading Zlín data
#   URAU_CODE CLC count
# 0    CZ011C  41  3715
# ---------------------------
# Downloading Freiburg im Breisgau data
#   URAU_CODE CLC count
# 0    DE025C  41  4450
# ---------------------------
# Downloading Regensburg data
#   URAU_CODE CLC  count
# 0    DE026C  40  24075
# ---------------------------
# Downloading Frankfurt (Oder) data
#   URAU_CODE CLC  count
# 1    DE027C  41  28575
# ---------------------------
# Downloading Wilhelmshaven data
#   URAU_CODE CLC  count
# 1    DE045C  44  20872
# ---------------------------
# Downloading Ludwigsburg data
#   URAU_CODE CLC count
# 0    DE046C  40  4590
# ---------------------------
# Downloading Chemnitz data
# No water features
#   URAU_CODE CLC count
# 0    DE046C  40  4590
# ---------------------------
# Downloading Bochum data
#   URAU_CODE CLC  count
# 0    DE015C  41  11153
# ---------------------------
# Downloading Bielefeld data
# No water features
#   URAU_CODE CLC  count
# 0    DE015C  41  11153
# ---------------------------
# Downloading Fulda data
# No water features
#   URAU_CODE CLC  count
# 0    DE015C  41  11153
# ---------------------------
# Downloading Kempten (Allgäu) data
# No water features
#   URAU_CODE CLC  count
# 0    DE015C  41  11153
# ---------------------------
# Downloading Braunschweig data
#   URAU_CODE CLC  count
# 0    DE085C  41  11298
# ---------------------------
# Downloading Ostrava data
#   URAU_CODE CLC  count
# 0    CZ003C  41  23454
# ---------------------------
# Downloading Brandenburg an der Havel data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 0    CZ003C  41  23454
# ---------------------------
# Downloading Aachen data
# No water features
#   URAU_CODE CLC  count
# 0    CZ003C  41  23454
# ---------------------------
# Downloading Krefeld data
#   URAU_CODE CLC  count
# 1    DE087C  41  13338
# ---------------------------
# Downloading Oberhausen data
# No water features
#   URAU_CODE CLC  count
# 1    DE087C  41  13338
# ---------------------------
# Downloading Rīga data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 1    DE087C  41  13338
# ---------------------------
# Downloading Liepāja data
#   URAU_CODE CLC  count
# 2    LV002C  44  25283
# ---------------------------
# Downloading Plzeň data
#   URAU_CODE CLC  count
# 0    CZ004C  41  15293
# ---------------------------
# Downloading Ulm data
#   URAU_CODE CLC count
# 0    DE110C  41   203
# ---------------------------
# Downloading Pforzheim data
# No water features
#   URAU_CODE CLC count
# 0    DE110C  41   203
# ---------------------------
# Downloading Kladno data
# No water features
#   URAU_CODE CLC count
# 0    DE110C  41   203
# ---------------------------
# Downloading Weimar data
# No water features
#   URAU_CODE CLC count
# 0    DE110C  41   203
# ---------------------------
# Downloading Schwerin data
#   URAU_CODE CLC   count
# 0    DE029C  41  362637
# ---------------------------
# Downloading Erfurt data
#   URAU_CODE CLC  count
# 0    DE030C  41  34397
# ---------------------------
# Downloading Jelgava data
#   URAU_CODE CLC count
# 1    LV003C  41  2251
# ---------------------------
# Downloading Daugavpils data
#   URAU_CODE CLC  count
# 1    LV004C  41  46187
# ---------------------------
# Downloading Bremen data
# Splitting bounding box in (3, 3)  subgrid
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 1    LV004C  41  46187
# ---------------------------
# Downloading Karlovy Vary data
#   URAU_CODE CLC count
# 0    CZ013C  41   644
# ---------------------------
# Downloading Jihlava data
#   URAU_CODE CLC count
# 0    CZ014C  41  3325
# ---------------------------
# Downloading Landshut data
#   URAU_CODE CLC count
# 1    DE064C  41  7385
# ---------------------------
# Downloading Sindelfingen data
# No water features
#   URAU_CODE CLC count
# 1    DE064C  41  7385
# ---------------------------
# Downloading Rosenheim data
#   URAU_CODE CLC count
# 1    DE066C  41  5774
# ---------------------------
# Downloading Frankenthal (Pfalz) data
#   URAU_CODE CLC count
# 1    DE067C  41   683
# ---------------------------
# Downloading Potsdam data
#   URAU_CODE CLC   count
# 1    DE038C  41  141643
# ---------------------------
# Downloading Koblenz data
#   URAU_CODE CLC  count
# 0    DE039C  40  63531
# ---------------------------
# Downloading Wetzlar data
#   URAU_CODE CLC count
# 0    DE076C  41  6861
# ---------------------------
# Downloading Tübingen data
#   URAU_CODE CLC count
# 0    DE047C  41  4530
# ---------------------------
# Downloading Villingen-Schwenningen data
# No water features
#   URAU_CODE CLC count
# 0    DE047C  41  4530
# ---------------------------
# Downloading Ludwigshafen am Rhein data
#   URAU_CODE CLC count
# 1    DE096C  41  9734
# ---------------------------
# Downloading Halle an der Saale data
#   URAU_CODE CLC  count
# 0    DE017C  41  16559
# ---------------------------
# Downloading Magdeburg data
#   URAU_CODE CLC  count
# 1    DE018C  41  41509
# ---------------------------
# Downloading Salzgitter data
#   URAU_CODE CLC  count
# 1    DE114C  41  30815
# ---------------------------
# Downloading Reutlingen data
# No water features
#   URAU_CODE CLC  count
# 1    DE114C  41  30815
# ---------------------------
# Downloading Sintra data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 1    DE114C  41  30815
# ---------------------------
# Downloading Zielona Góra data
#   URAU_CODE CLC count
# 0    PL018C  40  6417
# ---------------------------
# Downloading Vila Franca de Xira data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC count
# 0    PL018C  40  6417
# ---------------------------
# Downloading Athina data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC count
# 0    PL018C  40  6417
# ---------------------------
# Downloading Thessaloniki data
#   URAU_CODE CLC  count
# 0    EL002C  44  26453
# ---------------------------
# Downloading Pátra data
#   URAU_CODE CLC  count
# 0    EL003C  44  12658
# ---------------------------
# Downloading Irakleio data
#   URAU_CODE CLC  count
# 0    EL004C  44  10331
# ---------------------------
# Downloading Jelenia Góra data
#   URAU_CODE CLC count
# 0    PL019C  41  3981
# ---------------------------
# Downloading Nowy Sącz data
#   URAU_CODE CLC count
# 1    PL020C  41  2688
# ---------------------------
# Downloading Stavanger data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC count
# 1    PL020C  41  2688
# ---------------------------
# Downloading Warszawa data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC count
# 1    PL020C  41  2688
# ---------------------------
# Downloading Łódź data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC count
# 1    PL020C  41  2688
# ---------------------------
# Downloading Bergen data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC count
# 1    PL020C  41  2688
# ---------------------------
# Downloading Katowice data
#   URAU_CODE CLC  count
# 0    PL010C  41  16258
# ---------------------------
# Downloading Białystok data
#   URAU_CODE CLC count
# 0    PL011C  41  6205
# ---------------------------
# Downloading Paredes data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC count
# 0    PL011C  41  6205
# ---------------------------
# Downloading Suwałki data
#   URAU_CODE CLC count
# 0    PL021C  41  7183
# ---------------------------
# Downloading Póvoa de Varzim data
#   URAU_CODE CLC  count
# 0    PT013C  44  14984
# ---------------------------
# Downloading Badajoz data
# Splitting bounding box in (4, 4)  subgrid
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 0    PT013C  44  14984
# ---------------------------
# Downloading Logroño data
#   URAU_CODE CLC count
# 1    ES018C  41  5715
# ---------------------------
# Downloading Bilbao data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC count
# 1    ES018C  41  5715
# ---------------------------
# Downloading Ruda Śląska data
#   URAU_CODE CLC count
# 0    PL059C  41   944
# ---------------------------
# Downloading Rybnik data
#   URAU_CODE CLC  count
# 0    PL060C  41  58323
# ---------------------------
# Downloading Konin data
#   URAU_CODE CLC   count
# 0    PL022C  41  129283
# ---------------------------
# Downloading Żory data
#   URAU_CODE CLC count
# 0    PL023C  41  8931
# ---------------------------
# Downloading Braga data
#   URAU_CODE CLC  count
# 0    PT003C  40  23129
# ---------------------------
# Downloading Oradea data
#   URAU_CODE CLC  count
# 1    RO006C  41  11804
# ---------------------------
# Downloading Bacău data
#   URAU_CODE CLC  count
# 1    RO007C  41  24492
# ---------------------------
# Downloading Fürth data
# No water features
#   URAU_CODE CLC  count
# 1    RO007C  41  24492
# ---------------------------
# Downloading Cottbus data
#   URAU_CODE CLC count
# 0    DE117C  41  5343
# ---------------------------
# Downloading Siegen data
# No water features
#   URAU_CODE CLC count
# 0    DE117C  41  5343
# ---------------------------
# Downloading Koszalin data
#   URAU_CODE CLC  count
# 0    PL028C  41  12455
# ---------------------------
# Downloading Słupsk data
# No water features
#   URAU_CODE CLC  count
# 0    PL028C  41  12455
# ---------------------------
# Downloading Jastrzębie-Zdrój data
# No water features
#   URAU_CODE CLC  count
# 0    PL028C  41  12455
# ---------------------------
# Downloading Larisa data
#   URAU_CODE CLC  count
# 0    EL005C  40  23518
# ---------------------------
# Downloading Volos data
#   URAU_CODE CLC  count
# 0    EL006C  44  18199
# ---------------------------
# Downloading Ioannina data
#   URAU_CODE CLC  count
# 0    EL007C  41  58127
# ---------------------------
# Downloading Kavala data
#   URAU_CODE CLC  count
# 0    EL008C  44  63526
# ---------------------------
# Downloading Kalamata data
#   URAU_CODE CLC  count
# 1    EL009C  44  11227
# ---------------------------
# Downloading Ponta Delgada data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 1    EL009C  44  11227
# ---------------------------
# Downloading Aveiro data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 1    EL009C  44  11227
# ---------------------------
# Downloading Kraków data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 1    EL009C  44  11227
# ---------------------------
# Downloading Siedlce data
#   URAU_CODE CLC count
# 0    PL031C  41  3451
# ---------------------------
# Downloading Córdoba data
# Splitting bounding box in (3, 3)  subgrid
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC count
# 0    PL031C  41  3451
# ---------------------------
# Downloading Alicante/Alacant data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC count
# 0    PL031C  41  3451
# ---------------------------
# Downloading Trondheim data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC count
# 0    PL031C  41  3451
# ---------------------------
# Downloading Lisboa data
# Splitting bounding box in (3, 3)  subgrid
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC count
# 0    PL031C  41  3451
# ---------------------------
# Downloading Arad data
#   URAU_CODE CLC  count
# 0    RO008C  40  34566
# ---------------------------
# Downloading Wrocław data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 0    RO008C  40  34566
# ---------------------------
# Downloading Lugo data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 0    RO008C  40  34566
# ---------------------------
# Downloading San Fernando data
#   URAU_CODE CLC  count
# 1    ES029C  44  14689
# ---------------------------
# Downloading Girona data
# No water features
#   URAU_CODE CLC  count
# 1    ES029C  44  14689
# ---------------------------
# Downloading Bergisch Gladbach data
# No water features
#   URAU_CODE CLC  count
# 1    ES029C  44  14689
# ---------------------------
# Downloading Kielce data
#   URAU_CODE CLC count
# 0    PL012C  41  2293
# ---------------------------
# Downloading Toruń data
#   URAU_CODE CLC  count
# 0    PL013C  40  66130
# ---------------------------
# Downloading Olsztyn data
#   URAU_CODE CLC  count
# 1    PL014C  41  64436
# ---------------------------
# Downloading Timişoara data
#   URAU_CODE CLC count
# 1    RO003C  41   191
# ---------------------------
# Downloading Craiova data
#   URAU_CODE CLC count
# 1    RO004C  41  1422
# ---------------------------
# Downloading Brăila data
#   URAU_CODE CLC  count
# 0    RO005C  40  41361
# ---------------------------
# Downloading Częstochowa data
#   URAU_CODE CLC count
# 0    PL024C  41  2902
# ---------------------------
# Downloading Hildesheim data
# No water features
#   URAU_CODE CLC count
# 0    PL024C  41  2902
# ---------------------------
# Downloading Witten data
#   URAU_CODE CLC  count
# 0    DE121C  41  10939
# ---------------------------
# Downloading Zwickau data
# No water features
#   URAU_CODE CLC  count
# 0    DE121C  41  10939
# ---------------------------
# Downloading Trikala data
#   URAU_CODE CLC count
# 0    EL010C  40  2951
# ---------------------------
# Downloading Tychy data
#   URAU_CODE CLC  count
# 0    PL061C  41  12766
# ---------------------------
# Downloading Wałbrzych data
# No water features
#   URAU_CODE CLC  count
# 0    PL061C  41  12766
# ---------------------------
# Downloading Radom data
#   URAU_CODE CLC count
# 0    PL025C  41   295
# ---------------------------
# Downloading Płock data
#   URAU_CODE CLC  count
# 0    PL026C  40  56004
# ---------------------------
# Downloading Kalisz data
#   URAU_CODE CLC count
# 0    PL027C  41   838
# ---------------------------
# Downloading Piotrków Trybunalski data
#   URAU_CODE CLC count
# 0    PL032C  41  7128
# ---------------------------
# Downloading Lubin data
# No water features
#   URAU_CODE CLC count
# 0    PL032C  41  7128
# ---------------------------
# Downloading Piła data
#   URAU_CODE CLC  count
# 0    PL034C  41  20957
# ---------------------------
# Downloading Inowrocław data
# No water features
#   URAU_CODE CLC  count
# 0    PL034C  41  20957
# ---------------------------
# Downloading Serres data
#   URAU_CODE CLC count
# 0    EL011C  40  9103
# ---------------------------
# Downloading Katerini data
#   URAU_CODE CLC count
# 1    EL012C  44  4580
# ---------------------------
# Downloading Xanthi data
# No water features
#   URAU_CODE CLC count
# 1    EL012C  44  4580
# ---------------------------
# Downloading Chania data
#   URAU_CODE CLC count
# 0    EL014C  44  7318
# ---------------------------
# Downloading Rzeszów data
#   URAU_CODE CLC  count
# 0    PL015C  41  12123
# ---------------------------
# Downloading Bucureşti data
#   URAU_CODE CLC  count
# 1    RO001C  41  65572
# ---------------------------
# Downloading Cluj-Napoca data
#   URAU_CODE CLC count
# 0    RO002C  40  6893
# ---------------------------
# Downloading Ostrowiec Świętokrzyski data
# No water features
#   URAU_CODE CLC count
# 0    RO002C  40  6893
# ---------------------------
# Downloading Gniezno data
# No water features
#   URAU_CODE CLC count
# 0    RO002C  40  6893
# ---------------------------
# Downloading Stargard data
# No water features
#   URAU_CODE CLC count
# 0    RO002C  40  6893
# ---------------------------
# Downloading Ostrów Wielkopolski data
#   URAU_CODE CLC count
# 0    PL039C  41  2448
# ---------------------------
# Downloading Przemyśl data
#   URAU_CODE CLC  count
# 0    PL040C  40  11393
# ---------------------------
# Downloading Vigo data
#   URAU_CODE CLC  count
# 1    ES022C  44  56236
# ---------------------------
# Downloading Gijón data
#   URAU_CODE CLC  count
# 1    ES023C  44  26044
# ---------------------------
# Downloading Elbląg data
#   URAU_CODE CLC count
# 0    PL063C  40  9613
# ---------------------------
# Downloading Włocławek data
#   URAU_CODE CLC   count
# 0    PL064C  40  108305
# ---------------------------
# Downloading Tarnów data
#   URAU_CODE CLC  count
# 1    PL065C  41  13904
# ---------------------------
# Downloading Porto data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 1    PL065C  41  13904
# ---------------------------
# Downloading Erlangen data
#   URAU_CODE CLC count
# 0    DE123C  41  5289
# ---------------------------
# Downloading Wuppertal data
#   URAU_CODE CLC count
# 0    DE124C  41  3109
# ---------------------------
# Downloading Cuenca data
# Splitting bounding box in (4, 4)  subgrid
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC count
# 0    DE124C  41  3109
# ---------------------------
# Downloading Eivissa data
#   URAU_CODE CLC  count
# 0    ES089C  44  11884
# ---------------------------
# Downloading Madrid data
# Splitting bounding box in (3, 3)  subgrid
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 0    ES089C  44  11884
# ---------------------------
# Downloading Faro data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 0    ES089C  44  11884
# ---------------------------
# Downloading Opole data
#   URAU_CODE CLC  count
# 1    PL016C  41  22953
# ---------------------------
# Downloading Granada data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 1    PL016C  41  22953
# ---------------------------
# Downloading Elche/Elx data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 1    PL016C  41  22953
# ---------------------------
# Downloading Linares data
# No water features
#   URAU_CODE CLC  count
# 1    PL016C  41  22953
# ---------------------------
# Downloading Santa Cruz de Tenerife data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 1    PL016C  41  22953
# ---------------------------
# Downloading Gorzów Wielkopolski data
#   URAU_CODE CLC  count
# 0    PL017C  40  13677
# ---------------------------
# Downloading Chorzów data
#   URAU_CODE CLC count
# 0    PL066C  41  2993
# ---------------------------
# Downloading Legnica data
#   URAU_CODE CLC  count
# 0    PL067C  41  10073
# ---------------------------
# Downloading Grudziądz data
#   URAU_CODE CLC  count
# 1    PL068C  41  21252
# ---------------------------
# Downloading Lorca data
# Splitting bounding box in (3, 3)  subgrid
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 1    PL068C  41  21252
# ---------------------------
# Downloading Bytom data
#   URAU_CODE CLC count
# 0    PL057C  41  5167
# ---------------------------
# Downloading Bielsko-Biała data
#   URAU_CODE CLC count
# 0    PL058C  41  6302
# ---------------------------
# Downloading San Sebastián/Donostia data
#   URAU_CODE CLC  count
# 1    ES063C  44  18122
# ---------------------------
# Downloading Alcalá de Henares data
# No water features
#   URAU_CODE CLC  count
# 1    ES063C  44  18122
# ---------------------------
# Downloading Almería data
# Splitting bounding box in (5, 5)  subgrid
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 1    ES063C  44  18122
# ---------------------------
# Downloading Palma de Mallorca data
# Splitting bounding box in (3, 3)  subgrid
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 1    ES063C  44  18122
# ---------------------------
# Downloading Alcoy data
# No water features
#   URAU_CODE CLC  count
# 1    ES063C  44  18122
# ---------------------------
# Downloading Marseille data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 1    ES063C  44  18122
# ---------------------------
# Downloading Galway data
#   URAU_CODE CLC  count
# 3    IE004C  44  16283
# ---------------------------
# Downloading Århus data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 3    IE004C  44  16283
# ---------------------------
# Downloading Ávila data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 3    IE004C  44  16283
# ---------------------------
# Downloading Colmar data
# No water features
#   URAU_CODE CLC  count
# 3    IE004C  44  16283
# ---------------------------
# Downloading Martigues data
#   URAU_CODE CLC  count
# 2    FR066C  44  40668
# ---------------------------
# Downloading Meaux data
#   URAU_CODE CLC count
# 0    FR067C  41  6264
# ---------------------------
# Downloading Bourges data
#   URAU_CODE CLC count
# 0    FR068C  41  5863
# ---------------------------
# Downloading Saint-Brieuc data
#   URAU_CODE CLC count
# 0    FR069C  41  6823
# ---------------------------
# Downloading Málaga data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC count
# 0    FR069C  41  6823
# ...
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 0    IT023C  44  11022
# ---------------------------
# Downloading Perugia data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 0    IT023C  44  11022
# ---------------------------
# Downloading Avellino data
# No water features
#   URAU_CODE CLC  count
# 0    IT023C  44  11022
# ---------------------------
# Downloading Pordenone data
# No water features
#   URAU_CODE CLC  count
# 0    IT023C  44  11022
# ---------------------------
# Downloading Lecco data
#   URAU_CODE CLC  count
# 0    IT052C  41  42763
# ---------------------------
# Downloading Almelo data
#   URAU_CODE CLC count
# 0    NL003C  41  6309
# ---------------------------
# Downloading Almere data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC count
# 0    NL003C  41  6309
# ---------------------------
# Downloading Alphen aan den Rijn data
#   URAU_CODE CLC count
# 0    NL005C  41  8168
# ---------------------------
# Downloading Leeuwarden data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC count
# 0    NL005C  41  8168
# ---------------------------
# Downloading Leiden data
#   URAU_CODE CLC count
# 1    NL029C  44  1938
# ---------------------------
# Downloading Lelystad data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC count
# 1    NL029C  44  1938
# ---------------------------
# Downloading Maastricht data
#   URAU_CODE CLC count
# 1    NL031C  41  8400
# ---------------------------
# Downloading Viseu data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC count
# 1    NL031C  41  8400
# ---------------------------
# Downloading Pisa data
#   URAU_CODE CLC  count
# 1    IT040C  44  23951
# ---------------------------
# Downloading Treviso data
#   URAU_CODE CLC count
# 1    IT041C  41  1477
# ---------------------------
# Downloading Varese data
#   URAU_CODE CLC  count
# 0    IT042C  41  42388
# ---------------------------
# Downloading Amersfoort data
# No water features
#   URAU_CODE CLC  count
# 0    IT042C  41  42388
# ---------------------------
# Downloading Apeldoorn data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 0    IT042C  41  42388
# ---------------------------
# Downloading Arnhem data
#   URAU_CODE CLC  count
# 1    NL008C  41  13510
# ---------------------------
# Downloading Assen data
#   URAU_CODE CLC count
# 0    NL009C  41  4769
# ---------------------------
# Downloading Bergen op Zoom data
#   URAU_CODE CLC   count
# 1    NL010C  41  104393
# ---------------------------
# Downloading Modena data
#   URAU_CODE CLC  count
# 0    IT029C  41  12127
# ---------------------------
# Downloading Poznań data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 0    IT029C  41  12127
# ---------------------------
# Downloading Zamość data
# No water features
#   URAU_CODE CLC  count
# 0    IT029C  41  12127
# ---------------------------
# Downloading Chełm data
# No water features
#   URAU_CODE CLC  count
# 0    IT029C  41  12127
# ---------------------------
# Downloading Pabianice data
# No water features
#   URAU_CODE CLC  count
# 0    IT029C  41  12127
# ---------------------------
# Downloading L'Aquila data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 0    IT029C  41  12127
# ---------------------------
# Downloading Alessandria data
#   URAU_CODE CLC  count
# 0    IT079C  40  45400
# ---------------------------
# Downloading Gela data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 0    IT079C  40  45400
# ---------------------------
# Downloading Bagheria data
#   URAU_CODE CLC count
# 0    IT061C  44  7405
# ---------------------------
# Downloading Anzio data
#   URAU_CODE CLC  count
# 0    IT062C  44  15675
# ---------------------------
# Downloading Głogów data
#   URAU_CODE CLC  count
# 0    PL044C  40  19314
# ---------------------------
# Downloading Stalowa Wola data
#   URAU_CODE CLC  count
# 0    PL045C  40  15416
# ---------------------------
# Downloading Tomaszów Mazowiecki data
#   URAU_CODE CLC count
# 0    PL046C  40  9265
# ---------------------------
# Downloading Reggio di Calabria data
#   URAU_CODE CLC  count
# 0    IT024C  44  23189
# ---------------------------
# Downloading Middelburg        data
#   URAU_CODE CLC count
# 3    NL032C  44  3047
# ---------------------------
# Downloading Nijmegen data
#   URAU_CODE CLC  count
# 1    NL033C  41  10324
# ---------------------------
# Downloading Nissewaard data
#   URAU_CODE CLC  count
# 1    NL034C  41  18334
# ---------------------------
# Downloading Oss data
#   URAU_CODE CLC  count
# 1    NL035C  41  29606
# ---------------------------
# Downloading Purmerend data
# No water features
#   URAU_CODE CLC  count
# 1    NL035C  41  29606
# ---------------------------
# Downloading Gdańsk data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 1    NL035C  41  29606
# ---------------------------
# Downloading Łomża data
# No water features
#   URAU_CODE CLC  count
# 1    NL035C  41  29606
# ---------------------------
# Downloading Leszno data
# No water features
#   URAU_CODE CLC  count
# 1    NL035C  41  29606
# ---------------------------
# Downloading Oslo data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 1    NL035C  41  29606
# ---------------------------
# Downloading Altamura data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 1    NL035C  41  29606
# ---------------------------
# Downloading Breda data
#   URAU_CODE CLC count
# 0    NL011C  41  6089
# ---------------------------
# Downloading Deventer data
#   URAU_CODE CLC count
# 1    NL012C  41  8479
# ---------------------------
# Downloading Stockholm data
# Splitting bounding box in (3, 3)  subgrid
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC count
# 1    NL012C  41  8479
# ---------------------------
# Downloading Malmö data
#   URAU_CODE CLC  count
# 0    SE003C  44  37321
# ---------------------------
# Downloading Västerås data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 0    SE003C  44  37321
# ---------------------------
# Downloading Piatra Neamţ data
#   URAU_CODE CLC  count
# 1    RO011C  41  14252
# ---------------------------
# Downloading Cǎlǎraşi data
#   URAU_CODE CLC  count
# 1    RO012C  41  13997
# ---------------------------
# Downloading Giurgiu data
#   URAU_CODE CLC count
# 1    RO013C  41   536
# ---------------------------
# Downloading Alba Iulia data
#   URAU_CODE CLC  count
# 0    RO014C  40  23089
# ---------------------------
# Downloading Göteborg data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 0    RO014C  40  23089
# ---------------------------
# Downloading Focşani data
#   URAU_CODE CLC count
# 0    RO015C  41  6091
# ---------------------------
# Downloading Târgu Jiu data
#   URAU_CODE CLC  count
# 1    RO016C  41  15995
# ---------------------------
# Downloading Tulcea data
#   URAU_CODE CLC  count
# 1    RO017C  41  37017
# ---------------------------
# Downloading Södertälje data
# Splitting bounding box in (3, 3)  subgrid
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 1    RO017C  41  37017
# ---------------------------
# Downloading Norrköping data
# Splitting bounding box in (4, 4)  subgrid
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 1    RO017C  41  37017
# ---------------------------
# Downloading Baia Mare data
#   URAU_CODE CLC  count
# 0    RO029C  41  12310
# ---------------------------
# Downloading Buzău data
#   URAU_CODE CLC count
# 1    RO030C  41  1644
# ---------------------------
# Downloading Umeå data
# Splitting bounding box in (4, 4)  subgrid
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC count
# 1    RO030C  41  1644
# ---------------------------
# Downloading Bistriţa data
# No water features
#   URAU_CODE CLC count
# 1    RO030C  41  1644
# ---------------------------
# Downloading Constanţa data
#   URAU_CODE CLC  count
# 1    RO023C  44  75503
# ---------------------------
# Downloading Jönköping data
# Splitting bounding box in (3, 3)  subgrid
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 1    RO023C  44  75503
# ---------------------------
# Downloading Žilina data
#   URAU_CODE CLC  count
# 1    SK006C  41  27642
# ---------------------------
# Downloading Trnava data
#   URAU_CODE CLC count
# 0    SK007C  41  2782
# ---------------------------
# Downloading Helsingborg data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC count
# 0    SK007C  41  2782
# ---------------------------
# Downloading Lund data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC count
# 0    SK007C  41  2782
# ---------------------------
# Downloading Târgovişte data
#   URAU_CODE CLC count
# 0    RO018C  40  9278
# ---------------------------
# Downloading Slatina data
#   URAU_CODE CLC  count
# 0    RO019C  41  30027
# ---------------------------
# Downloading Bârlad data
#   URAU_CODE CLC count
# 0    RO020C  41   577
# ---------------------------
# Downloading Roman data
#   URAU_CODE CLC count
# 1    RO021C  41  2100
# ---------------------------
# Downloading Satu Mare data
#   URAU_CODE CLC  count
# 0    RO031C  40  19366
# ---------------------------
# Downloading Botoşani data
#   URAU_CODE CLC count
# 0    RO032C  41  2306
# ---------------------------
# Downloading Iaşi data
#   URAU_CODE CLC  count
# 0    RO024C  41  12707
# ---------------------------
# Downloading Borås data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 0    RO024C  41  12707
# ---------------------------
# Downloading Râmnicu Vâlcea data
#   URAU_CODE CLC  count
# 1    RO033C  41  54912
# ---------------------------
# Downloading Banská Bystrica data
# No water features
#   URAU_CODE CLC  count
# 1    RO033C  41  54912
# ---------------------------
# Downloading Galaţi data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC  count
# 1    RO033C  41  54912
# ---------------------------
# Downloading Trenčín data
#   URAU_CODE CLC  count
# 0    SK008C  40  11154
# ---------------------------
# Downloading Suceava data
#   URAU_CODE CLC count
# 1    RO034C  41  4360
# ---------------------------
# Downloading Drobeta-Turnu Severin data
#   URAU_CODE CLC   count
# 0    RO035C  40  108481
# ---------------------------
# Downloading Uppsala data
# Splitting bounding box in (4, 4)  subgrid
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC   count
# 0    RO035C  40  108481
# ---------------------------
# Downloading Ljubljana data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC   count
# 0    RO035C  40  108481
# ---------------------------
# Downloading Nitra data
#   URAU_CODE CLC count
# 0    SK004C  40  3820
# ---------------------------
# Downloading Prešov data
# No water features
#   URAU_CODE CLC count
# 0    SK004C  40  3820
# ---------------------------
# Downloading Linköping data
# Splitting bounding box in (3, 3)  subgrid
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC count
# 0    SK004C  40  3820
# ---------------------------
# Downloading Braşov data
# No water features
#   URAU_CODE CLC count
# 0    SK004C  40  3820
# ---------------------------
# Downloading Ploieşti data
#   URAU_CODE CLC count
# 0    RO027C  40  2236
# ---------------------------
# Downloading Maribor data
#   URAU_CODE CLC count
# 1    SI002C  41   560
# ---------------------------
# Downloading Sibiu data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC count
# 1    SI002C  41   560
# ---------------------------
# Downloading Piteşti data
#   URAU_CODE CLC count
# 1    RO028C  41  1019
# ---------------------------
# Downloading Bratislava data
# Splitting bounding box in (2, 2)  subgrid
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC count
# 1    RO028C  41  1019
# ---------------------------
# Downloading Târgu Mureş data
#   URAU_CODE CLC count
# 0    RO010C  40  8882
# ---------------------------
# Downloading Košice data
#   URAU_CODE CLC count
# 0    SK002C  41  2964
# ---------------------------
# Downloading Örebro data
# Splitting bounding box in (3, 3)  subgrid
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
# No water features
#   URAU_CODE CLC count
# 0    SK002C  41  2964
# ---------------------------

# %%
# post processing

# optionally retrieve data from temporary csv
# df = pd.read_csv("clc400.csv", dtype={'Unnamed: 0': 'float64', 'URAU_CODE': 'str', 'CLC': 'str', 'count': 'float64'})
# df_all = df[["URAU_CODE","CLC","count"]]
df_sum = df_all.groupby(["URAU_CODE","CLC"]).sum(numeric_only=True).reset_index()
norm = df_sum.groupby(["CLC"])[['count']].transform(lambda x: (x/x.max())).rename(columns={'count': 'norm'})
df_sum['norm'] = norm
df_sum
# Out:
#     URAU_CODE CLC    count      norm
# 0      AT001C  40  75590.0  0.463359
# 1      AT001C  41  64261.0  0.177205
# 2      AT003C  40  56961.0  0.349165
# 3      AT003C  41  11289.0  0.031130
# 4      AT004C  40  16114.0  0.098777
# ..        ...  ..      ...       ...
# 608    SK004C  40   3820.0  0.023416
# 609    SK006C  40   8301.0  0.050884
# 610    SK006C  41  27642.0  0.076225
# 611    SK007C  41   2782.0  0.007672
# 612    SK008C  40  11154.0  0.068373
#
# [613 rows x 4 columns]

# %%
# save to sqlite
conn = sqlite3.connect(dbfile) 
df_sum.to_sql(table_name,conn,if_exists='replace',index=False)
conn.commit()
conn.close()

# %%
#check database
query = """ 
  SELECT *
         FROM  c_urban_cube_clc
         LIMIT 10
         """
con = sqlite3.connect(dbfile)
df= pd.read_sql(query, con)
# Be sure to close the connection
con.close()
print (df)
print ("END")
# Out:
#   URAU_CODE CLC    count      norm
# 0    AT001C  40  75590.0  0.463359
# 1    AT001C  41  64261.0  0.177205
# 2    AT003C  40  56961.0  0.349165
# 3    AT003C  41  11289.0  0.031130
# 4    AT004C  40  16114.0  0.098777
# 5    AT005C  40  10913.0  0.066896
# 6    AT006C  41  14378.0  0.039648
# 7    BE001C  40   3150.0  0.019309
# 8    BE003C  40  47219.0  0.289447
# 9    BE003C  41  17110.0  0.047182
# END
