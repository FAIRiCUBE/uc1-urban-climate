# %% [markdown]
# # Climate indicators
#
# The notebook titled climate_indicators.ipynb from the FAIRiCUBE Urban Climate Use Case repository focuses on computing and analyzing climate-related indicators for European cities. It serves as a foundational step in understanding urban climate dynamics, which is essential for informed urban planning and climate adaptation strategies.
#
#
# This notebook is designed to break down different climate indicators.
# The datasource are ERA-5 Data on:
# https://cloud.google.com/storage/docs/public-datasets/era5?hl=de
#
# We use this data source because the data is available there in an analysis ready cloud-optimised format.
#
# The selected climate indices are:
# - Number of summer days
# - Number of tropical nights
# - 2m temperature statistics (mean, std, min, max)
# - total precipitation (mean, std, min, max)
#
#
# This notebook is designed to:
# - Access Climate Data: Retrieve gridded climate datasets, such as temperature and humidity, from sources like the Copernicus Climate Data Store.
# - Compute Climate Indicators: Calculate various climate indicators, including:
#     - Average annual temperature
#     - Number of summer days (e.g., days with temperatures above 25°C)
#     - Number of tropical nights (e.g., nights with temperatures above 20°C)
#     - Universal Thermal Climate Index (UTCI) metrics
# - Spatial Analysis: Aggregate and analyze these indicators at the city level, aligning with urban boundaries to provide city-specific insights.
# - Data Integration: Prepare the computed indicators for integration with other datasets, such as socio-economic or land use data, facilitating comprehensive urban climate assessments.

# %%
# reading LIBS
import sqlalchemy as sa # conection to the database
from datetime import datetime, timedelta
#import timezonefinder
from configparser import ConfigParser
import matplotlib.pyplot as plt
import pandas as pd
import xarray as xr      
import fsspec

print ("lib done")
# Out:
# lib done

# %%
from dask.distributed import Client, performance_report
client = Client()  # Connect to distributed cluster and override default
client
# Out:
# <Client: 'tcp://127.0.0.1:43551' processes=4 threads=8, memory=30.00 GiB>

# %%
# check data:

fs = fsspec.filesystem('gs')
fs.ls('gs://gcp-public-data-arco-era5/ar/1959-2022-full_37-1h-0p25deg-chunk-1.zarr-v2/')


arco_era5 = xr.open_zarr(
    'gs://gcp-public-data-arco-era5/ar/1959-2022-full_37-1h-0p25deg-chunk-1.zarr-v2', 
    # chunks={'time': 24*30},
    consolidated=True,
    drop_variables=["10m_u_component_of_wind",  
    "10m_v_component_of_wind",
    # "2m_temperature",
    "angle_of_sub_gridscale_orography",
    "anisotropy_of_sub_gridscale_orography",
    "geopotential",
    "geopotential_at_surface",
    "high_vegetation_cover",
    "lake_cover",
    "lake_depth",
    "land_sea_mask",
    "low_vegetation_cover",
    "mean_sea_level_pressure",
    "sea_ice_cover",
    "sea_surface_temperature",
    "slope_of_sub_gridscale_orography",
    "soil_type",
    "specific_humidity",
    "standard_deviation_of_filtered_subgrid_orography",
    "standard_deviation_of_orography",
    "surface_pressure",
    "temperature",
    "toa_incident_solar_radiation",
    "total_cloud_cover",
    "total_column_water_vapour",
    # "total_precipitation",
    "type_of_high_vegetation",
    "type_of_low_vegetation",
    "u_component_of_wind",
    "v_component_of_wind",
    "vertical_velocity"]
)
arco_era5


#for var in arco_era5.data_vars:
#    print(var)
# Out:
# <xarray.Dataset>
# Dimensions:              (time: 552264, latitude: 721, longitude: 1440,
#                           level: 37)
# Coordinates:
#   * latitude             (latitude) float32 90.0 89.75 89.5 ... -89.75 -90.0
#   * level                (level) int64 1 2 3 5 7 10 ... 875 900 925 950 975 1000
#   * longitude            (longitude) float32 0.0 0.25 0.5 ... 359.2 359.5 359.8
#   * time                 (time) datetime64[ns] 1959-01-01 ... 2021-12-31T23:0...
# Data variables:
#     2m_temperature       (time, latitude, longitude) float32 dask.array<chunksize=(1, 721, 1440), meta=np.ndarray>
#     total_precipitation  (time, latitude, longitude) float32 dask.array<chunksize=(1, 721, 1440), meta=np.ndarray>

# %% [markdown]
# ## Testing the data source and data:

# %%
arco_era5['2m_temperature_degree_celcius'].sel(time=slice(start_date, end_date)).sel(longitude=lon_city[0],latitude=lat_city[0], method="ffill")

# %%
# subeset of the big climate data cube:

# select 1 year

##PARAMETER+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++S
## Lux -location: AOI
lat_city=[37.8193869629]  #### y
lon_city=[lon_to_360(-25.7287017223)]   #### x
# subest time: TIME-RANGE
start_date = "2020-12-01"; end_date = "2020-12-31";   # TESTING only on month in 2020
##PARAMETER+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++E
# update values:  # Kelvin to Degree:
arco_era5['2m_temperature_degree_celcius'] = arco_era5['2m_temperature'] - 273.15

# subeset cube:
#arco_era5_2018_luxembourg = arco_era5['2m_temperature'].sel(time=slice(start_date, end_date),longitude=lon_city,latitude=lat_city)
arco_era5_2018_luxembourg = arco_era5['2m_temperature_degree_celcius'].sel(time=slice(start_date, end_date)).sel(longitude=lon_city[0],latitude=lat_city[0], method="ffill")

## calculation of different indicators:


## 1. TEMPERATURE indicicators:

## DAY and NIGHT SET:
START_NIGHT_h = 18  
END_NIGHT_h = 6

START_DAY_h = 6
END_DAY_h = 18


## 1.1 MAX and MIN per DAY and NIGHT:

# --------------------------------------------------------------------------------------------------------------

# --------------------------------------------------------------------------------------------------------------

## 1.1.1 MAX
max_temperature_per_day = arco_era5_2018_luxembourg.resample(time='D').max(dim='time')  # calc max and min temp per day
night_time_range = arco_era5_2018_luxembourg.sel(time=((arco_era5_2018_luxembourg['time.hour'] >= START_NIGHT_h) | (arco_era5_2018_luxembourg['time.hour'] < END_NIGHT_h)))
max_night_temperature_per_day = night_time_range.resample(time='D').max(dim='time') 


## MAX temp NIGHT per YEAR
max_night_temperature_per_year = night_time_range.resample(time='Y').max(dim='time') 
#print("Max Temp [°C] in the night per year:")
#print(max_night_temperature_per_year.time.dt.year.values.item())
#print(max_night_temperature_per_year.values.item())
#print("---")


day_time_range = arco_era5_2018_luxembourg.sel(time=((arco_era5_2018_luxembourg['time.hour'] >= START_DAY_h) | (arco_era5_2018_luxembourg['time.hour'] < END_DAY_h)))
max_day_temperature_per_day = day_time_range.resample(time='D').max(dim='time') 

## MAX temp DAY per YEAR
max_day_temperature_per_year = day_time_range.resample(time='Y').max(dim='time') 
#print("Max Temp [°C] in the day per year:")
#print(max_day_temperature_per_year.time.dt.year.values.item())
#print(max_day_temperature_per_year.values.item())
#print("---")


## 1.1.2 MIN
min_temperature_per_day = arco_era5_2018_luxembourg.resample(time='D').min(dim='time')
#night_time_range = arco_era5_2018_luxembourg.sel(time=((arco_era5_2018_luxembourg['time.hour'] >= START_NIGHT_h) | (arco_era5_2018_luxembourg['time.hour'] < END_NIGHT_h)))
min_night_temperature_per_day = night_time_range.resample(time='D').min(dim='time') 
#day_time_range = arco_era5_2018_luxembourg.sel(time=((arco_era5_2018_luxembourg['time.hour'] >= START_DAY_h) | (arco_era5_2018_luxembourg['time.hour'] < END_DAY_h)))
min_day_temperature_per_day = day_time_range.resample(time='D').min(dim='time') 





## 1.2 Number of tropical nights
# Calculate the number of tropical days per year
#tropical_threshold = 30
#tropical_nights_count_per_year = (max_night_temperature_per_year > tropical_threshold).groupby('time.year').sum()
## Print the result
#print("Number of tropical nights per year:")
#print("---")
##print(tropical_nights_count_per_year['year'].values.item())
##print(tropical_nights_count_per_year.values.item())
#tropical_nights_count_per_year_df = tropical_nights_count_per_year.to_dataframe()
#new_column_names = {'2m_temperature_degree_celcius': 'tropical_nights_count_per_year'}
#tropical_nights_count_per_year_df.rename(columns=new_column_names, inplace=True)


#print(tropical_nights_count_per_year_df)
#print("---")




## 1.3 Number of summer days
#Annual count of days when TX (daily maximum temperature) > 25°C. Let TXij be daily minimum temperature on day i in year j. Count the number of days where TXij > 25 °C.
max_temperature_per_day = arco_era5_2018_luxembourg.resample(time='D').max(dim='time')  # calc max and min temp per day

summer_day_threshold = 25
summer_days_count_per_year = (max_temperature_per_day > summer_day_threshold).groupby('time.year').sum()


#print("Number of summer days per year:")
#print("---")
##print(summer_days_count_per_year['year'].values.item())
##print(summer_days_count_per_year.values.item())
#summer_days_count_per_year_df = summer_days_count_per_year.to_dataframe()
#new_column_names = {'2m_temperature_degree_celcius': 'summer_days_count_per_year'}
#summer_days_count_per_year_df.rename(columns=new_column_names, inplace=True)
#print (summer_days_count_per_year_df)
#print("---")
#

#arco_era5_2018_month = arco_era5_2018.resample(time="1M")
#ds =arco_era5_2018_month

#ds_time_subeset = ds.sel(time=slice(start_date, end_date)) 

#ds = ds_time_subeset

#print (arco_era5_2018_luxembourg)
    

#max_temperature_per_day.plot() 

# #


# Create a single subplot with two columns
fig, ax = plt.subplots(figsize=(12, 5))

# Plot the original temperature data
max_night_temperature_per_day.plot(ax=ax, label='max Temperature per NIGHT', color='blue')
max_day_temperature_per_day.plot(ax=ax, label='max Temperature per DAY', color='red')

min_night_temperature_per_day.plot(ax=ax, label='min Temperature per NIGHT', color='green')
min_day_temperature_per_day.plot(ax=ax, label='min Temperature per DAY', color='black')

ax.set_title('Maximum % Minimum Temperature per Day and Night')
ax.set_xlabel('Time')
ax.set_ylabel('Temperature (°C)')
ax.legend()

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()

print ("done")

# %% [markdown]
# ## Filter datacube by location (city centre point coordinates, time)
#
# TODO remove dependency from db

# %%
from sqlalchemy import create_engine, text

### SET connection to MS-sql server:
################################################## SET postgre-sql connection:

################################################## read database keys:
def config(filename, section='postgresql'):
    # create a parser
    parser = ConfigParser()
    # read config file
    parser.read(filename)

    # get section, default to postgresql
    db = {}
    if parser.has_section(section):
        params = parser.items(section)
        for param in params:
            db[param[0]] = param[1]
    else:
        raise Exception(
            'Section {0} not found in the {1} file'.format(section, filename))

    return db
#config(filename='./../../../../uc1-urban-climate/database.ini')
keys = config(filename='./../../../../uc1-urban-climate/database.ini')

POSTGRESQL_SERVER_NAME=keys['host']
PORT=                  keys['port']
Database_name =        keys['database']
USER =                 keys['user']
PSW =                  keys['password']
##################################################
                                   
engine_postgresql = sa.create_engine('postgresql://'+USER+':'+PSW+ '@'+POSTGRESQL_SERVER_NAME+':'+str(PORT)+ '/' + Database_name)

## testing reading tables from database:

with engine_postgresql.begin() as conn:
    query = text("""SELECT urau_code, _wgs84y, _wgs84x, time_zone_offset
    FROM lut.l_city_urau2021;""")
    city_center_df = pd.read_sql_query(query, conn)
#print (city_center_df)
city_center_df = city_center_df.reset_index()  # make sure indexes pair with number of rows

city_center_df_r = city_center_df#[city_center_df['urau_code'] == 'PT007C']#[66:] #use this to create dataset subset
# city_center_df_r = city_center_df_r.loc[~(city_center_df_r['urau_code'].isin(['PT001C1', 'PT002C1', 'PT003C1']))]
# get city coordinates
# lonlat_list =[["NL005C", 4.640960, 52.113299], ["NL006C", 5.384670, 52.173656], ["NL007C", 5.921886, 52.189884]]
# helper function
def lon_to_360(dlon: float) -> float:
    return ((360 + (dlon % 360)) % 360)

lon_list = [lon_to_360(val) for val in city_center_df_r["_wgs84x"].values.tolist()]
lat_list = city_center_df_r["_wgs84y"].values.tolist()
city_list = city_center_df_r["urau_code"].values.tolist()
target_lon = xr.DataArray(lon_list, dims="city", coords={"city": city_list})
target_lat = xr.DataArray(lat_list, dims="city", coords={"city": city_list})
time_zone_offset = xr.DataArray(city_center_df_r['time_zone_offset'], dims="city", coords={"city": city_list})

# %%
# subest time: TIME-RANGE
start_date = "2018-01-01"
end_date = "2018-12-31"
data = arco_era5.sel(time=slice(start_date, end_date))
## next filter dataframe by city:
data = data.sel(
    longitude=target_lon, 
    latitude=target_lat, method="ffill")

data = xr.merge([data,time_zone_offset])

# ##PARAMETER+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++E
# # update values:  # Kelvin to Degree:
# data['2m_temperature_degree_celcius'] = data['2m_temperature'] - 273.15

# transform into Dask DataFrame to speed up computations
data_df = data.to_dask_dataframe()
data_df = data_df.reset_index()
# select only relevant variables
data_df = data_df[['city', 'time', 'time_zone_offset', 'latitude', 'longitude', '2m_temperature', 'total_precipitation']]

# %% [markdown]
# ## Summer days and tropical nights

# %%
def daytime(x):
    time_local = x.time+timedelta(hours=x.time_zone_offset)
    if(time_local.hour >= 6 and time_local.hour < 18):
        return 1
    else:
        return 0

def night_date(x):
    # assign previous day date to nighttime hours [0..end_night]
    # first adjust to local time
    time_local = x.time+timedelta(hours=x.time_zone_offset)
    if(time_local.hour < 6):
        # date = x.time - timedelta(days=1)
        return x.time - timedelta(days=1)
    else:
        return x.time


data_df['daytime'] = data_df.apply(daytime, axis=1, meta=(None, 'int'))
data_df['time_shifted'] =data_df.apply(night_date, axis=1, meta=(None, 'datetime64[ns]'))
data_df['date'] = data_df.time_shifted.dt.date
# data_df['2m_temperature_degree_celcius'] = data['2m_temperature'] - 273.15

# %%
## calculation of different indicators:
## 1.1 MAX and MIN per DAY and NIGHT:
with performance_report(filename="temp_min_2018.html"):
    # temp_max = data_df.groupby(['city', 'daytime', 'date']).max()
    temp_min = data_df.groupby(['city', 'daytime', 'date']).min()
    # --------------------------------------------------------------------------------------------------------------
    # temp_max_c = temp_max.compute()
    temp_min_c = temp_min.compute()
    # --------------------------------------------------------------------------------------------------------------
client.close()
# Out:
# 2024-02-07 11:47:04,396 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:47:05,804 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:47:07,179 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:47:08,538 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:47:10,209 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:47:11,640 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:47:12,630 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:47:13,325 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:47:15,011 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:47:16,469 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:47:18,282 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:47:18,790 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:47:19,658 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:47:20,483 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:47:21,192 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:47:23,223 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:47:25,113 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:47:27,367 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:47:28,989 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:47:29,492 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:47:31,621 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:47:32,375 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:47:33,847 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:47:35,256 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:47:36,397 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:47:36,600 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:47:38,678 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:47:40,196 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:47:41,777 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:47:43,122 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:47:43,172 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:47:44,251 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:47:44,771 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:47:46,858 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:47:48,016 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:47:48,739 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:47:49,917 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:47:49,924 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:47:52,157 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:47:53,764 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:47:55,109 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:47:56,035 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:47:58,204 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:47:58,780 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:47:59,845 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:48:00,863 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:48:03,670 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:48:03,976 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:48:05,005 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:48:05,408 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:48:06,884 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:48:08,078 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:48:08,572 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:48:09,820 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:48:09,846 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-07 11:48:12,957 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-07 11:48:13,615 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:48:14,685 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-07 11:48:14,900 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:48:16,069 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-07 11:48:16,474 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:48:19,007 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-07 11:48:20,871 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-07 11:48:21,611 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:48:22,147 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-07 11:48:23,575 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:48:24,107 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-07 11:48:24,926 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:48:27,263 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-07 11:48:27,428 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:48:29,298 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:48:30,494 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-07 11:48:32,705 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-07 11:48:33,333 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:48:35,405 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:48:35,426 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-07 11:48:36,794 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:48:37,997 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-07 11:48:40,133 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:48:40,180 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:48:41,400 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:48:43,081 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:48:43,134 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:48:45,851 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:48:46,580 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:48:47,544 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:48:47,747 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:48:49,413 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:48:50,188 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:48:51,060 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:48:52,336 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:48:52,473 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:48:56,037 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:48:56,712 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:48:59,165 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:49:00,110 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:49:01,823 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:49:02,706 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:49:03,816 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:49:05,334 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:49:06,719 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:49:07,352 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:49:08,830 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:49:10,401 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:49:10,732 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:49:13,112 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:49:14,376 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-07 11:49:16,913 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-07 11:49:18,550 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-07 11:49:18,603 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:49:20,181 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:49:21,973 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:49:23,074 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-07 11:49:24,279 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:49:26,512 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-07 11:49:27,558 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:49:28,265 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-07 11:49:29,670 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:49:30,126 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:49:33,079 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:49:33,368 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:49:35,835 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:49:36,809 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:49:37,529 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:49:38,264 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:49:40,199 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:49:40,354 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:49:42,915 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:49:43,412 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:49:44,784 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:49:44,985 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:49:47,631 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:49:47,674 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:49:49,584 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:49:49,708 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:49:52,021 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:49:52,650 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:49:53,970 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:49:54,912 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:49:56,679 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:49:58,623 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:49:59,193 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:00,194 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:02,596 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:02,810 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:04,545 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:05,819 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:05,888 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:08,450 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:09,210 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:10,712 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:12,000 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:13,190 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:14,925 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:15,127 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:17,966 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:19,725 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:21,639 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:21,646 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:22,673 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:23,684 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:24,851 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:25,257 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:27,302 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:28,308 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:28,402 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:30,391 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:30,698 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:31,871 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:32,017 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:32,541 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:34,600 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:36,329 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:36,435 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:37,779 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:38,593 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:39,267 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:40,111 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:41,569 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:41,602 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:42,184 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:43,551 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:44,536 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:46,273 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:47,465 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:47,755 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:49,460 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:49,776 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:50,977 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:51,301 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:52,427 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:53,324 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:53,941 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:55,411 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:55,689 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:58,523 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:58,683 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:50:59,006 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:00,010 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:00,420 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:00,732 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:02,142 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:03,656 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:03,976 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:05,833 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:06,069 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:06,364 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:07,381 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:08,214 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:09,410 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:09,689 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:10,688 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:11,617 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:13,477 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:13,718 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:15,339 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:16,414 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:16,856 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:18,242 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:18,647 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:19,446 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:21,113 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:21,607 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:22,009 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:23,573 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:25,444 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:25,565 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:25,866 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:27,349 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:27,894 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:28,324 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:29,548 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:30,482 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:30,792 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:31,303 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:32,293 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:34,131 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:34,600 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:35,163 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:36,567 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:36,799 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:36,923 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:38,016 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:38,154 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:39,794 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:40,284 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:40,612 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:42,217 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:42,386 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:43,908 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:44,403 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:45,580 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:46,128 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:46,192 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:46,730 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:47,335 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:49,268 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:49,609 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:49,840 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:51,264 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:51,569 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:52,767 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:53,554 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:53,624 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:54,667 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:55,210 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:55,634 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:57,212 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:57,617 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:57,728 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2024-02-07 11:51:59,886 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:00,517 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:00,891 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:01,022 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:02,865 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:03,153 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:03,711 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:04,691 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:04,844 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:05,299 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:05,541 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:07,187 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:08,617 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:09,449 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:10,179 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:10,181 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:10,404 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:12,054 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:12,264 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:12,946 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:13,787 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:15,365 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:15,371 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:16,015 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:17,570 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:19,146 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:19,744 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:21,287 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:21,756 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:22,909 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:23,878 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:24,836 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:26,536 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:28,090 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:28,175 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:29,400 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:31,016 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:31,301 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:32,497 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:33,953 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:35,097 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:35,755 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:37,009 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:38,001 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:40,056 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:40,731 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:41,446 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:43,197 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:43,964 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:44,202 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:45,741 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:47,713 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:48,133 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:48,993 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:50,680 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:52,574 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:53,177 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:54,408 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:55,669 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:56,706 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:58,366 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:58,888 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:52:59,670 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-02-07 11:53:00,033 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:53:03,062 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:53:03,256 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-02-07 11:53:04,489 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 11:53:05,701 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:53:06,071 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-02-07 11:53:08,102 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:53:08,618 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-02-07 11:53:09,820 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:53:10,269 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2024-02-07 11:53:11,651 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:53:14,423 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:53:14,436 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:53:15,310 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2024-02-07 11:53:15,858 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:53:17,479 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:53:19,095 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2024-02-07 11:53:19,624 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:53:21,700 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:53:22,104 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2024-02-07 11:53:23,846 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:53:24,262 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:53:25,584 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:53:25,625 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:53:26,067 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:53:26,967 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2024-02-07 11:53:28,018 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:53:28,728 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:53:29,631 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:53:31,008 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:53:31,297 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-07 11:53:31,546 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 11:53:31,570 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:53:33,275 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 11:53:33,624 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-07 11:53:35,292 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# ...
# 2024-02-07 12:33:57,928 - distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# 2024-02-07 12:33:59,745 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 12:34:00,847 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-07 12:34:03,785 - distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# 2024-02-07 12:34:05,414 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:34:09,105 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 12:34:11,067 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-07 12:34:13,406 - distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# 2024-02-07 12:34:16,941 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:34:17,968 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 12:34:18,324 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-07 12:34:24,043 - distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# 2024-02-07 12:34:25,416 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:34:25,809 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 12:34:28,551 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-07 12:34:33,602 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:34:34,050 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:34:35,795 - distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# 2024-02-07 12:34:38,231 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-07 12:34:41,454 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:34:43,479 - distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# 2024-02-07 12:34:44,206 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:34:50,151 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-07 12:34:50,753 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:34:51,946 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:34:54,600 - distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# 2024-02-07 12:34:57,129 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-07 12:34:58,583 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:35:03,773 - distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# 2024-02-07 12:35:03,934 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:35:06,687 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-07 12:35:08,472 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:35:11,443 - distributed.utils_perf - WARNING - full garbage collections took 21% CPU time recently (threshold: 10%)
# 2024-02-07 12:35:13,718 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 12:35:15,274 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:35:16,754 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-07 12:35:21,700 - distributed.utils_perf - WARNING - full garbage collections took 21% CPU time recently (threshold: 10%)
# 2024-02-07 12:35:23,279 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-07 12:35:25,286 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-07 12:35:25,996 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:35:29,149 - distributed.utils_perf - WARNING - full garbage collections took 21% CPU time recently (threshold: 10%)
# 2024-02-07 12:35:33,697 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:35:34,109 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 12:35:38,268 - distributed.utils_perf - WARNING - full garbage collections took 21% CPU time recently (threshold: 10%)
# 2024-02-07 12:35:39,196 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:35:42,113 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 12:35:42,540 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:35:47,769 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:35:48,038 - distributed.utils_perf - WARNING - full garbage collections took 21% CPU time recently (threshold: 10%)
# 2024-02-07 12:35:52,627 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 12:35:55,342 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:35:55,963 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2024-02-07 12:35:56,023 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:36:03,936 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:36:03,971 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:36:05,123 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-07 12:36:06,847 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2024-02-07 12:36:12,879 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:36:13,551 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:36:15,114 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-07 12:36:18,706 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2024-02-07 12:36:23,390 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:36:24,103 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:36:24,318 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-07 12:36:28,004 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2024-02-07 12:36:31,686 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:36:33,192 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:36:35,455 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2024-02-07 12:36:37,887 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-07 12:36:41,757 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:36:43,259 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:36:45,167 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 12:36:48,765 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2024-02-07 12:36:54,865 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:36:57,289 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:36:57,349 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 12:36:58,772 - distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# 2024-02-07 12:37:04,507 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:37:06,475 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:37:08,682 - distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# 2024-02-07 12:37:10,955 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 12:37:14,489 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:37:16,134 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:37:17,455 - distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# 2024-02-07 12:37:20,676 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 12:37:25,198 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:37:26,131 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:37:27,148 - distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# 2024-02-07 12:37:30,617 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 12:37:32,847 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:37:37,297 - distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# 2024-02-07 12:37:37,880 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 12:37:41,190 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:37:43,098 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:37:47,642 - distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# 2024-02-07 12:37:49,084 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 12:37:50,668 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 12:37:53,563 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:37:56,197 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2024-02-07 12:37:56,373 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 12:38:02,724 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 12:38:04,344 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:38:05,490 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2024-02-07 12:38:06,405 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 12:38:12,650 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 12:38:14,274 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2024-02-07 12:38:18,076 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:38:18,457 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-07 12:38:21,473 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 12:38:25,012 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2024-02-07 12:38:26,853 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:38:28,234 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:38:32,337 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 12:38:36,576 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:38:36,629 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2024-02-07 12:38:41,121 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 12:38:41,291 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:38:44,331 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:38:46,117 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2024-02-07 12:38:50,562 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:38:52,996 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-07 12:38:54,248 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-07 12:38:56,356 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)

# %% [markdown]
# ### Filter summer days and tropical nights and yearly count

# %%
tropical_night_threshold = 20.0 + 273.15
# summer_day_threshold = 25.0 + 273.15
# # select only days and nights above the threshold
# temp_max_c.reset_index(inplace=True)
# summer_days = temp_max_c.loc[(temp_max_c['2m_temperature'] > summer_day_threshold) & (temp_max_c['daytime'] == 1)].reset_index()
# # count how many days pass the threshold per year
# summer_days_count = summer_days.groupby('city').count()

temp_min_c.reset_index(inplace=True)
tropical = temp_min_c.loc[(temp_min_c['2m_temperature'] > tropical_night_threshold) & (temp_min_c['daytime'] == 0)].reset_index()
tropical_count = tropical.groupby(['city', 'daytime']).count()

# add result to the list of cities and set result to 0 for cities that do not have tropical nights/summer days
# zero is a valid value too!
# summer_days_all = pd.merge(city_center_df_r, summer_days_count['2m_temperature'], how='left', left_on='urau_code', right_on='city').fillna(0)
tropical_nights_all = pd.merge(city_center_df_r, tropical_count['2m_temperature'], how='left', left_on='urau_code', right_on='city').fillna(0)

# %%
year = '2018'
# summer_days_count['year'] = year
# summer_days_count.reset_index()[['city', 'index', 'year']].to_csv('summer_days_2018.csv')
# tropical_count['year'] = year
# tropical_count.reset_index()[['city', 'index', 'year']].to_csv('tropical_count_2018.csv')
# summer_days_all
tropical_nights_all
# Out:
#      index urau_code    _wgs84y    _wgs84x  time_zone_offset  2m_temperature
# 0        0    ES019C  43.284187  -2.973099                 1            49.0
# 1        1    CH012C  47.178167   8.525289                 1             1.0
# 2        2    BG018C  43.283887  23.610568                 2             4.0
# 3        3    IT050C  40.913821  14.788222                 1            22.0
# 4        4    BG014C  41.891262  25.596173                 2            17.0
# ..     ...       ...        ...        ...               ...             ...
# 724    724    RO010C  46.541113  24.556075                 2             0.0
# 725    725    SE006C  59.944869  17.716293                 1             3.0
# 726    726    SI001C  46.071022  14.495290                 1             0.0
# 727    727    RO028C  44.855644  24.859411                 2             0.0
# 728    728    SK001C  48.148833  17.119074                 1            11.0
#
# [729 rows x 6 columns]

# %% [markdown]
# ### Save into the database

# %%
##################################
## cu_* tables mandatory columns:
# city_code,
# parameter, 
# parameter_id, 
# parameter_value, 
# year, 
# city_code_version, 
# lineage, 
# datasource
table_name = 'cu_city_era5_summer_days'
schema_name = 'cube'

summer_days_all.rename( columns= {'urau_code': 'city_code',
                         '2m_temperature': 'parameter_value'}, inplace=True)
summer_days_all['year'] = year
summer_days_all['parameter'] = 'Count of summer days (>25 degrees) per year per city, based on 5th gen. ECMWF Atmospheric Reanalysis model'
summer_days_all['parameter_id'] = 'city_era5_summer_days_count'
summer_days_all['lineage'] = 'https://github.com/FAIRiCUBE/uc1-urban-climate/blob/master/notebooks/dev/f04_climate_data/climate_indicators.ipynb'
summer_days_all['datasource'] = 'https://cloud.google.com/storage/docs/public-datasets/era5'
summer_days_all.drop(columns=['index', '_wgs84x', '_wgs84y', 'time_zone_offset'], inplace=True)
summer_days_all
# Out:
#     city_code  parameter_value  year  \
# 0      ES019C              2.0  2018
# 1      CH012C             68.0  2018
# 2      BG018C            131.0  2018
# 3      IT050C            101.0  2018
# 4      BG014C            142.0  2018
# ..        ...              ...   ...
# 724    RO010C            105.0  2018
# 725    SE006C             35.0  2018
# 726    SI001C             46.0  2018
# 727    RO028C             88.0  2018
# 728    SK001C            107.0  2018
#
#                                              parameter  \
# 0    Count of summer days (>25 degrees) per year pe...
# 1    Count of summer days (>25 degrees) per year pe...
# 2    Count of summer days (>25 degrees) per year pe...
# 3    Count of summer days (>25 degrees) per year pe...
# 4    Count of summer days (>25 degrees) per year pe...
# ..                                                 ...
# 724  Count of summer days (>25 degrees) per year pe...
# 725  Count of summer days (>25 degrees) per year pe...
# 726  Count of summer days (>25 degrees) per year pe...
# 727  Count of summer days (>25 degrees) per year pe...
# 728  Count of summer days (>25 degrees) per year pe...
#
#                     parameter_id  \
# 0    city_era5_summer_days_count
# 1    city_era5_summer_days_count
# 2    city_era5_summer_days_count
# 3    city_era5_summer_days_count
# 4    city_era5_summer_days_count
# ..                           ...
# 724  city_era5_summer_days_count
# 725  city_era5_summer_days_count
# 726  city_era5_summer_days_count
# 727  city_era5_summer_days_count
# 728  city_era5_summer_days_count
#
#                                                lineage  \
# 0    https://github.com/FAIRiCUBE/uc1-urban-climate...
# 1    https://github.com/FAIRiCUBE/uc1-urban-climate...
# 2    https://github.com/FAIRiCUBE/uc1-urban-climate...
# 3    https://github.com/FAIRiCUBE/uc1-urban-climate...
# 4    https://github.com/FAIRiCUBE/uc1-urban-climate...
# ..                                                 ...
# 724  https://github.com/FAIRiCUBE/uc1-urban-climate...
# 725  https://github.com/FAIRiCUBE/uc1-urban-climate...
# 726  https://github.com/FAIRiCUBE/uc1-urban-climate...
# 727  https://github.com/FAIRiCUBE/uc1-urban-climate...
# 728  https://github.com/FAIRiCUBE/uc1-urban-climate...
#
#                                             datasource
# 0    https://cloud.google.com/storage/docs/public-d...
# 1    https://cloud.google.com/storage/docs/public-d...
# 2    https://cloud.google.com/storage/docs/public-d...
# 3    https://cloud.google.com/storage/docs/public-d...
# 4    https://cloud.google.com/storage/docs/public-d...
# ..                                                 ...
# 724  https://cloud.google.com/storage/docs/public-d...
# 725  https://cloud.google.com/storage/docs/public-d...
# 726  https://cloud.google.com/storage/docs/public-d...
# 727  https://cloud.google.com/storage/docs/public-d...
# 728  https://cloud.google.com/storage/docs/public-d...
#
# [729 rows x 7 columns]

# %%
summer_days_all.to_sql(table_name, engine_postgresql, schema=schema_name, if_exists='replace')
# Out:
# 729

# %%
##################################
## cu_* tables mandatory columns:
# city_code,
# parameter, 
# parameter_id, 
# parameter_value, 
# year, 
# city_code_version, 
# lineage, 
# datasource
table_name = 'cu_city_era5_tropical_nights'
schema_name = 'cube'
tropical = tropical_nights_all
tropical.rename( columns= {'city': 'city_code',
                  '2m_temperature': 'parameter_value'}, inplace=True)
tropical['year'] = year
tropical['parameter'] = 'Count of tropical nights (min. temperature >20 degrees) per year per city, based on 5th gen. ECMWF Atmospheric Reanalysis model'
tropical['parameter_id'] = 'city_era5_tropical_nights_count'
tropical['lineage'] = 'https://github.com/FAIRiCUBE/uc1-urban-climate/blob/master/notebooks/dev/f04_climate_data/climate_indicators.ipynb'
tropical['datasource'] = 'https://cloud.google.com/storage/docs/public-datasets/era5'
tropical.drop(columns=['index', '_wgs84x', '_wgs84y', 'time_zone_offset'], inplace=True)
tropical
# Out:
#     urau_code  parameter_value  year  \
# 0      ES019C             49.0  2018
# 1      CH012C              1.0  2018
# 2      BG018C              4.0  2018
# 3      IT050C             22.0  2018
# 4      BG014C             17.0  2018
# ..        ...              ...   ...
# 724    RO010C              0.0  2018
# 725    SE006C              3.0  2018
# 726    SI001C              0.0  2018
# 727    RO028C              0.0  2018
# 728    SK001C             11.0  2018
#
#                                              parameter  \
# 0    Count of tropical nights (min. temperature >20...
# 1    Count of tropical nights (min. temperature >20...
# 2    Count of tropical nights (min. temperature >20...
# 3    Count of tropical nights (min. temperature >20...
# 4    Count of tropical nights (min. temperature >20...
# ..                                                 ...
# 724  Count of tropical nights (min. temperature >20...
# 725  Count of tropical nights (min. temperature >20...
# 726  Count of tropical nights (min. temperature >20...
# 727  Count of tropical nights (min. temperature >20...
# 728  Count of tropical nights (min. temperature >20...
#
#                         parameter_id  \
# 0    city_era5_tropical_nights_count
# 1    city_era5_tropical_nights_count
# 2    city_era5_tropical_nights_count
# 3    city_era5_tropical_nights_count
# 4    city_era5_tropical_nights_count
# ..                               ...
# 724  city_era5_tropical_nights_count
# 725  city_era5_tropical_nights_count
# 726  city_era5_tropical_nights_count
# 727  city_era5_tropical_nights_count
# 728  city_era5_tropical_nights_count
#
#                                                lineage  \
# 0    https://github.com/FAIRiCUBE/uc1-urban-climate...
# 1    https://github.com/FAIRiCUBE/uc1-urban-climate...
# 2    https://github.com/FAIRiCUBE/uc1-urban-climate...
# 3    https://github.com/FAIRiCUBE/uc1-urban-climate...
# 4    https://github.com/FAIRiCUBE/uc1-urban-climate...
# ..                                                 ...
# 724  https://github.com/FAIRiCUBE/uc1-urban-climate...
# 725  https://github.com/FAIRiCUBE/uc1-urban-climate...
# 726  https://github.com/FAIRiCUBE/uc1-urban-climate...
# 727  https://github.com/FAIRiCUBE/uc1-urban-climate...
# 728  https://github.com/FAIRiCUBE/uc1-urban-climate...
#
#                                             datasource
# 0    https://cloud.google.com/storage/docs/public-d...
# 1    https://cloud.google.com/storage/docs/public-d...
# 2    https://cloud.google.com/storage/docs/public-d...
# 3    https://cloud.google.com/storage/docs/public-d...
# 4    https://cloud.google.com/storage/docs/public-d...
# ..                                                 ...
# 724  https://cloud.google.com/storage/docs/public-d...
# 725  https://cloud.google.com/storage/docs/public-d...
# 726  https://cloud.google.com/storage/docs/public-d...
# 727  https://cloud.google.com/storage/docs/public-d...
# 728  https://cloud.google.com/storage/docs/public-d...
#
# [729 rows x 7 columns]

# %%
tropical.to_sql(table_name, engine_postgresql, schema=schema_name, if_exists='replace')
# Out:
# 729

# %% [markdown]
# ## Daily temperature stats

# %%
with performance_report(filename="climate_stats_2018.html"):
    climate_stats = data_df.groupby('city')[['2m_temperature', 'total_precipitation']].agg(['mean', 'std', 'min', 'max'])
    climate_stats_c = climate_stats.compute()
# Out:
# ERROR:tornado.application:Exception in callback <bound method BokehTornado._keep_alive of <bokeh.server.tornado.BokehTornado object at 0x7fa376c6e8e0>>
# Traceback (most recent call last):
#   File "/home/conda/fairicubeuc1/467086c01351ef630f14ef1c1e2c3607605786e25d92214e8ed7a5ca85b36969-20230703-150612-959289-12-fairicube_env/lib/python3.9/site-packages/tornado/ioloop.py", line 921, in _run
#     val = self.callback()
#   File "/home/conda/fairicubeuc1/467086c01351ef630f14ef1c1e2c3607605786e25d92214e8ed7a5ca85b36969-20230703-150612-959289-12-fairicube_env/lib/python3.9/site-packages/bokeh/server/tornado.py", line 760, in _keep_alive
#     c.send_ping()
#   File "/home/conda/fairicubeuc1/467086c01351ef630f14ef1c1e2c3607605786e25d92214e8ed7a5ca85b36969-20230703-150612-959289-12-fairicube_env/lib/python3.9/site-packages/bokeh/server/connection.py", line 93, in send_ping
#     self._socket.ping(str(self._ping_count).encode("utf-8"))
#   File "/home/conda/fairicubeuc1/467086c01351ef630f14ef1c1e2c3607605786e25d92214e8ed7a5ca85b36969-20230703-150612-959289-12-fairicube_env/lib/python3.9/site-packages/tornado/websocket.py", line 444, in ping
#     raise WebSocketClosedError()
# tornado.websocket.WebSocketClosedError
# 2024-02-02 09:25:08,786 - tornado.application - ERROR - Exception in callback <bound method BokehTornado._keep_alive of <bokeh.server.tornado.BokehTornado object at 0x7fa376c6e8e0>>
# Traceback (most recent call last):
#   File "/home/conda/fairicubeuc1/467086c01351ef630f14ef1c1e2c3607605786e25d92214e8ed7a5ca85b36969-20230703-150612-959289-12-fairicube_env/lib/python3.9/site-packages/tornado/ioloop.py", line 921, in _run
#     val = self.callback()
#   File "/home/conda/fairicubeuc1/467086c01351ef630f14ef1c1e2c3607605786e25d92214e8ed7a5ca85b36969-20230703-150612-959289-12-fairicube_env/lib/python3.9/site-packages/bokeh/server/tornado.py", line 760, in _keep_alive
#     c.send_ping()
#   File "/home/conda/fairicubeuc1/467086c01351ef630f14ef1c1e2c3607605786e25d92214e8ed7a5ca85b36969-20230703-150612-959289-12-fairicube_env/lib/python3.9/site-packages/bokeh/server/connection.py", line 93, in send_ping
#     self._socket.ping(str(self._ping_count).encode("utf-8"))
#   File "/home/conda/fairicubeuc1/467086c01351ef630f14ef1c1e2c3607605786e25d92214e8ed7a5ca85b36969-20230703-150612-959289-12-fairicube_env/lib/python3.9/site-packages/tornado/websocket.py", line 444, in ping
#     raise WebSocketClosedError()
# tornado.websocket.WebSocketClosedError
# 2024-02-02 09:27:32,678 - distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# 2024-02-02 09:27:36,209 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2024-02-02 09:27:39,381 - distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# 2024-02-02 09:27:46,746 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2024-02-02 09:27:59,238 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)

# %%
client.close()

# %%
climate_stats_c
# Out:
#        2m_temperature                                    total_precipitation  \
#                  mean        std         min         max                mean
# city
# ES019C     288.266296   4.468978  274.669495  299.118530            0.000152
# CH012C     284.568481   8.230749  260.960510  306.778198            0.000128
# BG018C     285.901049  10.107052  256.783844  306.631409            0.000083
# IT050C     288.210292   7.184011  264.208771  305.620911            0.000166
# BG014C     287.567296   9.539940  256.713562  308.798645            0.000084
# ...               ...        ...         ...         ...                 ...
# RO010C     284.615500   9.644480  260.641907  304.793335            0.000073
# SE006C     280.396224   9.955242  256.820801  305.406708            0.000057
# SI001C     283.285869   8.665122  256.816132  303.702789            0.000159
# RO028C     283.647069   9.588638  255.702881  303.032104            0.000100
# SK001C     285.555646   9.603027  260.887482  308.379669            0.000072
#
#
#              std           min       max
# city
# ES019C  0.000353 -3.725290e-09  0.005259
# CH012C  0.000372 -3.725290e-09  0.007403
# BG018C  0.000284 -3.725290e-09  0.007257
# IT050C  0.000534 -3.725290e-09  0.009408
# BG014C  0.000342 -3.725290e-09  0.006873
# ...          ...           ...       ...
# RO010C  0.000248 -3.725290e-09  0.005556
# SE006C  0.000238 -3.725290e-09  0.005981
# SI001C  0.000543 -3.725290e-09  0.013283
# RO028C  0.000352 -3.725290e-09  0.007217
# SK001C  0.000265 -3.725290e-09  0.005450
#
# [729 rows x 8 columns]

# %% [markdown]
# ### Save into the database

# %%
year = '2018'
precipitation_stats = climate_stats_c[['total_precipitation']]
precipitation_stats.columns = precipitation_stats.columns.droplevel(0)
precipitation_stats.reset_index(inplace=True)
precipitation_stats

temperature_stats = climate_stats_c[['2m_temperature']]
temperature_stats.columns = temperature_stats.columns.droplevel(0)
temperature_stats.reset_index(inplace=True)
temperature_stats
# Out:
#        city        mean        std         min         max
# 0    ES019C  288.266296   4.468978  274.669495  299.118530
# 1    CH012C  284.568481   8.230749  260.960510  306.778198
# 2    BG018C  285.901049  10.107052  256.783844  306.631409
# 3    IT050C  288.210292   7.184011  264.208771  305.620911
# 4    BG014C  287.567296   9.539940  256.713562  308.798645
# ..      ...         ...        ...         ...         ...
# 724  RO010C  284.615500   9.644480  260.641907  304.793335
# 725  SE006C  280.396224   9.955242  256.820801  305.406708
# 726  SI001C  283.285869   8.665122  256.816132  303.702789
# 727  RO028C  283.647069   9.588638  255.702881  303.032104
# 728  SK001C  285.555646   9.603027  260.887482  308.379669
#
# [729 rows x 5 columns]

# %% [markdown]
# #### Long tables (cu_* tables)

# %%
schema_name = 'cube'
table_name = 'cu_city_era5_total_precipitation'
precipitation_stats.rename(columns={'mean': 'parameter_value-city_era5_total_precipitation_yearly_mean',
                     'std' : 'parameter_value-city_era5_total_precipitation_yearly_std',
                     'min' : 'parameter_value-city_era5_total_precipitation_yearly_min',
                     'max' : 'parameter_value-city_era5_total_precipitation_yearly_max',
                     'city' : 'city_code'}, inplace=True)
precipitation_stats_long = pd.wide_to_long(precipitation_stats, stubnames='parameter_value', 
                                  i='city_code', 
                                  j='parameter_id', 
                                  sep='-', 
                                  suffix='(city_era5_total_precipitation_yearly_[A-z]*)')
precipitation_stats_long.reset_index(inplace=True)
##################################
## cu_* tables mandatory columns:
# city_code,
# parameter, 
# parameter_id, 
# parameter_value, 
# year, 
# city_code_version, 
# lineage, 
# datasource

precipitation_stats_long['year'] = year
precipitation_stats_long['parameter'] = precipitation_stats_long['parameter_id']
precipitation_stats_long.loc[precipitation_stats_long['parameter_id'] == 'city_era5_total_precipitation_yearly_mean', 'parameter'] ='hourly total precipitation averaged in city over one year, based on 5th gen. ECMWF Atmospheric Reanalysis model'
precipitation_stats_long.loc[precipitation_stats_long['parameter_id'] == 'city_era5_total_precipitation_yearly_std', 'parameter'] = 'hourly total precipitation standard deviation in city over one year, based on 5th gen. ECMWF Atmospheric Reanalysis model'
precipitation_stats_long.loc[precipitation_stats_long['parameter_id'] == 'city_era5_total_precipitation_yearly_min', 'parameter'] = 'hourly total precipitation minimum in city within one year, based on 5th gen. ECMWF Atmospheric Reanalysis model'
precipitation_stats_long.loc[precipitation_stats_long['parameter_id'] == 'city_era5_total_precipitation_yearly_max', 'parameter'] = 'hourly total precipitation maximum in city within one year, based on 5th gen. ECMWF Atmospheric Reanalysis model'
precipitation_stats_long['city_code_version'] = 'ua_2021'
precipitation_stats_long['lineage'] = 'https://github.com/FAIRiCUBE/uc1-urban-climate/blob/master/notebooks/dev/f04_climate_data/climate_indicators.ipynb'
precipitation_stats_long['datasource'] = 'https://cloud.google.com/storage/docs/public-datasets/era5'
precipitation_stats_long
# Out:
# /tmp/ipykernel_344/88878874.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   precipitation_stats.rename(columns={'mean': 'parameter_value-city_era5_total_precipitation_yearly_mean',
#      city_code                               parameter_id  parameter_value  \
# 0       ES019C  city_era5_total_precipitation_yearly_mean         0.000152
# 1       CH012C  city_era5_total_precipitation_yearly_mean         0.000128
# 2       BG018C  city_era5_total_precipitation_yearly_mean         0.000083
# 3       IT050C  city_era5_total_precipitation_yearly_mean         0.000166
# 4       BG014C  city_era5_total_precipitation_yearly_mean         0.000084
# ...        ...                                        ...              ...
# 2911    RO010C   city_era5_total_precipitation_yearly_max         0.005556
# 2912    SE006C   city_era5_total_precipitation_yearly_max         0.005981
# 2913    SI001C   city_era5_total_precipitation_yearly_max         0.013283
# 2914    RO028C   city_era5_total_precipitation_yearly_max         0.007217
# 2915    SK001C   city_era5_total_precipitation_yearly_max         0.005450
#
#       year                                          parameter  \
# 0     2018  hourly total precipitation averaged in city ov...
# 1     2018  hourly total precipitation averaged in city ov...
# 2     2018  hourly total precipitation averaged in city ov...
# 3     2018  hourly total precipitation averaged in city ov...
# 4     2018  hourly total precipitation averaged in city ov...
# ...    ...                                                ...
# 2911  2018  hourly total precipitation maximum in city wit...
# 2912  2018  hourly total precipitation maximum in city wit...
# 2913  2018  hourly total precipitation maximum in city wit...
# 2914  2018  hourly total precipitation maximum in city wit...
# 2915  2018  hourly total precipitation maximum in city wit...
#
#      city_code_version                                            lineage  \
# 0              ua_2021  https://github.com/FAIRiCUBE/uc1-urban-climate...
# 1              ua_2021  https://github.com/FAIRiCUBE/uc1-urban-climate...
# 2              ua_2021  https://github.com/FAIRiCUBE/uc1-urban-climate...
# 3              ua_2021  https://github.com/FAIRiCUBE/uc1-urban-climate...
# 4              ua_2021  https://github.com/FAIRiCUBE/uc1-urban-climate...
# ...                ...                                                ...
# 2911           ua_2021  https://github.com/FAIRiCUBE/uc1-urban-climate...
# 2912           ua_2021  https://github.com/FAIRiCUBE/uc1-urban-climate...
# 2913           ua_2021  https://github.com/FAIRiCUBE/uc1-urban-climate...
# 2914           ua_2021  https://github.com/FAIRiCUBE/uc1-urban-climate...
# 2915           ua_2021  https://github.com/FAIRiCUBE/uc1-urban-climate...
#
#                                              datasource
# 0     https://cloud.google.com/storage/docs/public-d...
# 1     https://cloud.google.com/storage/docs/public-d...
# 2     https://cloud.google.com/storage/docs/public-d...
# 3     https://cloud.google.com/storage/docs/public-d...
# 4     https://cloud.google.com/storage/docs/public-d...
# ...                                                 ...
# 2911  https://cloud.google.com/storage/docs/public-d...
# 2912  https://cloud.google.com/storage/docs/public-d...
# 2913  https://cloud.google.com/storage/docs/public-d...
# 2914  https://cloud.google.com/storage/docs/public-d...
# 2915  https://cloud.google.com/storage/docs/public-d...
#
# [2916 rows x 8 columns]

# %%
precipitation_stats_long.to_sql(table_name, engine_postgresql, schema=schema_name, if_exists='replace')
# Out:
# 916

# %%
schema_name = 'cube'
table_name = 'cu_city_era5_2m_temperature'
temperature_stats.rename(columns={'mean': 'parameter_value-city_era5_2m_temperature_yearly_mean',
                     'std' : 'parameter_value-city_era5_2m_temperature_yearly_std',
                     'min' : 'parameter_value-city_era5_2m_temperature_yearly_min',
                     'max' : 'parameter_value-city_era5_2m_temperature_yearly_max',
                     'city' : 'city_code'}, inplace=True)
temperature_stats_long = pd.wide_to_long(temperature_stats, stubnames='parameter_value', 
                                  i='city_code', 
                                  j='parameter_id', 
                                  sep='-', 
                                  suffix='(city_era5_2m_temperature_yearly_[A-z]*)')
temperature_stats_long.reset_index(inplace=True)
##################################
## cu_* tables mandatory columns:
# city_code,
# parameter, 
# parameter_id, 
# parameter_value, 
# year, 
# city_code_version, 
# lineage, 
# datasource

temperature_stats_long['year'] = year
temperature_stats_long['parameter'] = temperature_stats_long['parameter_id']
temperature_stats_long.loc[temperature_stats_long['parameter_id'] == 'city_era5_2m_temperature_yearly_mean', 'parameter'] ='hourly 2m temperature averaged in city over one year, based on 5th gen. ECMWF Atmospheric Reanalysis model'
temperature_stats_long.loc[temperature_stats_long['parameter_id'] == 'city_era5_2m_temperature_yearly_std', 'parameter'] = 'hourly 2m temperature standard deviation in city over one year, based on 5th gen. ECMWF Atmospheric Reanalysis model'
temperature_stats_long.loc[temperature_stats_long['parameter_id'] == 'city_era5_2m_temperature_yearly_min', 'parameter'] = 'hourly 2m temperature minimum in city within one year, based on 5th gen. ECMWF Atmospheric Reanalysis model'
temperature_stats_long.loc[temperature_stats_long['parameter_id'] == 'city_era5_2m_temperature_yearly_max', 'parameter'] = 'hourly 2m temperature maximum in city within one year, based on 5th gen. ECMWF Atmospheric Reanalysis model'
temperature_stats_long['city_code_version'] = 'ua_2021'
temperature_stats_long['lineage'] = 'https://github.com/FAIRiCUBE/uc1-urban-climate/blob/master/notebooks/dev/f04_climate_data/climate_indicators.ipynb'
temperature_stats_long['datasource'] = 'https://cloud.google.com/storage/docs/public-datasets/era5'
temperature_stats_long
# Out:
# /tmp/ipykernel_344/3146435611.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temperature_stats.rename(columns={'mean': 'parameter_value-city_era5_2m_temperature_yearly_mean',
#      city_code                          parameter_id  parameter_value  year  \
# 0       ES019C  city_era5_2m_temperature_yearly_mean       288.266296  2018
# 1       CH012C  city_era5_2m_temperature_yearly_mean       284.568481  2018
# 2       BG018C  city_era5_2m_temperature_yearly_mean       285.901049  2018
# 3       IT050C  city_era5_2m_temperature_yearly_mean       288.210292  2018
# 4       BG014C  city_era5_2m_temperature_yearly_mean       287.567296  2018
# ...        ...                                   ...              ...   ...
# 2911    RO010C   city_era5_2m_temperature_yearly_max       304.793335  2018
# 2912    SE006C   city_era5_2m_temperature_yearly_max       305.406708  2018
# 2913    SI001C   city_era5_2m_temperature_yearly_max       303.702789  2018
# 2914    RO028C   city_era5_2m_temperature_yearly_max       303.032104  2018
# 2915    SK001C   city_era5_2m_temperature_yearly_max       308.379669  2018
#
#                                               parameter city_code_version  \
# 0     hourly 2m temperature averaged in city over on...           ua_2021
# 1     hourly 2m temperature averaged in city over on...           ua_2021
# 2     hourly 2m temperature averaged in city over on...           ua_2021
# 3     hourly 2m temperature averaged in city over on...           ua_2021
# 4     hourly 2m temperature averaged in city over on...           ua_2021
# ...                                                 ...               ...
# 2911  hourly 2m temperature maximum in city within o...           ua_2021
# 2912  hourly 2m temperature maximum in city within o...           ua_2021
# 2913  hourly 2m temperature maximum in city within o...           ua_2021
# 2914  hourly 2m temperature maximum in city within o...           ua_2021
# 2915  hourly 2m temperature maximum in city within o...           ua_2021
#
#                                                 lineage  \
# 0     https://github.com/FAIRiCUBE/uc1-urban-climate...
# 1     https://github.com/FAIRiCUBE/uc1-urban-climate...
# 2     https://github.com/FAIRiCUBE/uc1-urban-climate...
# 3     https://github.com/FAIRiCUBE/uc1-urban-climate...
# 4     https://github.com/FAIRiCUBE/uc1-urban-climate...
# ...                                                 ...
# 2911  https://github.com/FAIRiCUBE/uc1-urban-climate...
# 2912  https://github.com/FAIRiCUBE/uc1-urban-climate...
# 2913  https://github.com/FAIRiCUBE/uc1-urban-climate...
# 2914  https://github.com/FAIRiCUBE/uc1-urban-climate...
# 2915  https://github.com/FAIRiCUBE/uc1-urban-climate...
#
#                                              datasource
# 0     https://cloud.google.com/storage/docs/public-d...
# 1     https://cloud.google.com/storage/docs/public-d...
# 2     https://cloud.google.com/storage/docs/public-d...
# 3     https://cloud.google.com/storage/docs/public-d...
# 4     https://cloud.google.com/storage/docs/public-d...
# ...                                                 ...
# 2911  https://cloud.google.com/storage/docs/public-d...
# 2912  https://cloud.google.com/storage/docs/public-d...
# 2913  https://cloud.google.com/storage/docs/public-d...
# 2914  https://cloud.google.com/storage/docs/public-d...
# 2915  https://cloud.google.com/storage/docs/public-d...
#
# [2916 rows x 8 columns]

# %%
temperature_stats_long.to_sql(table_name, engine_postgresql, schema=schema_name, if_exists='replace')
# Out:
# 916
