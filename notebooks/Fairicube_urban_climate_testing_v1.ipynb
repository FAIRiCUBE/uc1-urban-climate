# %% [markdown]
# TESTING vvv

# %%
from edc import check_compatibility
check_compatibility("user-2022.10-14", dependencies=["SH"])

print ("hallo world")

# xcube_sh imports
from xcube_sh.cube import open_cube
from xcube_sh.config import CubeConfig
from xcube_sh.observers import Observers
from xcube_sh.sentinelhub import SentinelHub
from xcube_sh.viewer import ViewerServer

# xcube imports
from xcube.core.maskset import MaskSet
from xcube.core.geom import mask_dataset_by_geometry
from xcube.core.geom import clip_dataset_by_geometry

# Various utilities
import json
import matplotlib
import pandas as pd
import numpy as np
import xarray as xr
import shapely.geometry
import IPython.display
import zarr
from io import StringIO
# Out:
# <script type="text/javascript">
#         function toggle(id) {
#             el = document.getElementById(id);
#             el.style.display = el.style.display === "none" ? "block" : "none";
#         }
#     </script>
# <h2>Base image difference detected</h2>
# <p>This notebook has been verified using the <a href="https://github.com/eurodatacube/base-images/releases/tag/user-2022.10-14" target="_blank">base image <strong>user-2022.10-14</strong></a>,
# whereas you are currently running <a href="https://github.com/eurodatacube/base-images/releases/tag/user-2022.07-00" target="_blank">base image <strong>user-2022.07-00</strong></a>.</p>
#
# <p>If you experience any problems, please consult the <a href="https://eurodatacube.com/marketplace" target="_blank">marketplace</a> for a more recent version of this notebook.</p>
#
# <p>The following changes occurred in base image in between these versions:</p>
#
#
#             <p><h3 style="display: inline">New libraries (16)</h3>
#             <a href="#" onclick="toggle('#139760656415664')">show</a><p/>
#             <pre id="#139760656415664" style="display: none; margin-top: 5px"><code>+abseil-cpp                20210324.2           h9c3ff4c_0    conda-forge
# +bolt-python               0.7.1                    pypi_0    pypi
# +boto                      2.49.0                   pypi_0    pypi
# +dataclasses               0.8                pyhc8e2a94_3    conda-forge
# +imagecodecs-lite          2019.12.3        py39hd257fcd_5    conda-forge
# +importlib_metadata        4.11.4               hd8ed1ab_0    conda-forge
# +ipython_genutils          0.2.0                      py_1    conda-forge
# +libllvm10                 10.0.1               he513fc3_3    conda-forge
# +nbconvert                 6.5.0              pyhd8ed1ab_0    conda-forge
# +nbconvert-pandoc          6.5.0              pyhd8ed1ab_0    conda-forge
# +notebook                  6.4.12             pyha770c72_0    conda-forge
# +pandoc                    2.18                 ha770c72_0    conda-forge
# +prometheus_client         0.14.1             pyhd8ed1ab_0    conda-forge
# +thunder-python            1.4.2                    pypi_0    pypi
# +thunder-registration      1.0.1                    pypi_0    pypi
# +typed-ast                 1.5.4            py39hb9d737c_0    conda-forge
# </code></pre>
#
#             <p><h3 style="display: inline">Removed libraries (49)</h3>
#             <a href="#" onclick="toggle('#139760656198992')">show</a><p/>
#             <pre id="#139760656198992" style="display: none; margin-top: 5px"><code>-aiohttp-cors              0.7.0                    pypi_0    pypi
# -aom                       3.5.0                h27087fc_0    conda-forge
# -bidict                    0.22.0                   pypi_0    pypi
# -blessed                   1.19.1                   pypi_0    pypi
# -brunsli                   0.1                  h9c3ff4c_0    conda-forge
# -c-blosc2                  2.4.2                h7a311fb_0    conda-forge
# -charls                    2.3.4                h9c3ff4c_0    conda-forge
# -colorful                  0.5.4                    pypi_0    pypi
# -contourpy                 1.0.5            py39hf939315_0    conda-forge
# -dav1d                     1.0.0                h166bdaf_1    conda-forge
# -deepdiff                  5.8.1                    pypi_0    pypi
# -distlib                   0.3.6                    pypi_0    pypi
# -eo-grow                   1.3.1                    pypi_0    pypi
# -filelock                  3.8.0                    pypi_0    pypi
# -google-api-core           2.10.2                   pypi_0    pypi
# -googleapis-common-protos  1.56.4                   pypi_0    pypi
# -gpustat                   1.0.0                    pypi_0    pypi
# -grpcio                    1.43.0                   pypi_0    pypi
# -imagecodecs               2022.9.26        py39hf586f7a_0    conda-forge
# -jxrlib                    1.1                  h7f98852_2    conda-forge
# -libabseil                 20220623.0      cxx17_h48a1fff_4    conda-forge
# -libaec                    1.0.6                h9c3ff4c_0    conda-forge
# -libavif                   0.10.1               h5cdd6b5_2    conda-forge
# -libllvm11                 11.1.0               he0ac6c6_4    conda-forge
# -libsqlite                 3.39.4               h753d276_0    conda-forge
# -libzopfli                 1.0.3                h9c3ff4c_0    conda-forge
# -markdown                  3.4.1                    pypi_0    pypi
# -morecantile               3.1.2                    pypi_0    pypi
# -nvidia-ml-py              11.495.46                pypi_0    pypi
# -opencensus                0.11.0                   pypi_0    pypi
# -opencensus-context        0.1.3                    pypi_0    pypi
# -ordered-set               4.1.0                    pypi_0    pypi
# -panel                     0.14.0a26.post6+ge4bb671          pypi_0    pypi
# -param                     1.12.2                   pypi_0    pypi
# -pcre2                     10.37                hc3806b6_1    conda-forge
# -pkgutil-resolve-name      1.3.10             pyhd8ed1ab_0    conda-forge
# -prometheus-client         0.13.1                   pypi_0    pypi
# -py-spy                    0.3.14                   pypi_0    pypi
# -pyct                      0.4.8                    pypi_0    pypi
# -pydantic                  1.10.2                   pypi_0    pypi
# -pystac                    1.6.1              pyhd8ed1ab_1    conda-forge
# -python-rapidjson          1.8                      pypi_0    pypi
# -pyviz-comms               2.2.1                    pypi_0    pypi
# -ray                       2.0.0                    pypi_0    pypi
# -smart-open                6.2.0                    pypi_0    pypi
# -virtualenv                20.16.5                  pypi_0    pypi
# -werkzeug                  2.1.2              pyhd8ed1ab_1    conda-forge
# -zfp                       1.0.0                h27087fc_1    conda-forge
# -zlib-ng                   2.0.6                h166bdaf_0    conda-forge
# </code></pre>
#
#             <p><h3 style="display: inline">Libraries with major version differences (22)</h3>
#             <a href="#" onclick="toggle('#139760656113168')">show</a><p/>
#             <pre id="#139760656113168" style="display: none; margin-top: 5px"><code>-arrow-cpp                 9.0.0           py39hb3b17c4_7_cpu    conda-forge
# +arrow-cpp                 8.0.0           py39h395f399_3_cpu    conda-forge
# -attrs                     22.1.0             pyh71513ae_1    conda-forge
# +attrs                     21.4.0             pyhd8ed1ab_0    conda-forge
# -cryptography              38.0.2           py39hd97740a_0    conda-forge
# +cryptography              37.0.2           py39hd97740a_0    conda-forge
# -dask-image                2022.9.0           pyhd8ed1ab_0    conda-forge
# +dask-image                2021.12.0          pyhd8ed1ab_0    conda-forge
# -executing                 1.1.1              pyhd8ed1ab_0    conda-forge
# +executing                 0.8.3              pyhd8ed1ab_0    conda-forge
# -graphviz                  6.0.1                h5abf519_0    conda-forge
# +graphviz                  2.50.0               h8e749b2_2    conda-forge
# -harfbuzz                  5.3.0                h418a68e_0    conda-forge
# +harfbuzz                  3.4.0                hb4a5f5f_0    conda-forge
# -icu                       70.1                 h27087fc_0    conda-forge
# +icu                       69.1                 h9c3ff4c_0    conda-forge
# -ipywidgets                8.0.2              pyhd8ed1ab_1    conda-forge
# +ipywidgets                7.7.1              pyhd8ed1ab_0    conda-forge
# -jupyterlab_widgets        3.0.3              pyhd8ed1ab_0    conda-forge
# +jupyterlab_widgets        1.1.1              pyhd8ed1ab_0    conda-forge
# -lerc                      4.0.0                h27087fc_0    conda-forge
# +lerc                      3.0                  h9c3ff4c_0    conda-forge
# -libgoogle-cloud           2.2.0                h838d150_1    conda-forge
# +libgoogle-cloud           1.40.2               habd0e3a_0    conda-forge
# -mistune                   2.0.4              pyhd8ed1ab_0    conda-forge
# +mistune                   0.8.4           py39h3811e60_1005    conda-forge
# -nbconvert-core            7.2.1
# ---------
#
# The following environment variables are available:
#
# * `SH_CLIENT_ID`, `SH_INSTANCE_ID`, `SH_CLIENT_NAME`, `SH_CLIENT_SECRET`
# hallo world
