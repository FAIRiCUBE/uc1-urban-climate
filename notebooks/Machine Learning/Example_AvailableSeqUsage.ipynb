# %%
import pandas as pd

# %% [markdown]
# ### Import data

# %%
data = pd.read_csv('Available_Seq.csv')
data.head()
# Out:
#    index indic_code urau_code  1991  1992  1993  1994  1995  1996  1997  ...  \
# 0      0    EN1002V    AT001C   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1      1    EN1002V    AT002C   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2      2    EN1002V    AT003C   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3      3    EN1002V    AT004C   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4      4    EN1002V    AT005C   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#    2012  2013  2014  2015  2016  2017  2018  2019  2020  2021
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 34 columns]

# %% [markdown]
# ### Example (What are the cities/attributes pairs where the data is not available every one year, but available every two years and it has at least 10 years available)

# %%
data[~data['seq_1'] & data['seq_2'] & (data['n_years']>10)]
