# %%
from dask.distributed import Client
from dask.distributed import LocalCluster

# %%
# cluster = LocalCluster()
client = Client()
# Out:
# /home/conda/fairicubeuc1/898c84cf8044a9de1d61ead1f9b6c0602543ed9b62e264a9b27040cf8bded4d2-20230628-130800-852537-9-cube_env/lib/python3.9/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 33731 instead
#   warnings.warn(

# %%
client
# Out:
# <Client: 'tcp://127.0.0.1:34419' processes=2 threads=4, memory=15.00 GiB>

# %%
import dask.array as da
x = da.random.random((200000, 200000), chunks=(1000, 1000))
x
# Out:
# dask.array<random_sample, shape=(200000, 200000), dtype=float64, chunksize=(1000, 1000), chunktype=numpy.ndarray>

# %%
y = x + x.T
z = y[::2, 5000:].mean(axis=1)
z
# Out:
# dask.array<mean_agg-aggregate, shape=(100000,), dtype=float64, chunksize=(500,), chunktype=numpy.ndarray>

# %%
z.compute()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 z.compute()
#
# File /home/conda/fairicubeuc1/898c84cf8044a9de1d61ead1f9b6c0602543ed9b62e264a9b27040cf8bded4d2-20230628-130800-852537-9-cube_env/lib/python3.9/site-packages/dask/base.py:314, in DaskMethodsMixin.compute(self, **kwargs)
#     290 def compute(self, **kwargs):
#     291     """Compute this dask collection
#     292
#     293     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     312     dask.base.compute
#     313     """
# --> 314     (result,) = compute(self, traverse=False, **kwargs)
#     315     return result
#
# File /home/conda/fairicubeuc1/898c84cf8044a9de1d61ead1f9b6c0602543ed9b62e264a9b27040cf8bded4d2-20230628-130800-852537-9-cube_env/lib/python3.9/site-packages/dask/base.py:599, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
# ...

# %%
# cluster.close()
