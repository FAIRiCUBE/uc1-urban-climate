# %%
# Configure plots for inline use in Jupyter Notebook
# %matplotlib inline

import datetime as dt

# Utilities
import boto3
import dateutil
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
import os
import rasterio
# Various utilities
import json
import xarray as xr
import shapely.geometry
import IPython.display
import zarr

# Sentinel Hub
from sentinelhub import (
    CRS,
    BBox,
    ByocCollection,
    ByocCollectionAdditionalData,
    ByocCollectionBand,
    ByocTile,
    DataCollection,
    DownloadFailedException,
    MimeType,
    SentinelHubBYOC,
    SentinelHubRequest,
    SHConfig,
    bbox_to_dimensions,
    os_utils,
)

config = SHConfig()
config.instance_id = os.environ.get("SH_INSTANCE_ID")
config.sh_client_id = os.environ.get("SH_CLIENT_ID")
config.sh_client_secret = os.environ.get("SH_CLIENT_SECRET")
config.aws_access_key_id = os.environ.get("username")
config.aws_secret_access_key = os.environ.get("password")

print ("START the work ......")
# Out:
# START the work ......

# %%
lut =r"./../../../s3/data/d000_lookuptables/lookuptables.gpkg"
print (lut)
# Out:
# ./../../../s3/data/d000_lookuptables/lookuptables.gpkg

# %%
lut_table = gpd.read_file(lut,layer='L_UA2012_18_LUT')






lookuptable_city = L_core_city_urb_atl18
lookuptable_envZone = L_EnvZones
lookuptables — L_FUA_urban_atlas
lookuptables — L_UA_LCF_0612
lookuptables — L_UA_LCF_1218
lookuptables — L_UA2006_LUT
lookuptables — L_UA2012_18_LUT

# %%
for col in lut_table.columns.drop('geometry'):
    data = lut_table[col]
    print (data)
# Out:
# 0     13400
# 1     14100
# 2     31000
# 3     32000
# 4     12230
# 5     21000
# 6     12100
# 7     12210
# 8     11210
# 9     11100
# 10    40000
# 11    12220
# 12    14200
# 13    33000
# 14    11230
# 15    12400
# 16    23000
# 17    11240
# 18    13100
# 19    24000
# 20    11220
# 21    12300
# 22    22000
# 23    11300
# 24    50000
# 25    13300
# 26    25000
# Name: UA12_18_code, dtype: int64
# 0                Artificial surfaces
# 1                Artificial surfaces
# 2     Natural and semi-natural areas
# 3     Natural and semi-natural areas
# 4                Artificial surfaces
# 5                 Agricultural areas
# 6                Artificial surfaces
# 7                Artificial surfaces
# 8                Artificial surfaces
# 9                Artificial surfaces
# 10                          Wetlands
# 11               Artificial surfaces
# 12               Artificial surfaces
# 13    Natural and semi-natural areas
# 14               Artificial surfaces
# 15               Artificial surfaces
# 16                Agricultural areas
# 17               Artificial surfaces
# 18               Artificial surfaces
# 19                Agricultural areas
# 20               Artificial surfaces
# 21               Artificial surfaces
# 22                Agricultural areas
# 23               Artificial surfaces
# 24                             Water
# 25               Artificial surfaces
# 26                Agricultural areas
# Name: UA12_18_level1, dtype: object
# 0                     Mine, dump and construction sites
# 1           Artificial non-agricultural vegetated areas
# 2                                               Forests
# 3                    Herbaceous vegetation associations
# 4     Industrial, commercial, public, military, priv...
# 5                            Arable land (annual crops)
# 6     Industrial, commercial, public, military, priv...
# 7     Industrial, commercial, public, military, priv...
# 8                                          Urban fabric
# 9                                          Urban fabric
# 10                                             Wetlands
# 11    Industrial, commercial, public, military, priv...
# 12          Artificial non-agricultural vegetated areas
# 13            Open spaces with little or no vegetations
# 14                                         Urban fabric
# 15    Industrial, commercial, public, military, priv...
# 16                                             Pastures
# 17                                         Urban fabric
# 18                    Mine, dump and construction sites
# 19                        Complex and mixed cultivation
# 20                                         Urban fabric
# 21    Industrial, commercial, public, military, priv...
# 22                                      Permanent crops
# 23                                         Urban fabric
# 24                                                Water
# 25                    Mine, dump and construction sites
# 26                                             Orchards
# Name: UA12_18_level2, dtype: object
# 0                              Land without current use
# 1                                     Green urban areas
# 2                                               Forests
# 3                    Herbaceous vegetation associations
# 4             Road and rail network and associated land
# 5                            Arable land (annual crops)
# 6     Industrial, commercial, public, military and p...
# 7             Road and rail network and associated land
# 8           Discontinuous Urban Fabric (S.L. 10% - 80%)
# 9                  Continuous Urban Fabric (S.L. > 80%)
# 10                                             Wetlands
# 11            Road and rail network and associated land
# 12                        Sports and leisure facilities
# 13            Open spaces with little or no vegetations
# 14          Discontinuous Urban Fabric (S.L. 10% - 80%)
# 15                                             Airports
# 16                                             Pastures
# 17          Discontinuous Urban Fabric (S.L. 10% - 80%)
# 18                    Mineral extraction and dump sites
# 19                        Complex and mixed cultivation
# 20          Discontinuous Urban Fabric (S.L. 10% - 80%)
# 21                                           Port areas
# 22                                      Permanent crops
# 23                                  Isolated structures
# 24                                                Water
# 25                                   Construction sites
# 26                                             Orchards
# Name: UA12_18_level3, dtype: object
# 0                              Land without current use
# 1                                     Green urban areas
# 2                                               Forests
# 3                    Herbaceous vegetation associations
# 4                          Railways and associated land
# 5                            Arable land (annual crops)
# 6     Industrial, commercial, public, military and p...
# 7                Fast transit roads and associated land
# 8     Discontinuous Dense Urban Fabric (S.L. 50% - 80%)
# 9                  Continuous Urban Fabric (S.L. > 80%)
# 10                                             Wetlands
# 11                      Other roads and associated land
# 12                        Sports and leisure facilities
# 13            Open spaces with little or no vegetations
# 14    Discontinuous Low Density Urban Fabric (S.L. 1...
# 15                                             Airports
# 16                                             Pastures
# 17    Discontinuous Very Low Density Urban Fabric (S...
# 18                    Mineral extraction and dump sites
# 19                        Complex and mixed cultivation
# 20    Discontinuous Medium Density Urban Fabric (S.L...
# 21                                           Port areas
# 22                                      Permanent crops
# 23                                  Isolated structures
# 24                                                Water
# 25                                   Construction sites
# 26                                             Orchards
# Name: UA12_18_level4, dtype: object
# 0     0.05
# 1     0.05
# 2     0.00
# 3     0.00
# 4     0.40
# 5     0.00
# 6     0.60
# 7     0.40
# 8     0.65
# 9     0.90
# 10    0.00
# 11    0.40
# 12    0.05
# 13    0.00
# 14    0.20
# 15    0.60
# 16    0.00
# 17    0.05
# 18    0.10
# 19    0.00
# 20    0.40
# 21    0.80
# 22    0.00
# 23    0.10
# 24    0.00
# 25    0.30
# 26    0.00
# Name: Seal_share, dtype: float64

# %%
### reading raster
raster_2band = "./../../../s3/interim/LU001C/LU001C.tiff"
print (raster_2band)
# Out:
# ./../../../s3/interim/LU001C/LU001C.tiff

# %%
import geopandas as gpd
import numpy as np
import pandas as pd
import rasterio as rio
from pathlib import Path  

### reading raster
raster_2band = "./../../../s3/interim/LU001C/LU001C.tiff"
print (raster_2band)

with rio.Env():
    with rio.open(raster_2band) as src:
        crs = src.crs

        # create 1D coordinate arrays (coordinates of the pixel center)
        xmin, ymax = np.around(src.xy(0.00, 0.00), 9)  # src.xy(0, 0)
        xmax, ymin = np.around(src.xy(src.height-1, src.width-1), 9)  # src.xy(src.width-1, src.height-1)
        x = np.linspace(xmin, xmax, src.width)
        y = np.linspace(ymax, ymin, src.height)  # max -> min so coords are top -> bottom


        # create 2D arrays
        xs, ys = np.meshgrid(x, y)
        b1 = src.read(1)
        b2 = src.read(2)

        # Apply NoData mask
        mask = src.read_masks(1) > 0
        xs, ys, b1,b2 = xs[mask], ys[mask], b1[mask],b2[mask]

data = {"X": pd.Series(xs.ravel()),
        "Y": pd.Series(ys.ravel()),
        "city_code": pd.Series(b1.ravel()),
        "urban_atlas_2018": pd.Series(b2.ravel())
       
       }

df = pd.DataFrame(data=data)
geometry = gpd.points_from_xy(df.X, df.Y)
gdf = gpd.GeoDataFrame(df, crs=crs, geometry=geometry)

print(gdf.head())

print ("------------")

### combine:
combine_table_cube_urban=df.groupby(['city_code','urban_atlas_2018']).size().reset_index().rename(columns={0:'count'})
print(test.head())


combine_table_cube_urban.to_csv(index=False)

ouptut_table = "./../../../s3/data/c001_city_cube/tables/urban_cube_v1.csv"
filepath = Path(ouptut_table)  
filepath.parent.mkdir(parents=True, exist_ok=True)  
combine_table_cube_urban.to_csv(filepath)
# Out:
# ./../../../s3/interim/LU001C/LU001C.tiff
#           X          Y  city_code  urban_atlas_2018                  geometry
# 0  6.069266  49.654853      65535             31000  POINT (6.06927 49.65485)
# 1  6.069399  49.654853      65535             31000  POINT (6.06940 49.65485)
# 2  6.069532  49.654853      65535             31000  POINT (6.06953 49.65485)
# 3  6.069665  49.654853      65535             31000  POINT (6.06967 49.65485)
# 4  6.069798  49.654853      65535             31000  POINT (6.06980 49.65485)
# ------------
#    city_code  urban_atlas_2018  count
# 0        597             11100  26414
# 1        597             11210  64249
# 2        597             11220  16361
# 3        597             11230   1570
# 4        597             11240    247
