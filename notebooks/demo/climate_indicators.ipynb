# %% [markdown]
# # Climate indicators
#
# This notebook is designed to break down different climate indicators.
# The datasource are ERA-5 Data on:
# https://cloud.google.com/storage/docs/public-datasets/era5?hl=de
#
# We use this data source because the data is available there in an analysis ready cloud-optimised format.
#
# The selected climate indices are:
# - Number of summer days
# - Number of tropical nights
# - 2m temperature statistics (mean, std, min, max)
# - total precipitation (mean, std, min, max)

# %%
# reading LIBS
import sqlalchemy as sa # conection to the database
from datetime import datetime, timedelta
#import timezonefinder
from configparser import ConfigParser
import matplotlib.pyplot as plt
import pandas as pd
import xarray as xr      
import fsspec

print ("lib done")
# Out:
# lib done

# %%
from dask.distributed import Client, performance_report
client = Client()  # Connect to distributed cluster and override default
client
# Out:
# <Client: 'tcp://127.0.0.1:39527' processes=5 threads=15, memory=60.00 GiB>

# %%
# check data:

fs = fsspec.filesystem('gs')
fs.ls('gs://gcp-public-data-arco-era5/ar/1959-2022-full_37-1h-0p25deg-chunk-1.zarr-v2/')


arco_era5 = xr.open_zarr(
    'gs://gcp-public-data-arco-era5/ar/1959-2022-full_37-1h-0p25deg-chunk-1.zarr-v2', 
    # chunks={'time': 24*30},
    consolidated=True,
    drop_variables=["10m_u_component_of_wind",  
    "10m_v_component_of_wind",
    # "2m_temperature",
    "angle_of_sub_gridscale_orography",
    "anisotropy_of_sub_gridscale_orography",
    "geopotential",
    "geopotential_at_surface",
    "high_vegetation_cover",
    "lake_cover",
    "lake_depth",
    "land_sea_mask",
    "low_vegetation_cover",
    "mean_sea_level_pressure",
    "sea_ice_cover",
    "sea_surface_temperature",
    "slope_of_sub_gridscale_orography",
    "soil_type",
    "specific_humidity",
    "standard_deviation_of_filtered_subgrid_orography",
    "standard_deviation_of_orography",
    "surface_pressure",
    "temperature",
    "toa_incident_solar_radiation",
    "total_cloud_cover",
    "total_column_water_vapour",
    # "total_precipitation",
    "type_of_high_vegetation",
    "type_of_low_vegetation",
    "u_component_of_wind",
    "v_component_of_wind",
    "vertical_velocity"]
)
arco_era5


#for var in arco_era5.data_vars:
#    print(var)
# Out:
# <xarray.Dataset>
# Dimensions:              (time: 552264, latitude: 721, longitude: 1440,
#                           level: 37)
# Coordinates:
#   * latitude             (latitude) float32 90.0 89.75 89.5 ... -89.75 -90.0
#   * level                (level) int64 1 2 3 5 7 10 ... 875 900 925 950 975 1000
#   * longitude            (longitude) float32 0.0 0.25 0.5 ... 359.2 359.5 359.8
#   * time                 (time) datetime64[ns] 1959-01-01 ... 2021-12-31T23:0...
# Data variables:
#     2m_temperature       (time, latitude, longitude) float32 dask.array<chunksize=(1, 721, 1440), meta=np.ndarray>
#     total_precipitation  (time, latitude, longitude) float32 dask.array<chunksize=(1, 721, 1440), meta=np.ndarray>

# %% [markdown]
# ## Testing the data source and data:

# %%
arco_era5['2m_temperature_degree_celcius'].sel(time=slice(start_date, end_date)).sel(longitude=lon_city[0],latitude=lat_city[0], method="ffill")

# %%
# subeset of the big climate data cube:

# select 1 year

##PARAMETER+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++S
## Lux -location: AOI
lat_city=[37.8193869629]  #### y
lon_city=[lon_to_360(-25.7287017223)]   #### x
# subest time: TIME-RANGE
start_date = "2020-12-01"; end_date = "2020-12-31";   # TESTING only on month in 2020
##PARAMETER+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++E
# update values:  # Kelvin to Degree:
arco_era5['2m_temperature_degree_celcius'] = arco_era5['2m_temperature'] - 273.15

# subeset cube:
#arco_era5_2018_luxembourg = arco_era5['2m_temperature'].sel(time=slice(start_date, end_date),longitude=lon_city,latitude=lat_city)
arco_era5_2018_luxembourg = arco_era5['2m_temperature_degree_celcius'].sel(time=slice(start_date, end_date)).sel(longitude=lon_city[0],latitude=lat_city[0], method="ffill")

## calculation of different indicators:


## 1. TEMPERATURE indicicators:

## DAY and NIGHT SET:
START_NIGHT_h = 18  
END_NIGHT_h = 6

START_DAY_h = 6
END_DAY_h = 18


## 1.1 MAX and MIN per DAY and NIGHT:

# --------------------------------------------------------------------------------------------------------------

# --------------------------------------------------------------------------------------------------------------

## 1.1.1 MAX
max_temperature_per_day = arco_era5_2018_luxembourg.resample(time='D').max(dim='time')  # calc max and min temp per day
night_time_range = arco_era5_2018_luxembourg.sel(time=((arco_era5_2018_luxembourg['time.hour'] >= START_NIGHT_h) | (arco_era5_2018_luxembourg['time.hour'] < END_NIGHT_h)))
max_night_temperature_per_day = night_time_range.resample(time='D').max(dim='time') 


## MAX temp NIGHT per YEAR
max_night_temperature_per_year = night_time_range.resample(time='Y').max(dim='time') 
#print("Max Temp [°C] in the night per year:")
#print(max_night_temperature_per_year.time.dt.year.values.item())
#print(max_night_temperature_per_year.values.item())
#print("---")


day_time_range = arco_era5_2018_luxembourg.sel(time=((arco_era5_2018_luxembourg['time.hour'] >= START_DAY_h) | (arco_era5_2018_luxembourg['time.hour'] < END_DAY_h)))
max_day_temperature_per_day = day_time_range.resample(time='D').max(dim='time') 

## MAX temp DAY per YEAR
max_day_temperature_per_year = day_time_range.resample(time='Y').max(dim='time') 
#print("Max Temp [°C] in the day per year:")
#print(max_day_temperature_per_year.time.dt.year.values.item())
#print(max_day_temperature_per_year.values.item())
#print("---")


## 1.1.2 MIN
min_temperature_per_day = arco_era5_2018_luxembourg.resample(time='D').min(dim='time')
#night_time_range = arco_era5_2018_luxembourg.sel(time=((arco_era5_2018_luxembourg['time.hour'] >= START_NIGHT_h) | (arco_era5_2018_luxembourg['time.hour'] < END_NIGHT_h)))
min_night_temperature_per_day = night_time_range.resample(time='D').min(dim='time') 
#day_time_range = arco_era5_2018_luxembourg.sel(time=((arco_era5_2018_luxembourg['time.hour'] >= START_DAY_h) | (arco_era5_2018_luxembourg['time.hour'] < END_DAY_h)))
min_day_temperature_per_day = day_time_range.resample(time='D').min(dim='time') 





## 1.2 Number of tropical nights
# Calculate the number of tropical days per year
#tropical_threshold = 30
#tropical_nights_count_per_year = (max_night_temperature_per_year > tropical_threshold).groupby('time.year').sum()
## Print the result
#print("Number of tropical nights per year:")
#print("---")
##print(tropical_nights_count_per_year['year'].values.item())
##print(tropical_nights_count_per_year.values.item())
#tropical_nights_count_per_year_df = tropical_nights_count_per_year.to_dataframe()
#new_column_names = {'2m_temperature_degree_celcius': 'tropical_nights_count_per_year'}
#tropical_nights_count_per_year_df.rename(columns=new_column_names, inplace=True)


#print(tropical_nights_count_per_year_df)
#print("---")




## 1.3 Number of summer days
#Annual count of days when TX (daily maximum temperature) > 25°C. Let TXij be daily minimum temperature on day i in year j. Count the number of days where TXij > 25 °C.
max_temperature_per_day = arco_era5_2018_luxembourg.resample(time='D').max(dim='time')  # calc max and min temp per day

summer_day_threshold = 25
summer_days_count_per_year = (max_temperature_per_day > summer_day_threshold).groupby('time.year').sum()


#print("Number of summer days per year:")
#print("---")
##print(summer_days_count_per_year['year'].values.item())
##print(summer_days_count_per_year.values.item())
#summer_days_count_per_year_df = summer_days_count_per_year.to_dataframe()
#new_column_names = {'2m_temperature_degree_celcius': 'summer_days_count_per_year'}
#summer_days_count_per_year_df.rename(columns=new_column_names, inplace=True)
#print (summer_days_count_per_year_df)
#print("---")
#

#arco_era5_2018_month = arco_era5_2018.resample(time="1M")
#ds =arco_era5_2018_month

#ds_time_subeset = ds.sel(time=slice(start_date, end_date)) 

#ds = ds_time_subeset

#print (arco_era5_2018_luxembourg)
    

#max_temperature_per_day.plot() 

# #


# Create a single subplot with two columns
fig, ax = plt.subplots(figsize=(12, 5))

# Plot the original temperature data
max_night_temperature_per_day.plot(ax=ax, label='max Temperature per NIGHT', color='blue')
max_day_temperature_per_day.plot(ax=ax, label='max Temperature per DAY', color='red')

min_night_temperature_per_day.plot(ax=ax, label='min Temperature per NIGHT', color='green')
min_day_temperature_per_day.plot(ax=ax, label='min Temperature per DAY', color='black')

ax.set_title('Maximum % Minimum Temperature per Day and Night')
ax.set_xlabel('Time')
ax.set_ylabel('Temperature (°C)')
ax.legend()

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()

print ("done")

# %% [markdown]
# ## Filter datacube by location (city centre point coordinates, time)

# %%
from sqlalchemy import create_engine, text

### SET connection to MS-sql server:
################################################## SET postgre-sql connection:

################################################## read database keys:
def config(filename, section='postgresql'):
    # create a parser
    parser = ConfigParser()
    # read config file
    parser.read(filename)

    # get section, default to postgresql
    db = {}
    if parser.has_section(section):
        params = parser.items(section)
        for param in params:
            db[param[0]] = param[1]
    else:
        raise Exception(
            'Section {0} not found in the {1} file'.format(section, filename))

    return db
#config(filename='./../../../../uc1-urban-climate/database.ini')
keys = config(filename='./../../../../uc1-urban-climate/database.ini')

POSTGRESQL_SERVER_NAME=keys['host']
PORT=                  keys['port']
Database_name =        keys['database']
USER =                 keys['user']
PSW =                  keys['password']
##################################################
                                   
engine_postgresql = sa.create_engine('postgresql://'+USER+':'+PSW+ '@'+POSTGRESQL_SERVER_NAME+':'+str(PORT)+ '/' + Database_name)

## testing reading tables from database:

with engine_postgresql.begin() as conn:
    query = text("""SELECT urau_code, _wgs84y, _wgs84x, time_zone_offset
    FROM lut.l_city_urau2021;""")
    city_center_df = pd.read_sql_query(query, conn)
#print (city_center_df)
city_center_df = city_center_df.reset_index()  # make sure indexes pair with number of rows

city_center_df_r = city_center_df#[city_center_df['urau_code'] == 'PT007C']#[66:] #use this to create dataset subset
# city_center_df_r = city_center_df_r.loc[~(city_center_df_r['urau_code'].isin(['PT001C1', 'PT002C1', 'PT003C1']))]
# get city coordinates
# lonlat_list =[["NL005C", 4.640960, 52.113299], ["NL006C", 5.384670, 52.173656], ["NL007C", 5.921886, 52.189884]]
# helper function
def lon_to_360(dlon: float) -> float:
    return ((360 + (dlon % 360)) % 360)

lon_list = [lon_to_360(val) for val in city_center_df_r["_wgs84x"].values.tolist()]
lat_list = city_center_df_r["_wgs84y"].values.tolist()
city_list = city_center_df_r["urau_code"].values.tolist()
target_lon = xr.DataArray(lon_list, dims="city", coords={"city": city_list})
target_lat = xr.DataArray(lat_list, dims="city", coords={"city": city_list})
time_zone_offset = xr.DataArray(city_center_df_r['time_zone_offset'], dims="city", coords={"city": city_list})

# %%
# subest time: TIME-RANGE
start_date = "2018-01-01"
end_date = "2018-12-31"
data = arco_era5.sel(time=slice(start_date, end_date))
## next filter dataframe by city:
data = data.sel(
    longitude=target_lon, 
    latitude=target_lat, method="ffill")

data = xr.merge([data,time_zone_offset])

# ##PARAMETER+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++E
# # update values:  # Kelvin to Degree:
# data['2m_temperature_degree_celcius'] = data['2m_temperature'] - 273.15

# transform into Dask DataFrame to speed up computations
data_df = data.to_dask_dataframe()
data_df = data_df.reset_index()
# select only relevant variables
data_df = data_df[['city', 'time', 'time_zone_offset', 'latitude', 'longitude', '2m_temperature', 'total_precipitation']]

# %% [markdown]
# ## Summer days and tropical nights

# %%
def daytime(x):
    time_local = x.time+timedelta(hours=x.time_zone_offset)
    if(time_local.hour >= 6 and time_local.hour < 18):
        return 1
    else:
        return 0

def night_date(x):
    # assign previous day date to nighttime hours [0..end_night]
    # first adjust to local time
    time_local = x.time+timedelta(hours=x.time_zone_offset)
    if(time_local.hour < 6):
        # date = x.time - timedelta(days=1)
        return x.time - timedelta(days=1)
    else:
        return x.time


data_df['daytime'] = data_df.apply(daytime, axis=1, meta=(None, 'int'))
data_df['time_shifted'] =data_df.apply(night_date, axis=1, meta=(None, 'datetime64[ns]'))
data_df['date'] = data_df.time_shifted.dt.date
# data_df['2m_temperature_degree_celcius'] = data['2m_temperature'] - 273.15

# %%
## calculation of different indicators:
## 1.1 MAX and MIN per DAY and NIGHT:
with performance_report(filename="temp_max_2018.html"):
    temp_max = data_df.groupby(['city', 'daytime', 'date']).max()
    # temp_min = data_df.groupby(['city', 'daytime', 'date']).min()
    # --------------------------------------------------------------------------------------------------------------
    temp_max_c = temp_max.compute()
    # --------------------------------------------------------------------------------------------------------------
client.close()
# Out:
# 2024-02-01 14:38:07,735 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:38:09,498 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:38:11,696 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:38:12,128 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:38:14,325 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:38:16,451 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:38:19,630 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:38:25,792 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:38:28,492 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:38:31,654 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:38:34,286 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:38:35,851 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:38:38,624 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:38:40,459 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:38:41,545 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:38:41,684 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:38:44,473 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:38:45,020 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:38:47,274 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:38:47,844 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:38:48,977 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:38:51,497 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:38:53,107 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:38:53,630 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:38:55,086 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:38:57,530 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:38:59,270 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:38:59,631 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:00,232 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:01,440 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:01,846 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:03,852 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:03,870 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:03,906 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:06,169 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:06,200 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:07,642 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:08,260 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:09,128 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:09,938 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:10,998 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:11,885 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:13,091 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:15,420 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:15,799 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:17,458 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:17,507 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:19,709 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:19,984 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:21,926 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:22,882 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:24,641 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:25,083 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:26,511 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:27,249 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:28,707 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:29,760 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:30,719 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:31,784 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:32,212 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:33,693 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:34,036 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:35,104 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:35,219 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:36,284 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:37,172 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:37,873 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:40,115 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:40,698 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:41,810 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:42,235 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:43,894 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:45,594 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:46,285 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:48,098 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:49,231 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:49,879 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:50,688 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:51,652 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:52,644 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:53,316 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:54,304 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:54,554 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:56,230 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:57,067 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:58,069 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:59,060 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:59,615 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:39:59,926 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:01,367 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:01,844 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:01,948 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:04,464 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:05,012 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:05,057 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:06,978 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:06,996 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:07,948 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:08,946 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:09,171 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:09,725 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:11,643 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:11,846 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:12,091 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:12,232 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:13,732 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:14,150 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:14,629 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:15,616 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:15,975 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:16,818 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:17,280 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:18,576 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:18,758 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:18,939 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:20,443 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:20,839 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:22,581 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:22,731 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:22,770 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:23,196 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:24,546 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:24,566 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:25,361 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:26,779 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:27,312 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:27,489 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:29,681 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:29,702 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:29,779 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:29,841 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:31,327 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:31,753 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:32,109 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:33,239 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:33,712 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:33,906 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:35,752 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:35,791 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:36,032 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:36,106 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:38,327 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:38,383 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:38,570 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:40,406 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:40,896 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:41,022 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:41,303 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:43,278 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:43,405 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:44,164 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:44,981 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:45,164 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:46,973 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:47,002 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:47,899 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:48,491 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:49,439 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:49,452 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:50,092 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:51,111 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:52,522 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:52,539 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:53,422 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:54,244 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:54,351 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:55,409 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:56,031 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:56,697 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:57,599 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:57,675 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2024-02-01 14:40:58,612 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:00,289 - distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:00,504 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:00,795 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:01,338 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:02,431 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:04,108 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:04,483 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:04,896 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:05,323 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:05,944 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:06,871 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:07,630 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:08,868 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:09,016 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:09,754 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:10,477 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:11,294 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:11,969 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:12,687 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:12,763 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:13,545 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:14,978 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:14,996 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:15,282 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:15,718 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:17,696 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:17,846 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:18,624 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:19,426 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:20,354 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:20,868 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:21,187 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:21,257 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:22,506 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:22,708 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:24,081 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:24,122 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:25,463 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:26,632 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:26,801 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:26,809 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:28,591 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:29,197 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:29,797 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:29,887 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:30,725 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:31,409 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:31,430 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:33,102 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:34,366 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:35,492 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:35,833 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:36,426 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:37,352 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:37,645 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:38,456 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:38,777 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:40,124 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:40,368 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:40,576 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:41,540 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:43,081 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:43,379 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:43,884 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:45,271 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:45,975 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:46,425 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:46,968 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:47,094 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:48,330 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:49,009 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:49,535 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:51,116 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:51,127 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:52,744 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:53,002 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:53,382 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:54,042 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:54,346 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:54,831 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:57,146 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:57,662 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:57,682 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:57,892 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:41:58,999 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:00,638 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:00,868 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:01,273 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:01,869 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:02,902 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:03,188 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:03,972 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:04,417 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:05,991 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:07,047 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:07,122 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:07,461 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:09,070 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:09,670 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:10,059 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:10,342 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:11,775 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:12,189 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:12,979 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:13,212 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:15,568 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:15,589 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:16,301 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:16,745 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:17,889 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:18,171 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:19,250 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:20,403 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:21,591 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:22,039 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:22,349 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:23,038 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:23,838 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:24,580 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:25,572 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:25,843 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:26,970 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:27,137 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:27,860 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:28,859 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:29,933 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:29,972 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:30,309 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:32,262 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:32,699 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:33,504 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:33,726 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:34,718 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:35,804 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:36,787 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:36,800 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:37,033 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:38,625 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:39,731 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:39,756 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:40,717 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:42,003 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:42,648 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:43,275 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:43,618 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:44,826 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:44,858 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:45,611 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:46,490 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:46,495 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:48,625 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:49,443 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:50,358 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:50,761 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:51,130 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:52,619 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:53,136 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:53,820 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:54,001 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:54,851 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:55,595 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:57,076 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:58,433 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:58,618 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:42:58,712 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:43:00,077 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:43:00,261 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:43:00,857 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:43:01,609 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2024-02-01 14:43:03,102 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:43:03,867 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:43:04,934 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:43:05,384 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-01 14:43:06,549 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:43:06,734 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:43:07,901 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:43:08,787 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:43:08,834 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-01 14:43:09,455 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:43:10,567 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:43:10,939 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-01 14:43:12,356 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:43:13,118 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:43:13,638 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:43:15,135 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:43:16,402 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2024-02-01 14:43:16,441 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:43:16,782 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:43:17,291 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:43:18,363 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-02-01 14:43:18,689 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:43:20,079 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:43:20,543 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 14:43:21,968 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-02-01 14:43:22,318 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 14:43:24,193 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 14:43:24,577 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# ...
# 2024-02-01 15:19:05,499 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 15:19:08,326 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 15:19:11,638 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-01 15:19:12,758 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 15:19:13,613 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 15:19:17,928 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 15:19:20,086 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 15:19:21,286 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-01 15:19:22,156 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 15:19:28,503 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-02-01 15:19:29,297 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 15:19:29,630 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 15:19:29,668 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 15:19:35,924 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 15:19:36,799 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 15:19:37,958 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 15:19:39,909 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 15:19:42,337 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 15:19:47,221 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 15:19:47,495 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 15:19:47,679 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 15:19:50,540 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 15:19:54,365 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 15:19:55,656 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 15:19:57,131 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 15:19:58,259 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 15:20:01,544 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 15:20:04,797 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 15:20:04,915 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 15:20:08,329 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 15:20:12,029 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 15:20:12,584 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 15:20:14,364 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 15:20:15,734 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 15:20:20,105 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 15:20:21,249 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 15:20:22,237 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 15:20:26,107 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 15:20:28,471 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 15:20:29,546 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 15:20:30,323 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 15:20:35,599 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 15:20:35,978 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 15:20:39,200 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 15:20:42,661 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 15:20:44,069 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 15:20:45,421 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 15:20:49,376 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 15:20:50,214 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 15:20:51,863 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 15:20:53,178 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 15:20:58,040 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 15:20:58,146 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 15:21:01,412 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 15:21:01,582 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 15:21:05,312 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 15:21:08,290 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 15:21:09,522 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 15:21:14,286 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 15:21:14,383 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 15:21:16,215 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 15:21:17,370 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 15:21:21,611 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 15:21:23,678 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 15:21:25,189 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 15:21:26,966 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 15:21:30,695 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 15:21:32,672 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 15:21:32,695 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 15:21:35,640 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 15:21:38,714 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 15:21:41,157 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 15:21:42,018 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 15:21:44,580 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 15:21:48,232 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 15:21:49,530 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 15:21:50,047 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 15:21:53,872 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 15:21:57,811 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 15:21:57,830 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 15:21:59,907 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 15:22:02,174 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 15:22:06,586 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 15:22:07,541 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 15:22:08,291 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 15:22:08,719 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 15:22:15,215 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 15:22:16,355 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 15:22:18,370 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 15:22:18,692 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 15:22:24,707 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 15:22:25,752 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 15:22:26,638 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 15:22:27,143 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 15:22:33,836 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 15:22:34,269 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 15:22:35,647 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 15:22:35,898 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 15:22:42,195 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 15:22:43,463 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 15:22:43,494 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 15:22:44,670 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 15:22:51,209 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 15:22:52,134 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 15:22:53,345 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 15:22:53,869 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 15:22:57,140 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 15:23:00,693 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 15:23:02,475 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 15:23:02,637 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 15:23:06,530 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 15:23:10,433 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 15:23:11,494 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 15:23:11,578 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 15:23:17,739 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-02-01 15:23:18,919 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 15:23:20,403 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 15:23:21,343 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 15:23:26,374 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 15:23:27,725 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-02-01 15:23:28,749 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-02-01 15:23:31,096 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-02-01 15:23:35,134 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)

# %% [markdown]
# ### Filter summer days and tropical nights and yearly count

# %%
tropical_threshold = 30.0 + 273.15
summer_day_threshold = 25.0 + 273.15
# select only days and nights above the threshold
temp_max_c.reset_index(inplace=True)
summer_days = temp_max_c.loc[(temp_max_c['2m_temperature'] > summer_day_threshold) & (temp_max_c['daytime'] == 1)].reset_index()
tropical = temp_max_c.loc[(temp_max_c['2m_temperature'] > tropical_threshold) & (temp_max_c['daytime'] == 0)].reset_index()
# count how many days pass the threshold per year
tropical_count = tropical.groupby(['city', 'daytime']).count()
summer_days_count = summer_days.groupby('city').count()
# add result to the list of cities and set result to 0 for cities that do not have tropical nights/summer days
# zero is a valid value too!
summer_days_all = pd.merge(city_center_df_r, summer_days_count['2m_temperature'], how='left', left_on='urau_code', right_on='city').fillna(0)
tropical_nights_all = pd.merge(city_center_df_r, tropical_count['2m_temperature'], how='left', left_on='urau_code', right_on='city').fillna(0)

# %%
year = '2018'
# summer_days_count['year'] = year
# summer_days_count.reset_index()[['city', 'index', 'year']].to_csv('summer_days_2018.csv')
# tropical_count['year'] = year
# tropical_count.reset_index()[['city', 'index', 'year']].to_csv('tropical_count_2018.csv')
summer_days_all
# Out:
#      index urau_code    _wgs84y    _wgs84x  time_zone_offset  2m_temperature
# 0        0    ES019C  43.284187  -2.973099                 1             2.0
# 1        1    CH012C  47.178167   8.525289                 1            68.0
# 2        2    BG018C  43.283887  23.610568                 2           131.0
# 3        3    IT050C  40.913821  14.788222                 1           101.0
# 4        4    BG014C  41.891262  25.596173                 2           142.0
# ..     ...       ...        ...        ...               ...             ...
# 724    724    RO010C  46.541113  24.556075                 2           105.0
# 725    725    SE006C  59.944869  17.716293                 1            35.0
# 726    726    SI001C  46.071022  14.495290                 1            46.0
# 727    727    RO028C  44.855644  24.859411                 2            88.0
# 728    728    SK001C  48.148833  17.119074                 1           107.0
#
# [729 rows x 6 columns]

# %% [markdown]
# ### Save into the database

# %%
##################################
## cu_* tables mandatory columns:
# city_code,
# parameter, 
# parameter_id, 
# parameter_value, 
# year, 
# city_code_version, 
# lineage, 
# datasource
table_name = 'cu_city_era5_summer_days'
schema_name = 'cube'

summer_days_all.rename( columns= {'urau_code': 'city_code',
                         '2m_temperature': 'parameter_value'}, inplace=True)
summer_days_all['year'] = year
summer_days_all['parameter'] = 'Count of summer days (>25 degrees) per year per city, based on 5th gen. ECMWF Atmospheric Reanalysis model'
summer_days_all['parameter_id'] = 'city_era5_summer_days_count'
summer_days_all['lineage'] = 'https://github.com/FAIRiCUBE/uc1-urban-climate/blob/master/notebooks/dev/f04_climate_data/climate_indicators.ipynb'
summer_days_all['datasource'] = 'https://cloud.google.com/storage/docs/public-datasets/era5'
summer_days_all.drop(columns=['index', '_wgs84x', '_wgs84y', 'time_zone_offset'], inplace=True)
summer_days_all
# Out:
#     city_code  parameter_value  year  \
# 0      ES019C              2.0  2018
# 1      CH012C             68.0  2018
# 2      BG018C            131.0  2018
# 3      IT050C            101.0  2018
# 4      BG014C            142.0  2018
# ..        ...              ...   ...
# 724    RO010C            105.0  2018
# 725    SE006C             35.0  2018
# 726    SI001C             46.0  2018
# 727    RO028C             88.0  2018
# 728    SK001C            107.0  2018
#
#                                              parameter  \
# 0    Count of summer days (>25 degrees) per year pe...
# 1    Count of summer days (>25 degrees) per year pe...
# 2    Count of summer days (>25 degrees) per year pe...
# 3    Count of summer days (>25 degrees) per year pe...
# 4    Count of summer days (>25 degrees) per year pe...
# ..                                                 ...
# 724  Count of summer days (>25 degrees) per year pe...
# 725  Count of summer days (>25 degrees) per year pe...
# 726  Count of summer days (>25 degrees) per year pe...
# 727  Count of summer days (>25 degrees) per year pe...
# 728  Count of summer days (>25 degrees) per year pe...
#
#                     parameter_id  \
# 0    city_era5_summer_days_count
# 1    city_era5_summer_days_count
# 2    city_era5_summer_days_count
# 3    city_era5_summer_days_count
# 4    city_era5_summer_days_count
# ..                           ...
# 724  city_era5_summer_days_count
# 725  city_era5_summer_days_count
# 726  city_era5_summer_days_count
# 727  city_era5_summer_days_count
# 728  city_era5_summer_days_count
#
#                                                lineage  \
# 0    https://github.com/FAIRiCUBE/uc1-urban-climate...
# 1    https://github.com/FAIRiCUBE/uc1-urban-climate...
# 2    https://github.com/FAIRiCUBE/uc1-urban-climate...
# 3    https://github.com/FAIRiCUBE/uc1-urban-climate...
# 4    https://github.com/FAIRiCUBE/uc1-urban-climate...
# ..                                                 ...
# 724  https://github.com/FAIRiCUBE/uc1-urban-climate...
# 725  https://github.com/FAIRiCUBE/uc1-urban-climate...
# 726  https://github.com/FAIRiCUBE/uc1-urban-climate...
# 727  https://github.com/FAIRiCUBE/uc1-urban-climate...
# 728  https://github.com/FAIRiCUBE/uc1-urban-climate...
#
#                                             datasource
# 0    https://cloud.google.com/storage/docs/public-d...
# 1    https://cloud.google.com/storage/docs/public-d...
# 2    https://cloud.google.com/storage/docs/public-d...
# 3    https://cloud.google.com/storage/docs/public-d...
# 4    https://cloud.google.com/storage/docs/public-d...
# ..                                                 ...
# 724  https://cloud.google.com/storage/docs/public-d...
# 725  https://cloud.google.com/storage/docs/public-d...
# 726  https://cloud.google.com/storage/docs/public-d...
# 727  https://cloud.google.com/storage/docs/public-d...
# 728  https://cloud.google.com/storage/docs/public-d...
#
# [729 rows x 7 columns]

# %%
summer_days_all.to_sql(table_name, engine_postgresql, schema=schema_name, if_exists='replace')
# Out:
# 729

# %%
##################################
## cu_* tables mandatory columns:
# city_code,
# parameter, 
# parameter_id, 
# parameter_value, 
# year, 
# city_code_version, 
# lineage, 
# datasource
table_name = 'cu_city_era5_tropical_nights'
schema_name = 'cube'
tropical = tropical_nights_all
tropical.rename( columns= {'city': 'city_code',
                  '2m_temperature': 'parameter_value'}, inplace=True)
tropical['year'] = year
tropical['parameter'] = 'Count of tropical nights (>30 degrees) per year per city, based on 5th gen. ECMWF Atmospheric Reanalysis model'
tropical['parameter_id'] = 'city_era5_tropical_nights_count'
tropical['lineage'] = 'https://github.com/FAIRiCUBE/uc1-urban-climate/blob/master/notebooks/dev/f04_climate_data/climate_indicators.ipynb'
tropical['datasource'] = 'https://cloud.google.com/storage/docs/public-datasets/era5'
tropical.drop(columns=['index', '_wgs84x', '_wgs84y', 'time_zone_offset'], inplace=True)
tropical
# Out:
#     urau_code  parameter_value  year  \
# 0      ES019C              0.0  2018
# 1      CH012C              7.0  2018
# 2      BG018C             22.0  2018
# 3      IT050C              3.0  2018
# 4      BG014C             50.0  2018
# ..        ...              ...   ...
# 724    RO010C              2.0  2018
# 725    SE006C              1.0  2018
# 726    SI001C              0.0  2018
# 727    RO028C              0.0  2018
# 728    SK001C             16.0  2018
#
#                                              parameter  \
# 0    Count of tropical nights (>30 degrees) per yea...
# 1    Count of tropical nights (>30 degrees) per yea...
# 2    Count of tropical nights (>30 degrees) per yea...
# 3    Count of tropical nights (>30 degrees) per yea...
# 4    Count of tropical nights (>30 degrees) per yea...
# ..                                                 ...
# 724  Count of tropical nights (>30 degrees) per yea...
# 725  Count of tropical nights (>30 degrees) per yea...
# 726  Count of tropical nights (>30 degrees) per yea...
# 727  Count of tropical nights (>30 degrees) per yea...
# 728  Count of tropical nights (>30 degrees) per yea...
#
#                         parameter_id  \
# 0    city_era5_tropical_nights_count
# 1    city_era5_tropical_nights_count
# 2    city_era5_tropical_nights_count
# 3    city_era5_tropical_nights_count
# 4    city_era5_tropical_nights_count
# ..                               ...
# 724  city_era5_tropical_nights_count
# 725  city_era5_tropical_nights_count
# 726  city_era5_tropical_nights_count
# 727  city_era5_tropical_nights_count
# 728  city_era5_tropical_nights_count
#
#                                                lineage  \
# 0    https://github.com/FAIRiCUBE/uc1-urban-climate...
# 1    https://github.com/FAIRiCUBE/uc1-urban-climate...
# 2    https://github.com/FAIRiCUBE/uc1-urban-climate...
# 3    https://github.com/FAIRiCUBE/uc1-urban-climate...
# 4    https://github.com/FAIRiCUBE/uc1-urban-climate...
# ..                                                 ...
# 724  https://github.com/FAIRiCUBE/uc1-urban-climate...
# 725  https://github.com/FAIRiCUBE/uc1-urban-climate...
# 726  https://github.com/FAIRiCUBE/uc1-urban-climate...
# 727  https://github.com/FAIRiCUBE/uc1-urban-climate...
# 728  https://github.com/FAIRiCUBE/uc1-urban-climate...
#
#                                             datasource
# 0    https://cloud.google.com/storage/docs/public-d...
# 1    https://cloud.google.com/storage/docs/public-d...
# 2    https://cloud.google.com/storage/docs/public-d...
# 3    https://cloud.google.com/storage/docs/public-d...
# 4    https://cloud.google.com/storage/docs/public-d...
# ..                                                 ...
# 724  https://cloud.google.com/storage/docs/public-d...
# 725  https://cloud.google.com/storage/docs/public-d...
# 726  https://cloud.google.com/storage/docs/public-d...
# 727  https://cloud.google.com/storage/docs/public-d...
# 728  https://cloud.google.com/storage/docs/public-d...
#
# [729 rows x 7 columns]

# %%
tropical.to_sql(table_name, engine_postgresql, schema=schema_name, if_exists='replace')
# Out:
# 729

# %% [markdown]
# ## Daily temperature stats

# %%
with performance_report(filename="climate_stats_2018.html"):
    climate_stats = data_df.groupby('city')[['2m_temperature', 'total_precipitation']].agg(['mean', 'std', 'min', 'max'])
    climate_stats_c = climate_stats.compute()
# Out:
# ERROR:tornado.application:Exception in callback <bound method BokehTornado._keep_alive of <bokeh.server.tornado.BokehTornado object at 0x7fa376c6e8e0>>
# Traceback (most recent call last):
#   File "/home/conda/fairicubeuc1/467086c01351ef630f14ef1c1e2c3607605786e25d92214e8ed7a5ca85b36969-20230703-150612-959289-12-fairicube_env/lib/python3.9/site-packages/tornado/ioloop.py", line 921, in _run
#     val = self.callback()
#   File "/home/conda/fairicubeuc1/467086c01351ef630f14ef1c1e2c3607605786e25d92214e8ed7a5ca85b36969-20230703-150612-959289-12-fairicube_env/lib/python3.9/site-packages/bokeh/server/tornado.py", line 760, in _keep_alive
#     c.send_ping()
#   File "/home/conda/fairicubeuc1/467086c01351ef630f14ef1c1e2c3607605786e25d92214e8ed7a5ca85b36969-20230703-150612-959289-12-fairicube_env/lib/python3.9/site-packages/bokeh/server/connection.py", line 93, in send_ping
#     self._socket.ping(str(self._ping_count).encode("utf-8"))
#   File "/home/conda/fairicubeuc1/467086c01351ef630f14ef1c1e2c3607605786e25d92214e8ed7a5ca85b36969-20230703-150612-959289-12-fairicube_env/lib/python3.9/site-packages/tornado/websocket.py", line 444, in ping
#     raise WebSocketClosedError()
# tornado.websocket.WebSocketClosedError
# 2024-02-02 09:25:08,786 - tornado.application - ERROR - Exception in callback <bound method BokehTornado._keep_alive of <bokeh.server.tornado.BokehTornado object at 0x7fa376c6e8e0>>
# Traceback (most recent call last):
#   File "/home/conda/fairicubeuc1/467086c01351ef630f14ef1c1e2c3607605786e25d92214e8ed7a5ca85b36969-20230703-150612-959289-12-fairicube_env/lib/python3.9/site-packages/tornado/ioloop.py", line 921, in _run
#     val = self.callback()
#   File "/home/conda/fairicubeuc1/467086c01351ef630f14ef1c1e2c3607605786e25d92214e8ed7a5ca85b36969-20230703-150612-959289-12-fairicube_env/lib/python3.9/site-packages/bokeh/server/tornado.py", line 760, in _keep_alive
#     c.send_ping()
#   File "/home/conda/fairicubeuc1/467086c01351ef630f14ef1c1e2c3607605786e25d92214e8ed7a5ca85b36969-20230703-150612-959289-12-fairicube_env/lib/python3.9/site-packages/bokeh/server/connection.py", line 93, in send_ping
#     self._socket.ping(str(self._ping_count).encode("utf-8"))
#   File "/home/conda/fairicubeuc1/467086c01351ef630f14ef1c1e2c3607605786e25d92214e8ed7a5ca85b36969-20230703-150612-959289-12-fairicube_env/lib/python3.9/site-packages/tornado/websocket.py", line 444, in ping
#     raise WebSocketClosedError()
# tornado.websocket.WebSocketClosedError
# 2024-02-02 09:27:32,678 - distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# 2024-02-02 09:27:36,209 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2024-02-02 09:27:39,381 - distributed.utils_perf - WARNING - full garbage collections took 31% CPU time recently (threshold: 10%)
# 2024-02-02 09:27:46,746 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2024-02-02 09:27:59,238 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)

# %%
climate_stats_c
# Out:
#        2m_temperature                                    total_precipitation  \
#                  mean        std         min         max                mean
# city
# ES019C     288.266296   4.468978  274.669495  299.118530            0.000152
# CH012C     284.568481   8.230749  260.960510  306.778198            0.000128
# BG018C     285.901049  10.107052  256.783844  306.631409            0.000083
# IT050C     288.210292   7.184011  264.208771  305.620911            0.000166
# BG014C     287.567296   9.539940  256.713562  308.798645            0.000084
# ...               ...        ...         ...         ...                 ...
# RO010C     284.615500   9.644480  260.641907  304.793335            0.000073
# SE006C     280.396224   9.955242  256.820801  305.406708            0.000057
# SI001C     283.285869   8.665122  256.816132  303.702789            0.000159
# RO028C     283.647069   9.588638  255.702881  303.032104            0.000100
# SK001C     285.555646   9.603027  260.887482  308.379669            0.000072
#
#
#              std           min       max
# city
# ES019C  0.000353 -3.725290e-09  0.005259
# CH012C  0.000372 -3.725290e-09  0.007403
# BG018C  0.000284 -3.725290e-09  0.007257
# IT050C  0.000534 -3.725290e-09  0.009408
# BG014C  0.000342 -3.725290e-09  0.006873
# ...          ...           ...       ...
# RO010C  0.000248 -3.725290e-09  0.005556
# SE006C  0.000238 -3.725290e-09  0.005981
# SI001C  0.000543 -3.725290e-09  0.013283
# RO028C  0.000352 -3.725290e-09  0.007217
# SK001C  0.000265 -3.725290e-09  0.005450
#
# [729 rows x 8 columns]

# %% [markdown]
# ### Save into the database

# %%
year = '2018'
precipitation_stats = climate_stats_c[['total_precipitation']]
precipitation_stats.columns = precipitation_stats.columns.droplevel(0)
precipitation_stats.reset_index(inplace=True)
precipitation_stats

temperature_stats = climate_stats_c[['2m_temperature']]
temperature_stats.columns = temperature_stats.columns.droplevel(0)
temperature_stats.reset_index(inplace=True)
temperature_stats
# Out:
#        city        mean        std         min         max
# 0    ES019C  288.266296   4.468978  274.669495  299.118530
# 1    CH012C  284.568481   8.230749  260.960510  306.778198
# 2    BG018C  285.901049  10.107052  256.783844  306.631409
# 3    IT050C  288.210292   7.184011  264.208771  305.620911
# 4    BG014C  287.567296   9.539940  256.713562  308.798645
# ..      ...         ...        ...         ...         ...
# 724  RO010C  284.615500   9.644480  260.641907  304.793335
# 725  SE006C  280.396224   9.955242  256.820801  305.406708
# 726  SI001C  283.285869   8.665122  256.816132  303.702789
# 727  RO028C  283.647069   9.588638  255.702881  303.032104
# 728  SK001C  285.555646   9.603027  260.887482  308.379669
#
# [729 rows x 5 columns]

# %% [markdown]
# #### Long tables (cu_* tables)

# %%
schema_name = 'cube'
table_name = 'cu_city_era5_total_precipitation'
precipitation_stats.rename(columns={'mean': 'parameter_value-city_era5_total_precipitation_yearly_mean',
                     'std' : 'parameter_value-city_era5_total_precipitation_yearly_std',
                     'min' : 'parameter_value-city_era5_total_precipitation_yearly_min',
                     'max' : 'parameter_value-city_era5_total_precipitation_yearly_max',
                     'city' : 'city_code'}, inplace=True)
precipitation_stats_long = pd.wide_to_long(precipitation_stats, stubnames='parameter_value', 
                                  i='city_code', 
                                  j='parameter_id', 
                                  sep='-', 
                                  suffix='(city_era5_total_precipitation_yearly_[A-z]*)')
precipitation_stats_long.reset_index(inplace=True)
##################################
## cu_* tables mandatory columns:
# city_code,
# parameter, 
# parameter_id, 
# parameter_value, 
# year, 
# city_code_version, 
# lineage, 
# datasource

precipitation_stats_long['year'] = year
precipitation_stats_long['parameter'] = precipitation_stats_long['parameter_id']
precipitation_stats_long.loc[precipitation_stats_long['parameter_id'] == 'city_era5_total_precipitation_yearly_mean', 'parameter'] ='hourly total precipitation averaged in city over one year, based on 5th gen. ECMWF Atmospheric Reanalysis model'
precipitation_stats_long.loc[precipitation_stats_long['parameter_id'] == 'city_era5_total_precipitation_yearly_std', 'parameter'] = 'hourly total precipitation standard deviation in city over one year, based on 5th gen. ECMWF Atmospheric Reanalysis model'
precipitation_stats_long.loc[precipitation_stats_long['parameter_id'] == 'city_era5_total_precipitation_yearly_min', 'parameter'] = 'hourly total precipitation minimum in city within one year, based on 5th gen. ECMWF Atmospheric Reanalysis model'
precipitation_stats_long.loc[precipitation_stats_long['parameter_id'] == 'city_era5_total_precipitation_yearly_max', 'parameter'] = 'hourly total precipitation maximum in city within one year, based on 5th gen. ECMWF Atmospheric Reanalysis model'
precipitation_stats_long['city_code_version'] = 'ua_2021'
precipitation_stats_long['lineage'] = 'https://github.com/FAIRiCUBE/uc1-urban-climate/blob/master/notebooks/dev/f04_climate_data/climate_indicators.ipynb'
precipitation_stats_long['datasource'] = 'https://cloud.google.com/storage/docs/public-datasets/era5'
precipitation_stats_long
# Out:
# /tmp/ipykernel_344/88878874.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   precipitation_stats.rename(columns={'mean': 'parameter_value-city_era5_total_precipitation_yearly_mean',
#      city_code                               parameter_id  parameter_value  \
# 0       ES019C  city_era5_total_precipitation_yearly_mean         0.000152
# 1       CH012C  city_era5_total_precipitation_yearly_mean         0.000128
# 2       BG018C  city_era5_total_precipitation_yearly_mean         0.000083
# 3       IT050C  city_era5_total_precipitation_yearly_mean         0.000166
# 4       BG014C  city_era5_total_precipitation_yearly_mean         0.000084
# ...        ...                                        ...              ...
# 2911    RO010C   city_era5_total_precipitation_yearly_max         0.005556
# 2912    SE006C   city_era5_total_precipitation_yearly_max         0.005981
# 2913    SI001C   city_era5_total_precipitation_yearly_max         0.013283
# 2914    RO028C   city_era5_total_precipitation_yearly_max         0.007217
# 2915    SK001C   city_era5_total_precipitation_yearly_max         0.005450
#
#       year                                          parameter  \
# 0     2018  hourly total precipitation averaged in city ov...
# 1     2018  hourly total precipitation averaged in city ov...
# 2     2018  hourly total precipitation averaged in city ov...
# 3     2018  hourly total precipitation averaged in city ov...
# 4     2018  hourly total precipitation averaged in city ov...
# ...    ...                                                ...
# 2911  2018  hourly total precipitation maximum in city wit...
# 2912  2018  hourly total precipitation maximum in city wit...
# 2913  2018  hourly total precipitation maximum in city wit...
# 2914  2018  hourly total precipitation maximum in city wit...
# 2915  2018  hourly total precipitation maximum in city wit...
#
#      city_code_version                                            lineage  \
# 0              ua_2021  https://github.com/FAIRiCUBE/uc1-urban-climate...
# 1              ua_2021  https://github.com/FAIRiCUBE/uc1-urban-climate...
# 2              ua_2021  https://github.com/FAIRiCUBE/uc1-urban-climate...
# 3              ua_2021  https://github.com/FAIRiCUBE/uc1-urban-climate...
# 4              ua_2021  https://github.com/FAIRiCUBE/uc1-urban-climate...
# ...                ...                                                ...
# 2911           ua_2021  https://github.com/FAIRiCUBE/uc1-urban-climate...
# 2912           ua_2021  https://github.com/FAIRiCUBE/uc1-urban-climate...
# 2913           ua_2021  https://github.com/FAIRiCUBE/uc1-urban-climate...
# 2914           ua_2021  https://github.com/FAIRiCUBE/uc1-urban-climate...
# 2915           ua_2021  https://github.com/FAIRiCUBE/uc1-urban-climate...
#
#                                              datasource
# 0     https://cloud.google.com/storage/docs/public-d...
# 1     https://cloud.google.com/storage/docs/public-d...
# 2     https://cloud.google.com/storage/docs/public-d...
# 3     https://cloud.google.com/storage/docs/public-d...
# 4     https://cloud.google.com/storage/docs/public-d...
# ...                                                 ...
# 2911  https://cloud.google.com/storage/docs/public-d...
# 2912  https://cloud.google.com/storage/docs/public-d...
# 2913  https://cloud.google.com/storage/docs/public-d...
# 2914  https://cloud.google.com/storage/docs/public-d...
# 2915  https://cloud.google.com/storage/docs/public-d...
#
# [2916 rows x 8 columns]

# %%
precipitation_stats_long.to_sql(table_name, engine_postgresql, schema=schema_name, if_exists='replace')
# Out:
# 916

# %%
schema_name = 'cube'
table_name = 'cu_city_era5_2m_temperature'
temperature_stats.rename(columns={'mean': 'parameter_value-city_era5_2m_temperature_yearly_mean',
                     'std' : 'parameter_value-city_era5_2m_temperature_yearly_std',
                     'min' : 'parameter_value-city_era5_2m_temperature_yearly_min',
                     'max' : 'parameter_value-city_era5_2m_temperature_yearly_max',
                     'city' : 'city_code'}, inplace=True)
temperature_stats_long = pd.wide_to_long(temperature_stats, stubnames='parameter_value', 
                                  i='city_code', 
                                  j='parameter_id', 
                                  sep='-', 
                                  suffix='(city_era5_2m_temperature_yearly_[A-z]*)')
temperature_stats_long.reset_index(inplace=True)
##################################
## cu_* tables mandatory columns:
# city_code,
# parameter, 
# parameter_id, 
# parameter_value, 
# year, 
# city_code_version, 
# lineage, 
# datasource

temperature_stats_long['year'] = year
temperature_stats_long['parameter'] = temperature_stats_long['parameter_id']
temperature_stats_long.loc[temperature_stats_long['parameter_id'] == 'city_era5_2m_temperature_yearly_mean', 'parameter'] ='hourly 2m temperature averaged in city over one year, based on 5th gen. ECMWF Atmospheric Reanalysis model'
temperature_stats_long.loc[temperature_stats_long['parameter_id'] == 'city_era5_2m_temperature_yearly_std', 'parameter'] = 'hourly 2m temperature standard deviation in city over one year, based on 5th gen. ECMWF Atmospheric Reanalysis model'
temperature_stats_long.loc[temperature_stats_long['parameter_id'] == 'city_era5_2m_temperature_yearly_min', 'parameter'] = 'hourly 2m temperature minimum in city within one year, based on 5th gen. ECMWF Atmospheric Reanalysis model'
temperature_stats_long.loc[temperature_stats_long['parameter_id'] == 'city_era5_2m_temperature_yearly_max', 'parameter'] = 'hourly 2m temperature maximum in city within one year, based on 5th gen. ECMWF Atmospheric Reanalysis model'
temperature_stats_long['city_code_version'] = 'ua_2021'
temperature_stats_long['lineage'] = 'https://github.com/FAIRiCUBE/uc1-urban-climate/blob/master/notebooks/dev/f04_climate_data/climate_indicators.ipynb'
temperature_stats_long['datasource'] = 'https://cloud.google.com/storage/docs/public-datasets/era5'
temperature_stats_long
# Out:
# /tmp/ipykernel_344/3146435611.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temperature_stats.rename(columns={'mean': 'parameter_value-city_era5_2m_temperature_yearly_mean',
#      city_code                          parameter_id  parameter_value  year  \
# 0       ES019C  city_era5_2m_temperature_yearly_mean       288.266296  2018
# 1       CH012C  city_era5_2m_temperature_yearly_mean       284.568481  2018
# 2       BG018C  city_era5_2m_temperature_yearly_mean       285.901049  2018
# 3       IT050C  city_era5_2m_temperature_yearly_mean       288.210292  2018
# 4       BG014C  city_era5_2m_temperature_yearly_mean       287.567296  2018
# ...        ...                                   ...              ...   ...
# 2911    RO010C   city_era5_2m_temperature_yearly_max       304.793335  2018
# 2912    SE006C   city_era5_2m_temperature_yearly_max       305.406708  2018
# 2913    SI001C   city_era5_2m_temperature_yearly_max       303.702789  2018
# 2914    RO028C   city_era5_2m_temperature_yearly_max       303.032104  2018
# 2915    SK001C   city_era5_2m_temperature_yearly_max       308.379669  2018
#
#                                               parameter city_code_version  \
# 0     hourly 2m temperature averaged in city over on...           ua_2021
# 1     hourly 2m temperature averaged in city over on...           ua_2021
# 2     hourly 2m temperature averaged in city over on...           ua_2021
# 3     hourly 2m temperature averaged in city over on...           ua_2021
# 4     hourly 2m temperature averaged in city over on...           ua_2021
# ...                                                 ...               ...
# 2911  hourly 2m temperature maximum in city within o...           ua_2021
# 2912  hourly 2m temperature maximum in city within o...           ua_2021
# 2913  hourly 2m temperature maximum in city within o...           ua_2021
# 2914  hourly 2m temperature maximum in city within o...           ua_2021
# 2915  hourly 2m temperature maximum in city within o...           ua_2021
#
#                                                 lineage  \
# 0     https://github.com/FAIRiCUBE/uc1-urban-climate...
# 1     https://github.com/FAIRiCUBE/uc1-urban-climate...
# 2     https://github.com/FAIRiCUBE/uc1-urban-climate...
# 3     https://github.com/FAIRiCUBE/uc1-urban-climate...
# 4     https://github.com/FAIRiCUBE/uc1-urban-climate...
# ...                                                 ...
# 2911  https://github.com/FAIRiCUBE/uc1-urban-climate...
# 2912  https://github.com/FAIRiCUBE/uc1-urban-climate...
# 2913  https://github.com/FAIRiCUBE/uc1-urban-climate...
# 2914  https://github.com/FAIRiCUBE/uc1-urban-climate...
# 2915  https://github.com/FAIRiCUBE/uc1-urban-climate...
#
#                                              datasource
# 0     https://cloud.google.com/storage/docs/public-d...
# 1     https://cloud.google.com/storage/docs/public-d...
# 2     https://cloud.google.com/storage/docs/public-d...
# 3     https://cloud.google.com/storage/docs/public-d...
# 4     https://cloud.google.com/storage/docs/public-d...
# ...                                                 ...
# 2911  https://cloud.google.com/storage/docs/public-d...
# 2912  https://cloud.google.com/storage/docs/public-d...
# 2913  https://cloud.google.com/storage/docs/public-d...
# 2914  https://cloud.google.com/storage/docs/public-d...
# 2915  https://cloud.google.com/storage/docs/public-d...
#
# [2916 rows x 8 columns]

# %%
temperature_stats_long.to_sql(table_name, engine_postgresql, schema=schema_name, if_exists='replace')
# Out:
# 916
